# %% [markdown]
# ## Introduction
#
# The objective of this exercise is to check your ability to use basic Python Data Structures, control program flow and, define and use functions
#
#
# We will be using the [EU referendum results data](https://www.electoralcommission.org.uk/who-we-are-and-what-we-do/elections-and-referendums/past-elections-and-referendums/eu-referendum/results-and-turnout-eu-referendum).
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c4/2016_EU_Referendum_Ballot_Paper.svg/1280px-2016_EU_Referendum_Ballot_Paper.svg.png" width="450"/>
#
#
#
# For this exercise, we have split the full data into three files.
#
# ```uk_demo.json```
#
# | Field       | Description                    |
# |-------------|--------------------------------|
# | ```Area_Code```   | Unique identifier for the area  |
# | ```Area```        | Area Name               |
# | ```Region_Code``` | Unique identifier for the region |
# | ```Region```      | Region Name             |
# | ```Electorate```  | Number of registered voters in the area   |
#
# ```uk_results.json```
#
# | Field       | Description                            |
# |-------------|----------------------------------------|
# | ```Area_Code```   | Unique identifier for an area          |
# | ```Votes_Cast```  | Number of Votes Cast in the area       |
# | ```Valid_Votes``` | Number of Valid Votes cast in the area |
# | ```Remain```      | Number of votes for Remain             |
# | ```Leave```       | Number of votes for Leave              |
#
# ```uk_rejected_ballots.json```
#
# | Field                         | Description                                                            |
# |-------------------------------|------------------------------------------------------------------------|
# | ```Area_Code```               | Unique identifier for an area                                          |
# | ```Rejected_Ballots```        | Number of Rejected Ballots in the Area                                 |
# | ```No_official_mark```        | Number of ballots rejected because they did not have any offical mark  |
# | ```Voting_for_both_answers``` | Number of ballots rejected because they voted for both answers         |
# | ```Writing_or_mark```         | Number of ballots rejected because they had a writing instead of check |

# %% [markdown]
# ### Without using the Pandas / NumPy Libraries

# %% [markdown]
# ### Q1. Load the data

# %%
import requests

# %%
uk_demo_src = r"https://raw.githubusercontent.com/viveknest/statascratch-solutions/main/UK%20Referendum%20Data/uk_demo.json"
f = requests.get(uk_demo_src)
uk_demo = f.json()
uk_demo[:5]
# Out:
# [{'Area_Code': 'E06000031',
#   'Area': 'Peterborough',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 120892},
#  {'Area_Code': 'E06000032',
#   'Area': 'Luton',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 127612},
#  {'Area_Code': 'E06000033',
#   'Area': 'Southend-on-Sea',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 128856},
#  {'Area_Code': 'E06000034',
#   'Area': 'Thurrock',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 109897},
#  {'Area_Code': 'E06000055',
#   'Area': 'Bedford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 119530}]

# %%
uk_results_src = r"https://raw.githubusercontent.com/viveknest/statascratch-solutions/main/UK%20Referendum%20Data/uk_results.json"
f = requests.get(uk_results_src)
uk_results = f.json()
uk_results[:5]
# Out:
# [{'Area_Code': 'E06000031',
#   'Votes_Cast': 87469,
#   'Valid_Votes': 87392,
#   'Remain': 34176,
#   'Leave': 53216},
#  {'Area_Code': 'E06000032',
#   'Votes_Cast': 84616,
#   'Valid_Votes': 84481,
#   'Remain': 36708,
#   'Leave': 47773},
#  {'Area_Code': 'E06000033',
#   'Votes_Cast': 93939,
#   'Valid_Votes': 93870,
#   'Remain': 39348,
#   'Leave': 54522},
#  {'Area_Code': 'E06000034',
#   'Votes_Cast': 79950,
#   'Valid_Votes': 79916,
#   'Remain': 22151,
#   'Leave': 57765},
#  {'Area_Code': 'E06000055',
#   'Votes_Cast': 86135,
#   'Valid_Votes': 86066,
#   'Remain': 41497,
#   'Leave': 44569}]

# %%
uk_rejected_src = r"https://github.com/viveknest/statascratch-solutions/raw/main/UK%20Referendum%20Data/uk_rejected_ballots.json"
f = requests.get(uk_rejected_src)
uk_rejected = f.json()
uk_rejected[:5]
# Out:
# [{'Area_Code': 'E06000031',
#   'Rejected_Ballots': 77,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 32,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 38},
#  {'Area_Code': 'E06000032',
#   'Rejected_Ballots': 135,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 85,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 50},
#  {'Area_Code': 'E06000033',
#   'Rejected_Ballots': 69,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 21,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 48},
#  {'Area_Code': 'E06000034',
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 8,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 23},
#  {'Area_Code': 'E06000055',
#   'Rejected_Ballots': 69,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 26,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 42}]

# %% [markdown]
# ### Q2. Join the data
#
# Consolidate the three lists into a single list by joining on the Area Code

# %%
# Convert lists into a dictionary of dictionaries
def dict_convert(data, key = 'Area_Code'):
    out_dict = {}
    for row in data:
        out_dict.update({
            row[key]: row
        })
    return out_dict

# %%
uk_demo_dict = dict_convert(uk_demo)
uk_demo_dict
# Out:
# {'E06000031': {'Area_Code': 'E06000031',
#   'Area': 'Peterborough',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 120892},
#  'E06000032': {'Area_Code': 'E06000032',
#   'Area': 'Luton',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 127612},
#  'E06000033': {'Area_Code': 'E06000033',
#   'Area': 'Southend-on-Sea',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 128856},
#  'E06000034': {'Area_Code': 'E06000034',
#   'Area': 'Thurrock',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 109897},
#  'E06000055': {'Area_Code': 'E06000055',
#   'Area': 'Bedford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 119530},
#  'E06000056': {'Area_Code': 'E06000056',
#   'Area': 'Central Bedfordshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 204004},
#  'E07000008': {'Area_Code': 'E07000008',
#   'Area': 'Cambridge',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 80108},
#  'E07000009': {'Area_Code': 'E07000009',
#   'Area': 'East Cambridgeshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 62435},
#  'E07000010': {'Area_Code': 'E07000010',
#   'Area': 'Fenland',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 71447},
#  'E07000011': {'Area_Code': 'E07000011',
#   'Area': 'Huntingdonshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 128486},
#  'E07000012': {'Area_Code': 'E07000012',
#   'Area': 'South Cambridgeshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 114830},
#  'E07000066': {'Area_Code': 'E07000066',
#   'Area': 'Basildon',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 132771},
#  'E07000067': {'Area_Code': 'E07000067',
#   'Area': 'Braintree',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 112562},
#  'E07000068': {'Area_Code': 'E07000068',
#   'Area': 'Brentwood',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 58777},
#  'E07000069': {'Area_Code': 'E07000069',
#   'Area': 'Castle Point',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 68860},
#  'E07000070': {'Area_Code': 'E07000070',
#   'Area': 'Chelmsford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 129971},
#  'E07000071': {'Area_Code': 'E07000071',
#   'Area': 'Colchester',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 127520},
#  'E07000072': {'Area_Code': 'E07000072',
#   'Area': 'Epping Forest',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 100016},
#  'E07000073': {'Area_Code': 'E07000073',
#   'Area': 'Harlow',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 59124},
#  'E07000074': {'Area_Code': 'E07000074',
#   'Area': 'Maldon',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 49073},
#  'E07000075': {'Area_Code': 'E07000075',
#   'Area': 'Rochford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 66589},
#  'E07000076': {'Area_Code': 'E07000076',
#   'Area': 'Tendring',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 111167},
#  'E07000077': {'Area_Code': 'E07000077',
#   'Area': 'Uttlesford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 64735},
#  'E07000095': {'Area_Code': 'E07000095',
#   'Area': 'Broxbourne',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 68997},
#  'E07000096': {'Area_Code': 'E07000096',
#   'Area': 'Dacorum',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 108965},
#  'E07000098': {'Area_Code': 'E07000098',
#   'Area': 'Hertsmere',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 73295},
#  'E07000099': {'Area_Code': 'E07000099',
#   'Area': 'North Hertfordshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 99316},
#  'E07000102': {'Area_Code': 'E07000102',
#   'Area': 'Three Rivers',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 67380},
#  'E07000103': {'Area_Code': 'E07000103',
#   'Area': 'Watford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 65060},
#  'E07000143': {'Area_Code': 'E07000143',
#   'Area': 'Breckland',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 98989},
#  'E07000144': {'Area_Code': 'E07000144',
#   'Area': 'Broadland',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 99254},
#  'E07000145': {'Area_Code': 'E07000145',
#   'Area': 'Great Yarmouth',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 72634},
#  'E07000146': {'Area_Code': 'E07000146',
#   'Area': "King's Lynn and West Norfolk",
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 113884},
#  'E07000147': {'Area_Code': 'E07000147',
#   'Area': 'North Norfolk',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 83065},
#  'E07000148': {'Area_Code': 'E07000148',
#   'Area': 'Norwich',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 96091},
#  'E07000149': {'Area_Code': 'E07000149',
#   'Area': 'South Norfolk',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 102395},
#  'E07000200': {'Area_Code': 'E07000200',
#   'Area': 'Babergh',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 70628},
#  'E07000201': {'Area_Code': 'E07000201',
#   'Area': 'Forest Heath',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 38527},
#  'E07000202': {'Area_Code': 'E07000202',
#   'Area': 'Ipswich',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 91574},
#  'E07000203': {'Area_Code': 'E07000203',
#   'Area': 'Mid Suffolk',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 78325},
#  'E07000204': {'Area_Code': 'E07000204',
#   'Area': 'St Edmundsbury',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 81148},
#  'E07000205': {'Area_Code': 'E07000205',
#   'Area': 'Suffolk Coastal',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 98195},
#  'E07000206': {'Area_Code': 'E07000206',
#   'Area': 'Waveney',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 90391},
#  'E07000240': {'Area_Code': 'E07000240',
#   'Area': 'St Albans',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 104859},
#  'E07000241': {'Area_Code': 'E07000241',
#   'Area': 'Welwyn Hatfield',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 78146},
#  'E07000242': {'Area_Code': 'E07000242',
#   'Area': 'East Hertfordshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 106260},
#  'E07000243': {'Area_Code': 'E07000243',
#   'Area': 'Stevenage',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 62156},
#  'E06000015': {'Area_Code': 'E06000015',
#   'Area': 'Derby',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 171246},
#  'E06000016': {'Area_Code': 'E06000016',
#   'Area': 'Leicester',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 213819},
#  'E06000017': {'Area_Code': 'E06000017',
#   'Area': 'Rutland',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 29390},
#  'E06000018': {'Area_Code': 'E06000018',
#   'Area': 'Nottingham',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 195394},
#  'E07000032': {'Area_Code': 'E07000032',
#   'Area': 'Amber Valley',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 96760},
#  'E07000033': {'Area_Code': 'E07000033',
#   'Area': 'Bolsover',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 58063},
#  'E07000034': {'Area_Code': 'E07000034',
#   'Area': 'Chesterfield',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 79905},
#  'E07000035': {'Area_Code': 'E07000035',
#   'Area': 'Derbyshire Dales',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 57075},
#  'E07000036': {'Area_Code': 'E07000036',
#   'Area': 'Erewash',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 87596},
#  'E07000037': {'Area_Code': 'E07000037',
#   'Area': 'High Peak',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 72487},
#  'E07000038': {'Area_Code': 'E07000038',
#   'Area': 'North East Derbyshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 78855},
#  'E07000039': {'Area_Code': 'E07000039',
#   'Area': 'South Derbyshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73856},
#  'E07000129': {'Area_Code': 'E07000129',
#   'Area': 'Blaby',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73832},
#  'E07000130': {'Area_Code': 'E07000130',
#   'Area': 'Charnwood',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 133780},
#  'E07000131': {'Area_Code': 'E07000131',
#   'Area': 'Harborough',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 67420},
#  'E07000132': {'Area_Code': 'E07000132',
#   'Area': 'Hinckley and Bosworth',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 85305},
#  'E07000133': {'Area_Code': 'E07000133',
#   'Area': 'Melton',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 37273},
#  'E07000134': {'Area_Code': 'E07000134',
#   'Area': 'North West Leicestershire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73944},
#  'E07000135': {'Area_Code': 'E07000135',
#   'Area': 'Oadby and Wigston',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 42684},
#  'E07000136': {'Area_Code': 'E07000136',
#   'Area': 'Boston',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 39363},
#  'E07000137': {'Area_Code': 'E07000137',
#   'Area': 'East Lindsey',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 107009},
#  'E07000138': {'Area_Code': 'E07000138',
#   'Area': 'Lincoln',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 63351},
#  'E07000139': {'Area_Code': 'E07000139',
#   'Area': 'North Kesteven',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 86468},
#  'E07000140': {'Area_Code': 'E07000140',
#   'Area': 'South Holland',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 65701},
#  'E07000141': {'Area_Code': 'E07000141',
#   'Area': 'South Kesteven',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 105457},
#  'E07000142': {'Area_Code': 'E07000142',
#   'Area': 'West Lindsey',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73499},
#  'E07000150': {'Area_Code': 'E07000150',
#   'Area': 'Corby',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 43313},
#  'E07000151': {'Area_Code': 'E07000151',
#   'Area': 'Daventry',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 61004},
#  'E07000152': {'Area_Code': 'E07000152',
#   'Area': 'East Northamptonshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 68334},
#  'E07000153': {'Area_Code': 'E07000153',
#   'Area': 'Kettering',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 70570},
#  'E07000154': {'Area_Code': 'E07000154',
#   'Area': 'Northampton',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 144948},
#  'E07000155': {'Area_Code': 'E07000155',
#   'Area': 'South Northamptonshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 71309},
#  'E07000156': {'Area_Code': 'E07000156',
#   'Area': 'Wellingborough',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 54572},
#  'E07000170': {'Area_Code': 'E07000170',
#   'Area': 'Ashfield',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 91916},
#  'E07000171': {'Area_Code': 'E07000171',
#   'Area': 'Bassetlaw',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 85547},
#  'E07000172': {'Area_Code': 'E07000172',
#   'Area': 'Broxtowe',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 83593},
#  'E07000173': {'Area_Code': 'E07000173',
#   'Area': 'Gedling',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 88298},
#  'E07000174': {'Area_Code': 'E07000174',
#   'Area': 'Mansfield',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 77624},
#  'E07000175': {'Area_Code': 'E07000175',
#   'Area': 'Newark and Sherwood',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 87338},
#  'E07000176': {'Area_Code': 'E07000176',
#   'Area': 'Rushcliffe',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 86401},
#  'E09000001': {'Area_Code': 'E09000001',
#   'Area': 'City of London',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 5987},
#  'E09000002': {'Area_Code': 'E09000002',
#   'Area': 'Barking and Dagenham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 115812},
#  'E09000003': {'Area_Code': 'E09000003',
#   'Area': 'Barnet',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 223467},
#  'E09000004': {'Area_Code': 'E09000004',
#   'Area': 'Bexley',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 170779},
#  'E09000005': {'Area_Code': 'E09000005',
#   'Area': 'Brent',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 186793},
#  'E09000006': {'Area_Code': 'E09000006',
#   'Area': 'Bromley',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 231473},
#  'E09000007': {'Area_Code': 'E09000007',
#   'Area': 'Camden',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 145425},
#  'E09000008': {'Area_Code': 'E09000008',
#   'Area': 'Croydon',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 245349},
#  'E09000009': {'Area_Code': 'E09000009',
#   'Area': 'Ealing',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 212991},
#  'E09000010': {'Area_Code': 'E09000010',
#   'Area': 'Enfield',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 198387},
#  'E09000011': {'Area_Code': 'E09000011',
#   'Area': 'Greenwich',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 168967},
#  'E09000012': {'Area_Code': 'E09000012',
#   'Area': 'Hackney',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 163284},
#  'E09000013': {'Area_Code': 'E09000013',
#   'Area': 'Hammersmith and Fulham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 114863},
#  'E09000014': {'Area_Code': 'E09000014',
#   'Area': 'Haringey',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 150098},
#  'E09000015': {'Area_Code': 'E09000015',
#   'Area': 'Harrow',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 162397},
#  'E09000016': {'Area_Code': 'E09000016',
#   'Area': 'Havering',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 183082},
#  'E09000017': {'Area_Code': 'E09000017',
#   'Area': 'Hillingdon',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 193033},
#  'E09000018': {'Area_Code': 'E09000018',
#   'Area': 'Hounslow',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 165050},
#  'E09000019': {'Area_Code': 'E09000019',
#   'Area': 'Islington',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 144514},
#  'E09000020': {'Area_Code': 'E09000020',
#   'Area': 'Kensington and Chelsea',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 83042},
#  'E09000021': {'Area_Code': 'E09000021',
#   'Area': 'Kingston upon Thames',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 108838},
#  'E09000022': {'Area_Code': 'E09000022',
#   'Area': 'Lambeth',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 210800},
#  'E09000023': {'Area_Code': 'E09000023',
#   'Area': 'Lewisham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 197514},
#  'E09000024': {'Area_Code': 'E09000024',
#   'Area': 'Merton',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 136352},
#  'E09000025': {'Area_Code': 'E09000025',
#   'Area': 'Newham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 176985},
#  'E09000026': {'Area_Code': 'E09000026',
#   'Area': 'Redbridge',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 189843},
#  'E09000027': {'Area_Code': 'E09000027',
#   'Area': 'Richmond upon Thames',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 132632},
#  'E09000028': {'Area_Code': 'E09000028',
#   'Area': 'Southwark',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 195875},
#  'E09000029': {'Area_Code': 'E09000029',
#   'Area': 'Sutton',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 140288},
#  'E09000030': {'Area_Code': 'E09000030',
#   'Area': 'Tower Hamlets',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 167820},
#  'E09000031': {'Area_Code': 'E09000031',
#   'Area': 'Waltham Forest',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 162983},
#  'E09000032': {'Area_Code': 'E09000032',
#   'Area': 'Wandsworth',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 219521},
#  'E09000033': {'Area_Code': 'E09000033',
#   'Area': 'Westminster',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 120524},
#  'E06000001': {'Area_Code': 'E06000001',
#   'Area': 'Hartlepool',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 70341},
#  'E06000002': {'Area_Code': 'E06000002',
#   'Area': 'Middlesbrough',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 94612},
#  'E06000003': {'Area_Code': 'E06000003',
#   'Area': 'Redcar and Cleveland',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 103529},
#  'E06000004': {'Area_Code': 'E06000004',
#   'Area': 'Stockton-on-Tees',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 141486},
#  'E06000005': {'Area_Code': 'E06000005',
#   'Area': 'Darlington',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 77662},
#  'E06000047': {'Area_Code': 'E06000047',
#   'Area': 'County Durham',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 389507},
#  'E06000057': {'Area_Code': 'E06000057',
#   'Area': 'Northumberland',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 240496},
#  'E08000021': {'Area_Code': 'E08000021',
#   'Area': 'Newcastle upon Tyne',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 190735},
#  'E08000022': {'Area_Code': 'E08000022',
#   'Area': 'North Tyneside',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 156993},
#  'E08000023': {'Area_Code': 'E08000023',
#   'Area': 'South Tyneside',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 115893},
#  'E08000024': {'Area_Code': 'E08000024',
#   'Area': 'Sunderland',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 207221},
#  'E08000037': {'Area_Code': 'E08000037',
#   'Area': 'Gateshead',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 145866},
#  'E06000006': {'Area_Code': 'E06000006',
#   'Area': 'Halton',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 95289},
#  'E06000007': {'Area_Code': 'E06000007',
#   'Area': 'Warrington',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 157042},
#  'E06000008': {'Area_Code': 'E06000008',
#   'Area': 'Blackburn with Darwen',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 100117},
#  'E06000009': {'Area_Code': 'E06000009',
#   'Area': 'Blackpool',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 102354},
#  'E06000049': {'Area_Code': 'E06000049',
#   'Area': 'Cheshire East',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 285957},
#  'E06000050': {'Area_Code': 'E06000050',
#   'Area': 'Cheshire West and Chester',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 259878},
#  'E07000026': {'Area_Code': 'E07000026',
#   'Area': 'Allerdale',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 74426},
#  'E07000027': {'Area_Code': 'E07000027',
#   'Area': 'Barrow-in-Furness',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 53194},
#  'E07000028': {'Area_Code': 'E07000028',
#   'Area': 'Carlisle',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 80124},
#  'E07000029': {'Area_Code': 'E07000029',
#   'Area': 'Copeland',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 54206},
#  'E07000030': {'Area_Code': 'E07000030',
#   'Area': 'Eden',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 41872},
#  'E07000031': {'Area_Code': 'E07000031',
#   'Area': 'South Lakeland',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 81948},
#  'E07000117': {'Area_Code': 'E07000117',
#   'Area': 'Burnley',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 64461},
#  'E07000118': {'Area_Code': 'E07000118',
#   'Area': 'Chorley',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 84159},
#  'E07000119': {'Area_Code': 'E07000119',
#   'Area': 'Fylde',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 61174},
#  'E07000120': {'Area_Code': 'E07000120',
#   'Area': 'Hyndburn',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 62042},
#  'E07000121': {'Area_Code': 'E07000121',
#   'Area': 'Lancaster',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 100567},
#  'E07000122': {'Area_Code': 'E07000122',
#   'Area': 'Pendle',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 64534},
#  'E07000123': {'Area_Code': 'E07000123',
#   'Area': 'Preston',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 94284},
#  'E07000124': {'Area_Code': 'E07000124',
#   'Area': 'Ribble Valley',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 46148},
#  'E07000125': {'Area_Code': 'E07000125',
#   'Area': 'Rossendale',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 52750},
#  'E07000126': {'Area_Code': 'E07000126',
#   'Area': 'South Ribble',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 84573},
#  'E07000127': {'Area_Code': 'E07000127',
#   'Area': 'West Lancashire',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 85834},
#  'E07000128': {'Area_Code': 'E07000128',
#   'Area': 'Wyre',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 84471},
#  'E08000001': {'Area_Code': 'E08000001',
#   'Area': 'Bolton',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 197109},
#  'E08000002': {'Area_Code': 'E08000002',
#   'Area': 'Bury',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 141600},
#  'E08000003': {'Area_Code': 'E08000003',
#   'Area': 'Manchester',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 338064},
#  'E08000004': {'Area_Code': 'E08000004',
#   'Area': 'Oldham',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 158084},
#  'E08000005': {'Area_Code': 'E08000005',
#   'Area': 'Rochdale',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 156621},
#  'E08000006': {'Area_Code': 'E08000006',
#   'Area': 'Salford',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 173668},
#  'E08000007': {'Area_Code': 'E08000007',
#   'Area': 'Stockport',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 221162},
#  'E08000008': {'Area_Code': 'E08000008',
#   'Area': 'Tameside',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 168047},
#  'E08000009': {'Area_Code': 'E08000009',
#   'Area': 'Trafford',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 165294},
#  'E08000010': {'Area_Code': 'E08000010',
#   'Area': 'Wigan',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 235982},
#  'E08000011': {'Area_Code': 'E08000011',
#   'Area': 'Knowsley',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 111647},
#  'E08000012': {'Area_Code': 'E08000012',
#   'Area': 'Liverpool',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 317924},
#  'E08000013': {'Area_Code': 'E08000013',
#   'Area': 'St. Helens',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 136096},
#  'E08000014': {'Area_Code': 'E08000014',
#   'Area': 'Sefton',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 206298},
#  'E08000015': {'Area_Code': 'E08000015',
#   'Area': 'Wirral',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 242568},
#  'N92000002': {'Area_Code': 'N92000002',
#   'Area': 'Northern Ireland',
#   'Region_Code': 'N92000002',
#   'Region': 'Northern Ireland',
#   'Electorate': 1260955},
#  'S12000005': {'Area_Code': 'S12000005',
#   'Area': 'Clackmannanshire',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 37841},
#  'S12000006': {'Area_Code': 'S12000006',
#   'Area': 'Dumfries and Galloway',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 115837},
#  'S12000008': {'Area_Code': 'S12000008',
#   'Area': 'East Ayrshire',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 91977},
#  'S12000010': {'Area_Code': 'S12000010',
#   'Area': 'East Lothian',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 77788},
#  'S12000011': {'Area_Code': 'S12000011',
#   'Area': 'East Renfrewshire',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 69575},
#  'S12000013': {'Area_Code': 'S12000013',
#   'Area': 'Eilean Siar',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 21259},
#  'S12000014': {'Area_Code': 'S12000014',
#   'Area': 'Falkirk',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 117392},
#  'S12000015': {'Area_Code': 'S12000015',
#   'Area': 'Fife',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 272995},
#  'S12000017': {'Area_Code': 'S12000017',
#   'Area': 'Highland',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 175563},
#  'S12000018': {'Area_Code': 'S12000018',
#   'Area': 'Inverclyde',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 58624},
#  'S12000019': {'Area_Code': 'S12000019',
#   'Area': 'Midlothian',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 66758},
#  'S12000020': {'Area_Code': 'S12000020',
#   'Area': 'Moray',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 71370},
#  'S12000021': {'Area_Code': 'S12000021',
#   'Area': 'North Ayrshire',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 104572},
#  'S12000023': {'Area_Code': 'S12000023',
#   'Area': 'Orkney Islands',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 16658},
#  'S12000024': {'Area_Code': 'S12000024',
#   'Area': 'Perth and Kinross',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 110224},
#  'S12000026': {'Area_Code': 'S12000026',
#   'Area': 'Scottish Borders',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 88440},
#  'S12000027': {'Area_Code': 'S12000027',
#   'Area': 'Shetland Islands',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 17375},
#  'S12000028': {'Area_Code': 'S12000028',
#   'Area': 'South Ayrshire',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 88116},
#  'S12000029': {'Area_Code': 'S12000029',
#   'Area': 'South Lanarkshire',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 248949},
#  'S12000030': {'Area_Code': 'S12000030',
#   'Area': 'Stirling',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 66100},
#  'S12000033': {'Area_Code': 'S12000033',
#   'Area': 'Aberdeen City',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 154266},
#  'S12000034': {'Area_Code': 'S12000034',
#   'Area': 'Aberdeenshire',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 196809},
#  'S12000035': {'Area_Code': 'S12000035',
#   'Area': 'Argyll and Bute',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 66642},
#  'S12000036': {'Area_Code': 'S12000036',
#   'Area': 'City of Edinburgh',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 346073},
#  'S12000038': {'Area_Code': 'S12000038',
#   'Area': 'Renfrewshire',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 127294},
#  'S12000039': {'Area_Code': 'S12000039',
#   'Area': 'West Dunbartonshire',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 67595},
#  'S12000040': {'Area_Code': 'S12000040',
#   'Area': 'West Lothian',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 130925},
#  'S12000041': {'Area_Code': 'S12000041',
#   'Area': 'Angus',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 87137},
#  'S12000042': {'Area_Code': 'S12000042',
#   'Area': 'Dundee City',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 105554},
#  'S12000044': {'Area_Code': 'S12000044',
#   'Area': 'North Lanarkshire',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 254567},
#  'S12000045': {'Area_Code': 'S12000045',
#   'Area': 'East Dunbartonshire',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 83031},
#  'S12000046': {'Area_Code': 'S12000046',
#   'Area': 'Glasgow City',
#   'Region_Code': 'S92000003',
#   'Region': 'Scotland',
#   'Electorate': 449806},
#  'E06000035': {'Area_Code': 'E06000035',
#   'Area': 'Medway',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 192524},
#  'E06000036': {'Area_Code': 'E06000036',
#   'Area': 'Bracknell Forest',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 85298},
#  'E06000037': {'Area_Code': 'E06000037',
#   'Area': 'West Berkshire',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 116757},
#  'E06000038': {'Area_Code': 'E06000038',
#   'Area': 'Reading',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 103172},
#  'E06000039': {'Area_Code': 'E06000039',
#   'Area': 'Slough',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 87873},
#  'E06000040': {'Area_Code': 'E06000040',
#   'Area': 'Windsor and Maidenhead',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 102665},
#  'E06000041': {'Area_Code': 'E06000041',
#   'Area': 'Wokingham',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 121891},
#  'E06000042': {'Area_Code': 'E06000042',
#   'Area': 'Milton Keynes',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 177211},
#  'E06000043': {'Area_Code': 'E06000043',
#   'Area': 'Brighton and Hove',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 198293},
#  'E06000044': {'Area_Code': 'E06000044',
#   'Area': 'Portsmouth',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 140517},
#  'E06000045': {'Area_Code': 'E06000045',
#   'Area': 'Southampton',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 158171},
#  'E06000046': {'Area_Code': 'E06000046',
#   'Area': 'Isle of Wight',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 109844},
#  'E07000004': {'Area_Code': 'E07000004',
#   'Area': 'Aylesbury Vale',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 136235},
#  'E07000005': {'Area_Code': 'E07000005',
#   'Area': 'Chiltern',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 70185},
#  'E07000006': {'Area_Code': 'E07000006',
#   'Area': 'South Bucks',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 52194},
#  'E07000007': {'Area_Code': 'E07000007',
#   'Area': 'Wycombe',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 125260},
#  'E07000061': {'Area_Code': 'E07000061',
#   'Area': 'Eastbourne',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 71726},
#  'E07000062': {'Area_Code': 'E07000062',
#   'Area': 'Hastings',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 61957},
#  'E07000063': {'Area_Code': 'E07000063',
#   'Area': 'Lewes',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 76428},
#  'E07000064': {'Area_Code': 'E07000064',
#   'Area': 'Rother',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 72755},
#  'E07000065': {'Area_Code': 'E07000065',
#   'Area': 'Wealden',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 121141},
#  'E07000084': {'Area_Code': 'E07000084',
#   'Area': 'Basingstoke and Deane',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 128677},
#  'E07000085': {'Area_Code': 'E07000085',
#   'Area': 'East Hampshire',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 90588},
#  'E07000086': {'Area_Code': 'E07000086',
#   'Area': 'Eastleigh',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 97280},
#  'E07000087': {'Area_Code': 'E07000087',
#   'Area': 'Fareham',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 90175},
#  'E07000088': {'Area_Code': 'E07000088',
#   'Area': 'Gosport',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 62781},
#  'E07000089': {'Area_Code': 'E07000089',
#   'Area': 'Hart',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 69946},
#  'E07000090': {'Area_Code': 'E07000090',
#   'Area': 'Havant',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 95366},
#  'E07000091': {'Area_Code': 'E07000091',
#   'Area': 'New Forest',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 141061},
#  'E07000092': {'Area_Code': 'E07000092',
#   'Area': 'Rushmoor',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 65790},
#  'E07000093': {'Area_Code': 'E07000093',
#   'Area': 'Test Valley',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 94559},
#  'E07000094': {'Area_Code': 'E07000094',
#   'Area': 'Winchester',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 89595},
#  'E07000105': {'Area_Code': 'E07000105',
#   'Area': 'Ashford',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 90516},
#  'E07000106': {'Area_Code': 'E07000106',
#   'Area': 'Canterbury',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 109399},
#  'E07000107': {'Area_Code': 'E07000107',
#   'Area': 'Dartford',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 73951},
#  'E07000108': {'Area_Code': 'E07000108',
#   'Area': 'Dover',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 85011},
#  'E07000109': {'Area_Code': 'E07000109',
#   'Area': 'Gravesham',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 72808},
#  'E07000110': {'Area_Code': 'E07000110',
#   'Area': 'Maidstone',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 117298},
#  'E07000111': {'Area_Code': 'E07000111',
#   'Area': 'Sevenoaks',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 87253},
#  'E07000112': {'Area_Code': 'E07000112',
#   'Area': 'Shepway',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 80879},
#  'E07000113': {'Area_Code': 'E07000113',
#   'Area': 'Swale',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 102209},
#  'E07000114': {'Area_Code': 'E07000114',
#   'Area': 'Thanet',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 99108},
#  'E07000115': {'Area_Code': 'E07000115',
#   'Area': 'Tonbridge and Malling',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 93019},
#  'E07000116': {'Area_Code': 'E07000116',
#   'Area': 'Tunbridge Wells',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 82181},
#  'E07000177': {'Area_Code': 'E07000177',
#   'Area': 'Cherwell',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 108342},
#  'E07000178': {'Area_Code': 'E07000178',
#   'Area': 'Oxford',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 97331},
#  'E07000179': {'Area_Code': 'E07000179',
#   'Area': 'South Oxfordshire',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 104231},
#  'E07000180': {'Area_Code': 'E07000180',
#   'Area': 'Vale of White Horse',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 94487},
#  'E07000181': {'Area_Code': 'E07000181',
#   'Area': 'West Oxfordshire',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 82441},
#  'E07000207': {'Area_Code': 'E07000207',
#   'Area': 'Elmbridge',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 98613},
#  'E07000208': {'Area_Code': 'E07000208',
#   'Area': 'Epsom and Ewell',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 56382},
#  'E07000209': {'Area_Code': 'E07000209',
#   'Area': 'Guildford',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 102209},
#  'E07000210': {'Area_Code': 'E07000210',
#   'Area': 'Mole Valley',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 66730},
#  'E07000211': {'Area_Code': 'E07000211',
#   'Area': 'Reigate and Banstead',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 103731},
#  'E07000212': {'Area_Code': 'E07000212',
#   'Area': 'Runnymede',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 58272},
#  'E07000213': {'Area_Code': 'E07000213',
#   'Area': 'Spelthorne',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 72674},
#  'E07000214': {'Area_Code': 'E07000214',
#   'Area': 'Surrey Heath',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 65569},
#  'E07000215': {'Area_Code': 'E07000215',
#   'Area': 'Tandridge',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 64044},
#  'E07000216': {'Area_Code': 'E07000216',
#   'Area': 'Waverley',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 92291},
#  'E07000217': {'Area_Code': 'E07000217',
#   'Area': 'Woking',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 71313},
#  'E07000223': {'Area_Code': 'E07000223',
#   'Area': 'Adur',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 48755},
#  'E07000224': {'Area_Code': 'E07000224',
#   'Area': 'Arun',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 117138},
#  'E07000225': {'Area_Code': 'E07000225',
#   'Area': 'Chichester',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 91659},
#  'E07000226': {'Area_Code': 'E07000226',
#   'Area': 'Crawley',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 73575},
#  'E07000227': {'Area_Code': 'E07000227',
#   'Area': 'Horsham',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 104270},
#  'E07000228': {'Area_Code': 'E07000228',
#   'Area': 'Mid Sussex',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 108416},
#  'E07000229': {'Area_Code': 'E07000229',
#   'Area': 'Worthing',
#   'Region_Code': 'E12000008',
#   'Region': 'South East',
#   'Electorate': 81384},
#  'E06000022': {'Area_Code': 'E06000022',
#   'Area': 'Bath and North East Somerset',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 136522},
#  'E06000023': {'Area_Code': 'E06000023',
#   'Area': 'Bristol, City of',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 312465},
#  'E06000024': {'Area_Code': 'E06000024',
#   'Area': 'North Somerset',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 160860},
#  'E06000025': {'Area_Code': 'E06000025',
#   'Area': 'South Gloucestershire',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 207793},
#  'E06000026': {'Area_Code': 'E06000026',
#   'Area': 'Plymouth',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 186989},
#  'E06000027': {'Area_Code': 'E06000027',
#   'Area': 'Torbay',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 102961},
#  'E06000028': {'Area_Code': 'E06000028',
#   'Area': 'Bournemouth',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 132752},
#  'E06000029': {'Area_Code': 'E06000029',
#   'Area': 'Poole',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 113421},
#  'E06000030': {'Area_Code': 'E06000030',
#   'Area': 'Swindon',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 148960},
#  'E06000052': {'Area_Code': 'E06000052',
#   'Area': 'Cornwall',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 419755},
#  'E06000053': {'Area_Code': 'E06000053',
#   'Area': 'Isles of Scilly',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 1799},
#  'E06000054': {'Area_Code': 'E06000054',
#   'Area': 'Wiltshire',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 366555},
#  'E07000040': {'Area_Code': 'E07000040',
#   'Area': 'East Devon',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 112527},
#  'E07000041': {'Area_Code': 'E07000041',
#   'Area': 'Exeter',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 86417},
#  'E07000042': {'Area_Code': 'E07000042',
#   'Area': 'Mid Devon',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 60532},
#  'E07000043': {'Area_Code': 'E07000043',
#   'Area': 'North Devon',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 75548},
#  'E07000044': {'Area_Code': 'E07000044',
#   'Area': 'South Hams',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 69121},
#  'E07000045': {'Area_Code': 'E07000045',
#   'Area': 'Teignbridge',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 103740},
#  'E07000046': {'Area_Code': 'E07000046',
#   'Area': 'Torridge',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 52881},
#  'E07000047': {'Area_Code': 'E07000047',
#   'Area': 'West Devon',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 43823},
#  'E07000048': {'Area_Code': 'E07000048',
#   'Area': 'Christchurch',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 39176},
#  'E07000049': {'Area_Code': 'E07000049',
#   'Area': 'East Dorset',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 71966},
#  'E07000050': {'Area_Code': 'E07000050',
#   'Area': 'North Dorset',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 52980},
#  'E07000051': {'Area_Code': 'E07000051',
#   'Area': 'Purbeck',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 36418},
#  'E07000052': {'Area_Code': 'E07000052',
#   'Area': 'West Dorset',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 82071},
#  'E07000053': {'Area_Code': 'E07000053',
#   'Area': 'Weymouth and Portland',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 50442},
#  'E07000078': {'Area_Code': 'E07000078',
#   'Area': 'Cheltenham',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 87060},
#  'E07000079': {'Area_Code': 'E07000079',
#   'Area': 'Cotswold',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 68734},
#  'E07000080': {'Area_Code': 'E07000080',
#   'Area': 'Forest of Dean',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 66705},
#  'E07000081': {'Area_Code': 'E07000081',
#   'Area': 'Gloucester',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 89661},
#  'E07000082': {'Area_Code': 'E07000082',
#   'Area': 'Stroud',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 92631},
#  'E07000083': {'Area_Code': 'E07000083',
#   'Area': 'Tewkesbury',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 67831},
#  'E07000187': {'Area_Code': 'E07000187',
#   'Area': 'Mendip',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 85068},
#  'E07000188': {'Area_Code': 'E07000188',
#   'Area': 'Sedgemoor',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 89714},
#  'E07000189': {'Area_Code': 'E07000189',
#   'Area': 'South Somerset',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 126495},
#  'E07000190': {'Area_Code': 'E07000190',
#   'Area': 'Taunton Deane',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 84164},
#  'E07000191': {'Area_Code': 'E07000191',
#   'Area': 'West Somerset',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 27478},
#  'GI': {'Area_Code': 'GI',
#   'Area': 'Gibraltar',
#   'Region_Code': 'E12000009',
#   'Region': 'South West',
#   'Electorate': 24119},
#  'W06000001': {'Area_Code': 'W06000001',
#   'Area': 'Isle of Anglesey',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 51445},
#  'W06000002': {'Area_Code': 'W06000002',
#   'Area': 'Gwynedd',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 84575},
#  'W06000003': {'Area_Code': 'W06000003',
#   'Area': 'Conwy',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 91368},
#  'W06000004': {'Area_Code': 'W06000004',
#   'Area': 'Denbighshire',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 75362},
#  'W06000005': {'Area_Code': 'W06000005',
#   'Area': 'Flintshire',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 115964},
#  'W06000006': {'Area_Code': 'W06000006',
#   'Area': 'Wrexham',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 98384},
#  'W06000008': {'Area_Code': 'W06000008',
#   'Area': 'Ceredigion',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 53400},
#  'W06000009': {'Area_Code': 'W06000009',
#   'Area': 'Pembrokeshire',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 92155},
#  'W06000010': {'Area_Code': 'W06000010',
#   'Area': 'Carmarthenshire',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 139227},
#  'W06000011': {'Area_Code': 'W06000011',
#   'Area': 'Swansea',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 172941},
#  'W06000012': {'Area_Code': 'W06000012',
#   'Area': 'Neath Port Talbot',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 105766},
#  'W06000013': {'Area_Code': 'W06000013',
#   'Area': 'Bridgend',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 104492},
#  'W06000014': {'Area_Code': 'W06000014',
#   'Area': 'Vale of Glamorgan',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 95011},
#  'W06000015': {'Area_Code': 'W06000015',
#   'Area': 'Cardiff',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 243689},
#  'W06000016': {'Area_Code': 'W06000016',
#   'Area': 'Rhondda Cynon Taf',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 172890},
#  'W06000018': {'Area_Code': 'W06000018',
#   'Area': 'Caerphilly',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 130801},
#  'W06000019': {'Area_Code': 'W06000019',
#   'Area': 'Blaenau Gwent',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 51136},
#  'W06000020': {'Area_Code': 'W06000020',
#   'Area': 'Torfaen',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 68957},
#  'W06000021': {'Area_Code': 'W06000021',
#   'Area': 'Monmouthshire',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 71607},
#  'W06000022': {'Area_Code': 'W06000022',
#   'Area': 'Newport',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 104977},
#  'W06000023': {'Area_Code': 'W06000023',
#   'Area': 'Powys',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 103270},
#  'W06000024': {'Area_Code': 'W06000024',
#   'Area': 'Merthyr Tydfil',
#   'Region_Code': 'W92000004',
#   'Region': 'Wales',
#   'Electorate': 42855},
#  'E06000019': {'Area_Code': 'E06000019',
#   'Area': 'Herefordshire, County of',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 138247},
#  'E06000020': {'Area_Code': 'E06000020',
#   'Area': 'Telford and Wrekin',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 124338},
#  'E06000021': {'Area_Code': 'E06000021',
#   'Area': 'Stoke-on-Trent',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 179010},
#  'E06000051': {'Area_Code': 'E06000051',
#   'Area': 'Shropshire',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 236788},
#  'E07000192': {'Area_Code': 'E07000192',
#   'Area': 'Cannock Chase',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 75010},
#  'E07000193': {'Area_Code': 'E07000193',
#   'Area': 'East Staffordshire',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 83558},
#  'E07000194': {'Area_Code': 'E07000194',
#   'Area': 'Lichfield',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 80369},
#  'E07000195': {'Area_Code': 'E07000195',
#   'Area': 'Newcastle-under-Lyme',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 92816},
#  'E07000196': {'Area_Code': 'E07000196',
#   'Area': 'South Staffordshire',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 85777},
#  'E07000197': {'Area_Code': 'E07000197',
#   'Area': 'Stafford',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 99612},
#  'E07000198': {'Area_Code': 'E07000198',
#   'Area': 'Staffordshire Moorlands',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 79347},
#  'E07000199': {'Area_Code': 'E07000199',
#   'Area': 'Tamworth',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 56825},
#  'E07000218': {'Area_Code': 'E07000218',
#   'Area': 'North Warwickshire',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 49790},
#  'E07000219': {'Area_Code': 'E07000219',
#   'Area': 'Nuneaton and Bedworth',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 93978},
#  'E07000220': {'Area_Code': 'E07000220',
#   'Area': 'Rugby',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 74137},
#  'E07000221': {'Area_Code': 'E07000221',
#   'Area': 'Stratford-on-Avon',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 98014},
#  'E07000222': {'Area_Code': 'E07000222',
#   'Area': 'Warwick',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 103099},
#  'E07000234': {'Area_Code': 'E07000234',
#   'Area': 'Bromsgrove',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 74170},
#  'E07000235': {'Area_Code': 'E07000235',
#   'Area': 'Malvern Hills',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 60217},
#  'E07000236': {'Area_Code': 'E07000236',
#   'Area': 'Redditch',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 61038},
#  'E07000237': {'Area_Code': 'E07000237',
#   'Area': 'Worcester',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 73516},
#  'E07000238': {'Area_Code': 'E07000238',
#   'Area': 'Wychavon',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 94497},
#  'E07000239': {'Area_Code': 'E07000239',
#   'Area': 'Wyre Forest',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 77878},
#  'E08000025': {'Area_Code': 'E08000025',
#   'Area': 'Birmingham',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 707293},
#  'E08000026': {'Area_Code': 'E08000026',
#   'Area': 'Coventry',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 221389},
#  'E08000027': {'Area_Code': 'E08000027',
#   'Area': 'Dudley',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 244516},
#  'E08000028': {'Area_Code': 'E08000028',
#   'Area': 'Sandwell',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 221429},
#  'E08000029': {'Area_Code': 'E08000029',
#   'Area': 'Solihull',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 160425},
#  'E08000030': {'Area_Code': 'E08000030',
#   'Area': 'Walsall',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 194729},
#  'E08000031': {'Area_Code': 'E08000031',
#   'Area': 'Wolverhampton',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 174760},
#  'E06000010': {'Area_Code': 'E06000010',
#   'Area': 'Kingston upon Hull, City of',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 180230},
#  'E06000011': {'Area_Code': 'E06000011',
#   'Area': 'East Riding of Yorkshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 266047},
#  'E06000012': {'Area_Code': 'E06000012',
#   'Area': 'North East Lincolnshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 116302},
#  'E06000013': {'Area_Code': 'E06000013',
#   'Area': 'North Lincolnshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 123611},
#  'E06000014': {'Area_Code': 'E06000014',
#   'Area': 'York',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 155157},
#  'E07000163': {'Area_Code': 'E07000163',
#   'Area': 'Craven',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 44320},
#  'E07000164': {'Area_Code': 'E07000164',
#   'Area': 'Hambleton',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 70133},
#  'E07000165': {'Area_Code': 'E07000165',
#   'Area': 'Harrogate',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 119987},
#  'E07000166': {'Area_Code': 'E07000166',
#   'Area': 'Richmondshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 36794},
#  'E07000167': {'Area_Code': 'E07000167',
#   'Area': 'Ryedale',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 41529},
#  'E07000168': {'Area_Code': 'E07000168',
#   'Area': 'Scarborough',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 82900},
#  'E07000169': {'Area_Code': 'E07000169',
#   'Area': 'Selby',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 65278},
#  'E08000016': {'Area_Code': 'E08000016',
#   'Area': 'Barnsley',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 175809},
#  'E08000017': {'Area_Code': 'E08000017',
#   'Area': 'Doncaster',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 217432},
#  'E08000018': {'Area_Code': 'E08000018',
#   'Area': 'Rotherham',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 197623},
#  'E08000019': {'Area_Code': 'E08000019',
#   'Area': 'Sheffield',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 396406},
#  'E08000032': {'Area_Code': 'E08000032',
#   'Area': 'Bradford',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 342817},
#  'E08000033': {'Area_Code': 'E08000033',
#   'Area': 'Calderdale',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 149195},
#  'E08000034': {'Area_Code': 'E08000034',
#   'Area': 'Kirklees',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 307081},
#  'E08000035': {'Area_Code': 'E08000035',
#   'Area': 'Leeds',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 543033},
#  'E08000036': {'Area_Code': 'E08000036',
#   'Area': 'Wakefield',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 246096}}

# %%
uk_results_dict = dict_convert(uk_results)
uk_rejected_dict = dict_convert(uk_rejected)

# %%
merged_dict = {}

for key in uk_demo_dict.keys():
    merged_dict.update({
        key: {**uk_demo_dict[key], **uk_results_dict[key], **uk_rejected_dict[key]}
    })
merged_dict
# Out:
# {'E06000031': {'Area_Code': 'E06000031',
#   'Area': 'Peterborough',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 120892,
#   'Votes_Cast': 87469,
#   'Valid_Votes': 87392,
#   'Remain': 34176,
#   'Leave': 53216,
#   'Rejected_Ballots': 77,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 32,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 38},
#  'E06000032': {'Area_Code': 'E06000032',
#   'Area': 'Luton',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 127612,
#   'Votes_Cast': 84616,
#   'Valid_Votes': 84481,
#   'Remain': 36708,
#   'Leave': 47773,
#   'Rejected_Ballots': 135,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 85,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 50},
#  'E06000033': {'Area_Code': 'E06000033',
#   'Area': 'Southend-on-Sea',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 128856,
#   'Votes_Cast': 93939,
#   'Valid_Votes': 93870,
#   'Remain': 39348,
#   'Leave': 54522,
#   'Rejected_Ballots': 69,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 21,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 48},
#  'E06000034': {'Area_Code': 'E06000034',
#   'Area': 'Thurrock',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 109897,
#   'Votes_Cast': 79950,
#   'Valid_Votes': 79916,
#   'Remain': 22151,
#   'Leave': 57765,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 8,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 23},
#  'E06000055': {'Area_Code': 'E06000055',
#   'Area': 'Bedford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 119530,
#   'Votes_Cast': 86135,
#   'Valid_Votes': 86066,
#   'Remain': 41497,
#   'Leave': 44569,
#   'Rejected_Ballots': 69,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 26,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 42},
#  'E06000056': {'Area_Code': 'E06000056',
#   'Area': 'Central Bedfordshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 204004,
#   'Votes_Cast': 158894,
#   'Valid_Votes': 158804,
#   'Remain': 69670,
#   'Leave': 89134,
#   'Rejected_Ballots': 90,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 34,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 55},
#  'E07000008': {'Area_Code': 'E07000008',
#   'Area': 'Cambridge',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 80108,
#   'Votes_Cast': 57852,
#   'Valid_Votes': 57799,
#   'Remain': 42682,
#   'Leave': 15117,
#   'Rejected_Ballots': 53,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 40},
#  'E07000009': {'Area_Code': 'E07000009',
#   'Area': 'East Cambridgeshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 62435,
#   'Votes_Cast': 48124,
#   'Valid_Votes': 48086,
#   'Remain': 23599,
#   'Leave': 24487,
#   'Rejected_Ballots': 38,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 18,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 20},
#  'E07000010': {'Area_Code': 'E07000010',
#   'Area': 'Fenland',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 71447,
#   'Votes_Cast': 52649,
#   'Valid_Votes': 52626,
#   'Remain': 15055,
#   'Leave': 37571,
#   'Rejected_Ballots': 23,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 12},
#  'E07000011': {'Area_Code': 'E07000011',
#   'Area': 'Huntingdonshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 128486,
#   'Votes_Cast': 99990,
#   'Valid_Votes': 99927,
#   'Remain': 45729,
#   'Leave': 54198,
#   'Rejected_Ballots': 63,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 31,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 32},
#  'E07000012': {'Area_Code': 'E07000012',
#   'Area': 'South Cambridgeshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 114830,
#   'Votes_Cast': 93250,
#   'Valid_Votes': 93189,
#   'Remain': 56128,
#   'Leave': 37061,
#   'Rejected_Ballots': 61,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 24,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 37},
#  'E07000066': {'Area_Code': 'E07000066',
#   'Area': 'Basildon',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 132771,
#   'Votes_Cast': 98062,
#   'Valid_Votes': 97999,
#   'Remain': 30748,
#   'Leave': 67251,
#   'Rejected_Ballots': 63,
#   'No_official_mark': 3,
#   'Voting_for_both_answers': 26,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 32},
#  'E07000067': {'Area_Code': 'E07000067',
#   'Area': 'Braintree',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 112562,
#   'Votes_Cast': 86303,
#   'Valid_Votes': 86236,
#   'Remain': 33523,
#   'Leave': 52713,
#   'Rejected_Ballots': 67,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 23,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 44},
#  'E07000068': {'Area_Code': 'E07000068',
#   'Area': 'Brentwood',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 58777,
#   'Votes_Cast': 46725,
#   'Valid_Votes': 46704,
#   'Remain': 19077,
#   'Leave': 27627,
#   'Rejected_Ballots': 21,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 3,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 17},
#  'E07000069': {'Area_Code': 'E07000069',
#   'Area': 'Castle Point',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 68860,
#   'Votes_Cast': 51909,
#   'Valid_Votes': 51845,
#   'Remain': 14154,
#   'Leave': 37691,
#   'Rejected_Ballots': 64,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 48},
#  'E07000070': {'Area_Code': 'E07000070',
#   'Area': 'Chelmsford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 129971,
#   'Votes_Cast': 100852,
#   'Valid_Votes': 100794,
#   'Remain': 47545,
#   'Leave': 53249,
#   'Rejected_Ballots': 58,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 23,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 33},
#  'E07000071': {'Area_Code': 'E07000071',
#   'Area': 'Colchester',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 127520,
#   'Votes_Cast': 95782,
#   'Valid_Votes': 95719,
#   'Remain': 44414,
#   'Leave': 51305,
#   'Rejected_Ballots': 63,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 39},
#  'E07000072': {'Area_Code': 'E07000072',
#   'Area': 'Epping Forest',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 100016,
#   'Votes_Cast': 76900,
#   'Valid_Votes': 76852,
#   'Remain': 28676,
#   'Leave': 48176,
#   'Rejected_Ballots': 48,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 21,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 25},
#  'E07000073': {'Area_Code': 'E07000073',
#   'Area': 'Harlow',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 59124,
#   'Votes_Cast': 43489,
#   'Valid_Votes': 43469,
#   'Remain': 13867,
#   'Leave': 29602,
#   'Rejected_Ballots': 20,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 1,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 19},
#  'E07000074': {'Area_Code': 'E07000074',
#   'Area': 'Maldon',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 49073,
#   'Votes_Cast': 38850,
#   'Valid_Votes': 38831,
#   'Remain': 14529,
#   'Leave': 24302,
#   'Rejected_Ballots': 19,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 8},
#  'E07000075': {'Area_Code': 'E07000075',
#   'Area': 'Rochford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 66589,
#   'Votes_Cast': 52479,
#   'Valid_Votes': 52447,
#   'Remain': 17510,
#   'Leave': 34937,
#   'Rejected_Ballots': 32,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 18},
#  'E07000076': {'Area_Code': 'E07000076',
#   'Area': 'Tendring',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 111167,
#   'Votes_Cast': 82703,
#   'Valid_Votes': 82657,
#   'Remain': 25210,
#   'Leave': 57447,
#   'Rejected_Ballots': 46,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 27},
#  'E07000077': {'Area_Code': 'E07000077',
#   'Area': 'Uttlesford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 64735,
#   'Votes_Cast': 51972,
#   'Valid_Votes': 51943,
#   'Remain': 25619,
#   'Leave': 26324,
#   'Rejected_Ballots': 29,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 5,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 24},
#  'E07000095': {'Area_Code': 'E07000095',
#   'Area': 'Broxbourne',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 68997,
#   'Votes_Cast': 50907,
#   'Valid_Votes': 50872,
#   'Remain': 17166,
#   'Leave': 33706,
#   'Rejected_Ballots': 35,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 21},
#  'E07000096': {'Area_Code': 'E07000096',
#   'Area': 'Dacorum',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 108965,
#   'Votes_Cast': 86307,
#   'Valid_Votes': 86244,
#   'Remain': 42542,
#   'Leave': 43702,
#   'Rejected_Ballots': 63,
#   'No_official_mark': 4,
#   'Voting_for_both_answers': 24,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 35},
#  'E07000098': {'Area_Code': 'E07000098',
#   'Area': 'Hertsmere',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 73295,
#   'Votes_Cast': 56159,
#   'Valid_Votes': 56125,
#   'Remain': 27593,
#   'Leave': 28532,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 12,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 22},
#  'E07000099': {'Area_Code': 'E07000099',
#   'Area': 'North Hertfordshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 99316,
#   'Votes_Cast': 77737,
#   'Valid_Votes': 77672,
#   'Remain': 42234,
#   'Leave': 35438,
#   'Rejected_Ballots': 65,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 29,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 35},
#  'E07000102': {'Area_Code': 'E07000102',
#   'Area': 'Three Rivers',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 67380,
#   'Votes_Cast': 52896,
#   'Valid_Votes': 52848,
#   'Remain': 25751,
#   'Leave': 27097,
#   'Rejected_Ballots': 48,
#   'No_official_mark': 4,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 25},
#  'E07000103': {'Area_Code': 'E07000103',
#   'Area': 'Watford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 65060,
#   'Votes_Cast': 46635,
#   'Valid_Votes': 46586,
#   'Remain': 23167,
#   'Leave': 23419,
#   'Rejected_Ballots': 49,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 23,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 22},
#  'E07000143': {'Area_Code': 'E07000143',
#   'Area': 'Breckland',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 98989,
#   'Votes_Cast': 73593,
#   'Valid_Votes': 73548,
#   'Remain': 26313,
#   'Leave': 47235,
#   'Rejected_Ballots': 45,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 35},
#  'E07000144': {'Area_Code': 'E07000144',
#   'Area': 'Broadland',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 99254,
#   'Votes_Cast': 77781,
#   'Valid_Votes': 77737,
#   'Remain': 35469,
#   'Leave': 42268,
#   'Rejected_Ballots': 44,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 0,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 44},
#  'E07000145': {'Area_Code': 'E07000145',
#   'Area': 'Great Yarmouth',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 72634,
#   'Votes_Cast': 50158,
#   'Valid_Votes': 50128,
#   'Remain': 14284,
#   'Leave': 35844,
#   'Rejected_Ballots': 30,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 9},
#  'E07000146': {'Area_Code': 'E07000146',
#   'Area': "King's Lynn and West Norfolk",
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 113884,
#   'Votes_Cast': 85128,
#   'Valid_Votes': 85080,
#   'Remain': 28587,
#   'Leave': 56493,
#   'Rejected_Ballots': 48,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 32},
#  'E07000147': {'Area_Code': 'E07000147',
#   'Area': 'North Norfolk',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 83065,
#   'Votes_Cast': 63829,
#   'Valid_Votes': 63790,
#   'Remain': 26214,
#   'Leave': 37576,
#   'Rejected_Ballots': 39,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 4,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 33},
#  'E07000148': {'Area_Code': 'E07000148',
#   'Area': 'Norwich',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 96091,
#   'Votes_Cast': 66422,
#   'Valid_Votes': 66366,
#   'Remain': 37326,
#   'Leave': 29040,
#   'Rejected_Ballots': 56,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 38},
#  'E07000149': {'Area_Code': 'E07000149',
#   'Area': 'South Norfolk',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 102395,
#   'Votes_Cast': 80418,
#   'Valid_Votes': 80358,
#   'Remain': 38817,
#   'Leave': 41541,
#   'Rejected_Ballots': 60,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 24,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 35},
#  'E07000200': {'Area_Code': 'E07000200',
#   'Area': 'Babergh',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 70628,
#   'Votes_Cast': 55272,
#   'Valid_Votes': 55242,
#   'Remain': 25309,
#   'Leave': 29933,
#   'Rejected_Ballots': 30,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 17},
#  'E07000201': {'Area_Code': 'E07000201',
#   'Area': 'Forest Heath',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 38527,
#   'Votes_Cast': 27977,
#   'Valid_Votes': 27951,
#   'Remain': 9791,
#   'Leave': 18160,
#   'Rejected_Ballots': 26,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 4,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 18},
#  'E07000202': {'Area_Code': 'E07000202',
#   'Area': 'Ipswich',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 91574,
#   'Votes_Cast': 66400,
#   'Valid_Votes': 66353,
#   'Remain': 27698,
#   'Leave': 38655,
#   'Rejected_Ballots': 47,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 1,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 39},
#  'E07000203': {'Area_Code': 'E07000203',
#   'Area': 'Mid Suffolk',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 78325,
#   'Votes_Cast': 61222,
#   'Valid_Votes': 61185,
#   'Remain': 27391,
#   'Leave': 33794,
#   'Rejected_Ballots': 37,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 4,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 33},
#  'E07000204': {'Area_Code': 'E07000204',
#   'Area': 'St Edmundsbury',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 81148,
#   'Votes_Cast': 62255,
#   'Valid_Votes': 62210,
#   'Remain': 26986,
#   'Leave': 35224,
#   'Rejected_Ballots': 45,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 30},
#  'E07000205': {'Area_Code': 'E07000205',
#   'Area': 'Suffolk Coastal',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 98195,
#   'Votes_Cast': 79226,
#   'Valid_Votes': 79184,
#   'Remain': 37218,
#   'Leave': 41966,
#   'Rejected_Ballots': 42,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 24},
#  'E07000206': {'Area_Code': 'E07000206',
#   'Area': 'Waveney',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 90391,
#   'Votes_Cast': 65687,
#   'Valid_Votes': 65646,
#   'Remain': 24356,
#   'Leave': 41290,
#   'Rejected_Ballots': 41,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 11,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 30},
#  'E07000240': {'Area_Code': 'E07000240',
#   'Area': 'St Albans',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 104859,
#   'Votes_Cast': 86524,
#   'Valid_Votes': 86445,
#   'Remain': 54208,
#   'Leave': 32237,
#   'Rejected_Ballots': 79,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 31,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 48},
#  'E07000241': {'Area_Code': 'E07000241',
#   'Area': 'Welwyn Hatfield',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 78146,
#   'Votes_Cast': 58641,
#   'Valid_Votes': 58610,
#   'Remain': 27550,
#   'Leave': 31060,
#   'Rejected_Ballots': 31,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 21},
#  'E07000242': {'Area_Code': 'E07000242',
#   'Area': 'East Hertfordshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 106260,
#   'Votes_Cast': 85433,
#   'Valid_Votes': 85366,
#   'Remain': 42372,
#   'Leave': 42994,
#   'Rejected_Ballots': 67,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 26,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 36},
#  'E07000243': {'Area_Code': 'E07000243',
#   'Area': 'Stevenage',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 62156,
#   'Votes_Cast': 45811,
#   'Valid_Votes': 45785,
#   'Remain': 18659,
#   'Leave': 27126,
#   'Rejected_Ballots': 26,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 12,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 12},
#  'E06000015': {'Area_Code': 'E06000015',
#   'Area': 'Derby',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 171246,
#   'Votes_Cast': 120772,
#   'Valid_Votes': 120655,
#   'Remain': 51612,
#   'Leave': 69043,
#   'Rejected_Ballots': 117,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 41,
#   'Writing_or_mark': 10,
#   'Unmarked_or_void': 66},
#  'E06000016': {'Area_Code': 'E06000016',
#   'Area': 'Leicester',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 213819,
#   'Votes_Cast': 139307,
#   'Valid_Votes': 138972,
#   'Remain': 70980,
#   'Leave': 67992,
#   'Rejected_Ballots': 335,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 154,
#   'Writing_or_mark': 8,
#   'Unmarked_or_void': 173},
#  'E06000017': {'Area_Code': 'E06000017',
#   'Area': 'Rutland',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 29390,
#   'Votes_Cast': 22984,
#   'Valid_Votes': 22966,
#   'Remain': 11353,
#   'Leave': 11613,
#   'Rejected_Ballots': 18,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 7},
#  'E06000018': {'Area_Code': 'E06000018',
#   'Area': 'Nottingham',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 195394,
#   'Votes_Cast': 120791,
#   'Valid_Votes': 120661,
#   'Remain': 59318,
#   'Leave': 61343,
#   'Rejected_Ballots': 130,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 47,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 79},
#  'E07000032': {'Area_Code': 'E07000032',
#   'Area': 'Amber Valley',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 96760,
#   'Votes_Cast': 73864,
#   'Valid_Votes': 73820,
#   'Remain': 29319,
#   'Leave': 44501,
#   'Rejected_Ballots': 44,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 7,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 36},
#  'E07000033': {'Area_Code': 'E07000033',
#   'Area': 'Bolsover',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 58063,
#   'Votes_Cast': 41999,
#   'Valid_Votes': 41972,
#   'Remain': 12242,
#   'Leave': 29730,
#   'Rejected_Ballots': 27,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 5,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 21},
#  'E07000034': {'Area_Code': 'E07000034',
#   'Area': 'Chesterfield',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 79905,
#   'Votes_Cast': 57470,
#   'Valid_Votes': 57424,
#   'Remain': 22946,
#   'Leave': 34478,
#   'Rejected_Ballots': 46,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 16,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 28},
#  'E07000035': {'Area_Code': 'E07000035',
#   'Area': 'Derbyshire Dales',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 57075,
#   'Votes_Cast': 46756,
#   'Valid_Votes': 46728,
#   'Remain': 22633,
#   'Leave': 24095,
#   'Rejected_Ballots': 28,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 5,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 23},
#  'E07000036': {'Area_Code': 'E07000036',
#   'Area': 'Erewash',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 87596,
#   'Votes_Cast': 66566,
#   'Valid_Votes': 66530,
#   'Remain': 25791,
#   'Leave': 40739,
#   'Rejected_Ballots': 36,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 20},
#  'E07000037': {'Area_Code': 'E07000037',
#   'Area': 'High Peak',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 72487,
#   'Votes_Cast': 54864,
#   'Valid_Votes': 54833,
#   'Remain': 27116,
#   'Leave': 27717,
#   'Rejected_Ballots': 31,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 18},
#  'E07000038': {'Area_Code': 'E07000038',
#   'Area': 'North East Derbyshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 78855,
#   'Votes_Cast': 59341,
#   'Valid_Votes': 59310,
#   'Remain': 22075,
#   'Leave': 37235,
#   'Rejected_Ballots': 31,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 16},
#  'E07000039': {'Area_Code': 'E07000039',
#   'Area': 'South Derbyshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73856,
#   'Votes_Cast': 56718,
#   'Valid_Votes': 56695,
#   'Remain': 22479,
#   'Leave': 34216,
#   'Rejected_Ballots': 23,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 5,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 18},
#  'E07000129': {'Area_Code': 'E07000129',
#   'Area': 'Blaby',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73832,
#   'Votes_Cast': 56512,
#   'Valid_Votes': 56471,
#   'Remain': 22888,
#   'Leave': 33583,
#   'Rejected_Ballots': 41,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 26},
#  'E07000130': {'Area_Code': 'E07000130',
#   'Area': 'Charnwood',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 133780,
#   'Votes_Cast': 94257,
#   'Valid_Votes': 94172,
#   'Remain': 43500,
#   'Leave': 50672,
#   'Rejected_Ballots': 85,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 47,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 38},
#  'E07000131': {'Area_Code': 'E07000131',
#   'Area': 'Harborough',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 67420,
#   'Votes_Cast': 54910,
#   'Valid_Votes': 54878,
#   'Remain': 27028,
#   'Leave': 27850,
#   'Rejected_Ballots': 32,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 1,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 29},
#  'E07000132': {'Area_Code': 'E07000132',
#   'Area': 'Hinckley and Bosworth',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 85305,
#   'Votes_Cast': 65516,
#   'Valid_Votes': 65470,
#   'Remain': 25969,
#   'Leave': 39501,
#   'Rejected_Ballots': 46,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 40},
#  'E07000133': {'Area_Code': 'E07000133',
#   'Area': 'Melton',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 37273,
#   'Votes_Cast': 30327,
#   'Valid_Votes': 30305,
#   'Remain': 12695,
#   'Leave': 17610,
#   'Rejected_Ballots': 22,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 12},
#  'E07000134': {'Area_Code': 'E07000134',
#   'Area': 'North West Leicestershire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73944,
#   'Votes_Cast': 57638,
#   'Valid_Votes': 57611,
#   'Remain': 22642,
#   'Leave': 34969,
#   'Rejected_Ballots': 27,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 21},
#  'E07000135': {'Area_Code': 'E07000135',
#   'Area': 'Oadby and Wigston',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 42684,
#   'Votes_Cast': 31489,
#   'Valid_Votes': 31465,
#   'Remain': 14292,
#   'Leave': 17173,
#   'Rejected_Ballots': 24,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 15},
#  'E07000136': {'Area_Code': 'E07000136',
#   'Area': 'Boston',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 39363,
#   'Votes_Cast': 30416,
#   'Valid_Votes': 30404,
#   'Remain': 7430,
#   'Leave': 22974,
#   'Rejected_Ballots': 12,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 1,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 10},
#  'E07000137': {'Area_Code': 'E07000137',
#   'Area': 'East Lindsey',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 107009,
#   'Votes_Cast': 80178,
#   'Valid_Votes': 80128,
#   'Remain': 23515,
#   'Leave': 56613,
#   'Rejected_Ballots': 50,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 21,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 27},
#  'E07000138': {'Area_Code': 'E07000138',
#   'Area': 'Lincoln',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 63351,
#   'Votes_Cast': 43928,
#   'Valid_Votes': 43894,
#   'Remain': 18902,
#   'Leave': 24992,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 17},
#  'E07000139': {'Area_Code': 'E07000139',
#   'Area': 'North Kesteven',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 86468,
#   'Votes_Cast': 67791,
#   'Valid_Votes': 67753,
#   'Remain': 25570,
#   'Leave': 42183,
#   'Rejected_Ballots': 38,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 24},
#  'E07000140': {'Area_Code': 'E07000140',
#   'Area': 'South Holland',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 65701,
#   'Votes_Cast': 49518,
#   'Valid_Votes': 49497,
#   'Remain': 13074,
#   'Leave': 36423,
#   'Rejected_Ballots': 21,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 8,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 13},
#  'E07000141': {'Area_Code': 'E07000141',
#   'Area': 'South Kesteven',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 105457,
#   'Votes_Cast': 82523,
#   'Valid_Votes': 82471,
#   'Remain': 33047,
#   'Leave': 49424,
#   'Rejected_Ballots': 52,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 34},
#  'E07000142': {'Area_Code': 'E07000142',
#   'Area': 'West Lindsey',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73499,
#   'Votes_Cast': 54781,
#   'Valid_Votes': 54753,
#   'Remain': 20906,
#   'Leave': 33847,
#   'Rejected_Ballots': 28,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 7,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 17},
#  'E07000150': {'Area_Code': 'E07000150',
#   'Area': 'Corby',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 43313,
#   'Votes_Cast': 32097,
#   'Valid_Votes': 32081,
#   'Remain': 11470,
#   'Leave': 20611,
#   'Rejected_Ballots': 16,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 4,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 12},
#  'E07000151': {'Area_Code': 'E07000151',
#   'Area': 'Daventry',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 61004,
#   'Votes_Cast': 49420,
#   'Valid_Votes': 49381,
#   'Remain': 20443,
#   'Leave': 28938,
#   'Rejected_Ballots': 39,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 27},
#  'E07000152': {'Area_Code': 'E07000152',
#   'Area': 'East Northamptonshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 68334,
#   'Votes_Cast': 52607,
#   'Valid_Votes': 52574,
#   'Remain': 21680,
#   'Leave': 30894,
#   'Rejected_Ballots': 33,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 25},
#  'E07000153': {'Area_Code': 'E07000153',
#   'Area': 'Kettering',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 70570,
#   'Votes_Cast': 53940,
#   'Valid_Votes': 53907,
#   'Remain': 21030,
#   'Leave': 32877,
#   'Rejected_Ballots': 33,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 12,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 20},
#  'E07000154': {'Area_Code': 'E07000154',
#   'Area': 'Northampton',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 144948,
#   'Votes_Cast': 105354,
#   'Valid_Votes': 105259,
#   'Remain': 43805,
#   'Leave': 61454,
#   'Rejected_Ballots': 95,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 35,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 53},
#  'E07000155': {'Area_Code': 'E07000155',
#   'Area': 'South Northamptonshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 71309,
#   'Votes_Cast': 56664,
#   'Valid_Votes': 56624,
#   'Remain': 25853,
#   'Leave': 30771,
#   'Rejected_Ballots': 40,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 18,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 21},
#  'E07000156': {'Area_Code': 'E07000156',
#   'Area': 'Wellingborough',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 54572,
#   'Votes_Cast': 41178,
#   'Valid_Votes': 41141,
#   'Remain': 15462,
#   'Leave': 25679,
#   'Rejected_Ballots': 37,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 18,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 17},
#  'E07000170': {'Area_Code': 'E07000170',
#   'Area': 'Ashfield',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 91916,
#   'Votes_Cast': 66946,
#   'Valid_Votes': 66899,
#   'Remain': 20179,
#   'Leave': 46720,
#   'Rejected_Ballots': 47,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 30},
#  'E07000171': {'Area_Code': 'E07000171',
#   'Area': 'Bassetlaw',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 85547,
#   'Votes_Cast': 64003,
#   'Valid_Votes': 63967,
#   'Remain': 20575,
#   'Leave': 43392,
#   'Rejected_Ballots': 36,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 20},
#  'E07000172': {'Area_Code': 'E07000172',
#   'Area': 'Broxtowe',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 83593,
#   'Votes_Cast': 65468,
#   'Valid_Votes': 65426,
#   'Remain': 29672,
#   'Leave': 35754,
#   'Rejected_Ballots': 42,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 8,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 33},
#  'E07000173': {'Area_Code': 'E07000173',
#   'Area': 'Gedling',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 88298,
#   'Votes_Cast': 67635,
#   'Valid_Votes': 67577,
#   'Remain': 30035,
#   'Leave': 37542,
#   'Rejected_Ballots': 58,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 38},
#  'E07000174': {'Area_Code': 'E07000174',
#   'Area': 'Mansfield',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 77624,
#   'Votes_Cast': 56370,
#   'Valid_Votes': 56344,
#   'Remain': 16417,
#   'Leave': 39927,
#   'Rejected_Ballots': 26,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 8,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 18},
#  'E07000175': {'Area_Code': 'E07000175',
#   'Area': 'Newark and Sherwood',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 87338,
#   'Votes_Cast': 67128,
#   'Valid_Votes': 67087,
#   'Remain': 26571,
#   'Leave': 40516,
#   'Rejected_Ballots': 41,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 25},
#  'E07000176': {'Area_Code': 'E07000176',
#   'Area': 'Rushcliffe',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 86401,
#   'Votes_Cast': 70470,
#   'Valid_Votes': 70410,
#   'Remain': 40522,
#   'Leave': 29888,
#   'Rejected_Ballots': 60,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 20,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 40},
#  'E09000001': {'Area_Code': 'E09000001',
#   'Area': 'City of London',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 5987,
#   'Votes_Cast': 4405,
#   'Valid_Votes': 4399,
#   'Remain': 3312,
#   'Leave': 1087,
#   'Rejected_Ballots': 6,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 2,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 4},
#  'E09000002': {'Area_Code': 'E09000002',
#   'Area': 'Barking and Dagenham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 115812,
#   'Votes_Cast': 73941,
#   'Valid_Votes': 73880,
#   'Remain': 27750,
#   'Leave': 46130,
#   'Rejected_Ballots': 61,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 21,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 40},
#  'E09000003': {'Area_Code': 'E09000003',
#   'Area': 'Barnet',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 223467,
#   'Votes_Cast': 161218,
#   'Valid_Votes': 161033,
#   'Remain': 100210,
#   'Leave': 60823,
#   'Rejected_Ballots': 185,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 54,
#   'Writing_or_mark': 12,
#   'Unmarked_or_void': 119},
#  'E09000004': {'Area_Code': 'E09000004',
#   'Area': 'Bexley',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 170779,
#   'Votes_Cast': 128570,
#   'Valid_Votes': 128489,
#   'Remain': 47603,
#   'Leave': 80886,
#   'Rejected_Ballots': 81,
#   'No_official_mark': 5,
#   'Voting_for_both_answers': 35,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 41},
#  'E09000005': {'Area_Code': 'E09000005',
#   'Area': 'Brent',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 186793,
#   'Votes_Cast': 121671,
#   'Valid_Votes': 121404,
#   'Remain': 72523,
#   'Leave': 48881,
#   'Rejected_Ballots': 267,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 157,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 110},
#  'E09000006': {'Area_Code': 'E09000006',
#   'Area': 'Bromley',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 231473,
#   'Votes_Cast': 182570,
#   'Valid_Votes': 182432,
#   'Remain': 92398,
#   'Leave': 90034,
#   'Rejected_Ballots': 138,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 43,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 95},
#  'E09000007': {'Area_Code': 'E09000007',
#   'Area': 'Camden',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 145425,
#   'Votes_Cast': 95281,
#   'Valid_Votes': 95133,
#   'Remain': 71295,
#   'Leave': 23838,
#   'Rejected_Ballots': 148,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 54,
#   'Writing_or_mark': 8,
#   'Unmarked_or_void': 86},
#  'E09000008': {'Area_Code': 'E09000008',
#   'Area': 'Croydon',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 245349,
#   'Votes_Cast': 171289,
#   'Valid_Votes': 171134,
#   'Remain': 92913,
#   'Leave': 78221,
#   'Rejected_Ballots': 155,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 73,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 77},
#  'E09000009': {'Area_Code': 'E09000009',
#   'Area': 'Ealing',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 212991,
#   'Votes_Cast': 149268,
#   'Valid_Votes': 149041,
#   'Remain': 90024,
#   'Leave': 59017,
#   'Rejected_Ballots': 227,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 115,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 109},
#  'E09000010': {'Area_Code': 'E09000010',
#   'Area': 'Enfield',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 198387,
#   'Votes_Cast': 137056,
#   'Valid_Votes': 136906,
#   'Remain': 76425,
#   'Leave': 60481,
#   'Rejected_Ballots': 150,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 69,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 80},
#  'E09000011': {'Area_Code': 'E09000011',
#   'Area': 'Greenwich',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 168967,
#   'Votes_Cast': 117470,
#   'Valid_Votes': 117365,
#   'Remain': 65248,
#   'Leave': 52117,
#   'Rejected_Ballots': 105,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 35,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 69},
#  'E09000012': {'Area_Code': 'E09000012',
#   'Area': 'Hackney',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 163284,
#   'Votes_Cast': 106422,
#   'Valid_Votes': 106266,
#   'Remain': 83398,
#   'Leave': 22868,
#   'Rejected_Ballots': 156,
#   'No_official_mark': 7,
#   'Voting_for_both_answers': 44,
#   'Writing_or_mark': 35,
#   'Unmarked_or_void': 70},
#  'E09000013': {'Area_Code': 'E09000013',
#   'Area': 'Hammersmith and Fulham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 114863,
#   'Votes_Cast': 80347,
#   'Valid_Votes': 80242,
#   'Remain': 56188,
#   'Leave': 24054,
#   'Rejected_Ballots': 105,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 32,
#   'Writing_or_mark': 8,
#   'Unmarked_or_void': 65},
#  'E09000014': {'Area_Code': 'E09000014',
#   'Area': 'Haringey',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 150098,
#   'Votes_Cast': 106032,
#   'Valid_Votes': 105846,
#   'Remain': 79991,
#   'Leave': 25855,
#   'Rejected_Ballots': 186,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 71,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 115},
#  'E09000015': {'Area_Code': 'E09000015',
#   'Area': 'Harrow',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 162397,
#   'Votes_Cast': 117352,
#   'Valid_Votes': 117225,
#   'Remain': 64042,
#   'Leave': 53183,
#   'Rejected_Ballots': 127,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 50,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 71},
#  'E09000016': {'Area_Code': 'E09000016',
#   'Area': 'Havering',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 183082,
#   'Votes_Cast': 139175,
#   'Valid_Votes': 139086,
#   'Remain': 42201,
#   'Leave': 96885,
#   'Rejected_Ballots': 89,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 25,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 62},
#  'E09000017': {'Area_Code': 'E09000017',
#   'Area': 'Hillingdon',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 193033,
#   'Votes_Cast': 133170,
#   'Valid_Votes': 133022,
#   'Remain': 58040,
#   'Leave': 74982,
#   'Rejected_Ballots': 148,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 55,
#   'Writing_or_mark': 16,
#   'Unmarked_or_void': 77},
#  'E09000018': {'Area_Code': 'E09000018',
#   'Area': 'Hounslow',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 165050,
#   'Votes_Cast': 115208,
#   'Valid_Votes': 115076,
#   'Remain': 58755,
#   'Leave': 56321,
#   'Rejected_Ballots': 132,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 39,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 87},
#  'E09000019': {'Area_Code': 'E09000019',
#   'Area': 'Islington',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 144514,
#   'Votes_Cast': 101723,
#   'Valid_Votes': 101600,
#   'Remain': 76420,
#   'Leave': 25180,
#   'Rejected_Ballots': 123,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 47,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 74},
#  'E09000020': {'Area_Code': 'E09000020',
#   'Area': 'Kensington and Chelsea',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 83042,
#   'Votes_Cast': 54801,
#   'Valid_Votes': 54739,
#   'Remain': 37601,
#   'Leave': 17138,
#   'Rejected_Ballots': 62,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 46},
#  'E09000021': {'Area_Code': 'E09000021',
#   'Area': 'Kingston upon Thames',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 108838,
#   'Votes_Cast': 85330,
#   'Valid_Votes': 85270,
#   'Remain': 52533,
#   'Leave': 32737,
#   'Rejected_Ballots': 60,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 16,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 41},
#  'E09000022': {'Area_Code': 'E09000022',
#   'Area': 'Lambeth',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 210800,
#   'Votes_Cast': 142162,
#   'Valid_Votes': 141924,
#   'Remain': 111584,
#   'Leave': 30340,
#   'Rejected_Ballots': 238,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 104,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 134},
#  'E09000023': {'Area_Code': 'E09000023',
#   'Area': 'Lewisham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 197514,
#   'Votes_Cast': 124637,
#   'Valid_Votes': 124473,
#   'Remain': 86955,
#   'Leave': 37518,
#   'Rejected_Ballots': 164,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 61,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 102},
#  'E09000024': {'Area_Code': 'E09000024',
#   'Area': 'Merton',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 136352,
#   'Votes_Cast': 100207,
#   'Valid_Votes': 100100,
#   'Remain': 63003,
#   'Leave': 37097,
#   'Rejected_Ballots': 107,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 45,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 62},
#  'E09000025': {'Area_Code': 'E09000025',
#   'Area': 'Newham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 176985,
#   'Votes_Cast': 104864,
#   'Valid_Votes': 104699,
#   'Remain': 55328,
#   'Leave': 49371,
#   'Rejected_Ballots': 165,
#   'No_official_mark': 9,
#   'Voting_for_both_answers': 87,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 69},
#  'E09000026': {'Area_Code': 'E09000026',
#   'Area': 'Redbridge',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 189843,
#   'Votes_Cast': 128397,
#   'Valid_Votes': 128233,
#   'Remain': 69213,
#   'Leave': 59020,
#   'Rejected_Ballots': 164,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 78,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 83},
#  'E09000027': {'Area_Code': 'E09000027',
#   'Area': 'Richmond upon Thames',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 132632,
#   'Votes_Cast': 108876,
#   'Valid_Votes': 108806,
#   'Remain': 75396,
#   'Leave': 33410,
#   'Rejected_Ballots': 70,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 26,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 42},
#  'E09000028': {'Area_Code': 'E09000028',
#   'Area': 'Southwark',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 195875,
#   'Votes_Cast': 129677,
#   'Valid_Votes': 129502,
#   'Remain': 94293,
#   'Leave': 35209,
#   'Rejected_Ballots': 175,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 60,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 110},
#  'E09000029': {'Area_Code': 'E09000029',
#   'Area': 'Sutton',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 140288,
#   'Votes_Cast': 106633,
#   'Valid_Votes': 106560,
#   'Remain': 49319,
#   'Leave': 57241,
#   'Rejected_Ballots': 73,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 25,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 41},
#  'E09000030': {'Area_Code': 'E09000030',
#   'Area': 'Tower Hamlets',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 167820,
#   'Votes_Cast': 108420,
#   'Valid_Votes': 108235,
#   'Remain': 73011,
#   'Leave': 35224,
#   'Rejected_Ballots': 185,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 105,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 74},
#  'E09000031': {'Area_Code': 'E09000031',
#   'Area': 'Waltham Forest',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 162983,
#   'Votes_Cast': 108689,
#   'Valid_Votes': 108551,
#   'Remain': 64156,
#   'Leave': 44395,
#   'Rejected_Ballots': 138,
#   'No_official_mark': 4,
#   'Voting_for_both_answers': 44,
#   'Writing_or_mark': 9,
#   'Unmarked_or_void': 81},
#  'E09000032': {'Area_Code': 'E09000032',
#   'Area': 'Wandsworth',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 219521,
#   'Votes_Cast': 158018,
#   'Valid_Votes': 157884,
#   'Remain': 118463,
#   'Leave': 39421,
#   'Rejected_Ballots': 134,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 55,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 79},
#  'E09000033': {'Area_Code': 'E09000033',
#   'Area': 'Westminster',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 120524,
#   'Votes_Cast': 78325,
#   'Valid_Votes': 78196,
#   'Remain': 53928,
#   'Leave': 24268,
#   'Rejected_Ballots': 129,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 47,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 81},
#  'E06000001': {'Area_Code': 'E06000001',
#   'Area': 'Hartlepool',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 70341,
#   'Votes_Cast': 46134,
#   'Valid_Votes': 46100,
#   'Remain': 14029,
#   'Leave': 32071,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 12,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 16},
#  'E06000002': {'Area_Code': 'E06000002',
#   'Area': 'Middlesbrough',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 94612,
#   'Votes_Cast': 61393,
#   'Valid_Votes': 61358,
#   'Remain': 21181,
#   'Leave': 40177,
#   'Rejected_Ballots': 35,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 16,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 18},
#  'E06000003': {'Area_Code': 'E06000003',
#   'Area': 'Redcar and Cleveland',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 103529,
#   'Votes_Cast': 72741,
#   'Valid_Votes': 72714,
#   'Remain': 24586,
#   'Leave': 48128,
#   'Rejected_Ballots': 27,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 21},
#  'E06000004': {'Area_Code': 'E06000004',
#   'Area': 'Stockton-on-Tees',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 141486,
#   'Votes_Cast': 100460,
#   'Valid_Votes': 100415,
#   'Remain': 38433,
#   'Leave': 61982,
#   'Rejected_Ballots': 45,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 28},
#  'E06000005': {'Area_Code': 'E06000005',
#   'Area': 'Darlington',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 77662,
#   'Votes_Cast': 55195,
#   'Valid_Votes': 55166,
#   'Remain': 24172,
#   'Leave': 30994,
#   'Rejected_Ballots': 29,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 0,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 29},
#  'E06000047': {'Area_Code': 'E06000047',
#   'Area': 'County Durham',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 389507,
#   'Votes_Cast': 267546,
#   'Valid_Votes': 267398,
#   'Remain': 113521,
#   'Leave': 153877,
#   'Rejected_Ballots': 148,
#   'No_official_mark': 3,
#   'Voting_for_both_answers': 35,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 109},
#  'E06000057': {'Area_Code': 'E06000057',
#   'Area': 'Northumberland',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 240496,
#   'Votes_Cast': 178815,
#   'Valid_Votes': 178721,
#   'Remain': 82022,
#   'Leave': 96699,
#   'Rejected_Ballots': 94,
#   'No_official_mark': 3,
#   'Voting_for_both_answers': 30,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 55},
#  'E08000021': {'Area_Code': 'E08000021',
#   'Area': 'Newcastle upon Tyne',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 190735,
#   'Votes_Cast': 129072,
#   'Valid_Votes': 129003,
#   'Remain': 65405,
#   'Leave': 63598,
#   'Rejected_Ballots': 69,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 20,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 44},
#  'E08000022': {'Area_Code': 'E08000022',
#   'Area': 'North Tyneside',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 156993,
#   'Votes_Cast': 113507,
#   'Valid_Votes': 113462,
#   'Remain': 52873,
#   'Leave': 60589,
#   'Rejected_Ballots': 45,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 25},
#  'E08000023': {'Area_Code': 'E08000023',
#   'Area': 'South Tyneside',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 115893,
#   'Votes_Cast': 79117,
#   'Valid_Votes': 79079,
#   'Remain': 30014,
#   'Leave': 49065,
#   'Rejected_Ballots': 38,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 27},
#  'E08000024': {'Area_Code': 'E08000024',
#   'Area': 'Sunderland',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 207221,
#   'Votes_Cast': 134400,
#   'Valid_Votes': 134324,
#   'Remain': 51930,
#   'Leave': 82394,
#   'Rejected_Ballots': 76,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 61},
#  'E08000037': {'Area_Code': 'E08000037',
#   'Area': 'Gateshead',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 145866,
#   'Votes_Cast': 103007,
#   'Valid_Votes': 102958,
#   'Remain': 44429,
#   'Leave': 58529,
#   'Rejected_Ballots': 49,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 33},
#  'E06000006': {'Area_Code': 'E06000006',
# ...
#   'Region': 'West Midlands',
#   'Electorate': 85777,
#   'Votes_Cast': 66739,
#   'Valid_Votes': 66692,
#   'Remain': 23444,
#   'Leave': 43248,
#   'Rejected_Ballots': 47,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 39},
#  'E07000197': {'Area_Code': 'E07000197',
#   'Area': 'Stafford',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 99612,
#   'Votes_Cast': 77527,
#   'Valid_Votes': 77484,
#   'Remain': 34098,
#   'Leave': 43386,
#   'Rejected_Ballots': 43,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 11,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 29},
#  'E07000198': {'Area_Code': 'E07000198',
#   'Area': 'Staffordshire Moorlands',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 79347,
#   'Votes_Cast': 59793,
#   'Valid_Votes': 59760,
#   'Remain': 21076,
#   'Leave': 38684,
#   'Rejected_Ballots': 33,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 20},
#  'E07000199': {'Area_Code': 'E07000199',
#   'Area': 'Tamworth',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 56825,
#   'Votes_Cast': 42151,
#   'Valid_Votes': 42129,
#   'Remain': 13705,
#   'Leave': 28424,
#   'Rejected_Ballots': 22,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 12,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 10},
#  'E07000218': {'Area_Code': 'E07000218',
#   'Area': 'North Warwickshire',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 49790,
#   'Votes_Cast': 37975,
#   'Valid_Votes': 37954,
#   'Remain': 12569,
#   'Leave': 25385,
#   'Rejected_Ballots': 21,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 12},
#  'E07000219': {'Area_Code': 'E07000219',
#   'Area': 'Nuneaton and Bedworth',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 93978,
#   'Votes_Cast': 69876,
#   'Valid_Votes': 69831,
#   'Remain': 23736,
#   'Leave': 46095,
#   'Rejected_Ballots': 45,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 20,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 23},
#  'E07000220': {'Area_Code': 'E07000220',
#   'Area': 'Rugby',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 74137,
#   'Votes_Cast': 58593,
#   'Valid_Votes': 58549,
#   'Remain': 25350,
#   'Leave': 33199,
#   'Rejected_Ballots': 44,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 29},
#  'E07000221': {'Area_Code': 'E07000221',
#   'Area': 'Stratford-on-Avon',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 98014,
#   'Votes_Cast': 79217,
#   'Valid_Votes': 79158,
#   'Remain': 38341,
#   'Leave': 40817,
#   'Rejected_Ballots': 59,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 50},
#  'E07000222': {'Area_Code': 'E07000222',
#   'Area': 'Warwick',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 103099,
#   'Votes_Cast': 81680,
#   'Valid_Votes': 81618,
#   'Remain': 47976,
#   'Leave': 33642,
#   'Rejected_Ballots': 62,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 33,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 29},
#  'E07000234': {'Area_Code': 'E07000234',
#   'Area': 'Bromsgrove',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 74170,
#   'Votes_Cast': 58855,
#   'Valid_Votes': 58815,
#   'Remain': 26252,
#   'Leave': 32563,
#   'Rejected_Ballots': 40,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 11,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 27},
#  'E07000235': {'Area_Code': 'E07000235',
#   'Area': 'Malvern Hills',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 60217,
#   'Votes_Cast': 48538,
#   'Valid_Votes': 48497,
#   'Remain': 23203,
#   'Leave': 25294,
#   'Rejected_Ballots': 41,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 31},
#  'E07000236': {'Area_Code': 'E07000236',
#   'Area': 'Redditch',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 61038,
#   'Votes_Cast': 45912,
#   'Valid_Votes': 45882,
#   'Remain': 17303,
#   'Leave': 28579,
#   'Rejected_Ballots': 30,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 7,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 23},
#  'E07000237': {'Area_Code': 'E07000237',
#   'Area': 'Worcester',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 73516,
#   'Votes_Cast': 54290,
#   'Valid_Votes': 54239,
#   'Remain': 25125,
#   'Leave': 29114,
#   'Rejected_Ballots': 51,
#   'No_official_mark': 7,
#   'Voting_for_both_answers': 22,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 20},
#  'E07000238': {'Area_Code': 'E07000238',
#   'Area': 'Wychavon',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 94497,
#   'Votes_Cast': 76425,
#   'Valid_Votes': 76389,
#   'Remain': 32188,
#   'Leave': 44201,
#   'Rejected_Ballots': 36,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 21},
#  'E07000239': {'Area_Code': 'E07000239',
#   'Area': 'Wyre Forest',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 77878,
#   'Votes_Cast': 57666,
#   'Valid_Votes': 57632,
#   'Remain': 21240,
#   'Leave': 36392,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 28},
#  'E08000025': {'Area_Code': 'E08000025',
#   'Area': 'Birmingham',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 707293,
#   'Votes_Cast': 451316,
#   'Valid_Votes': 450702,
#   'Remain': 223451,
#   'Leave': 227251,
#   'Rejected_Ballots': 614,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 311,
#   'Writing_or_mark': 17,
#   'Unmarked_or_void': 286},
#  'E08000026': {'Area_Code': 'E08000026',
#   'Area': 'Coventry',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 221389,
#   'Votes_Cast': 153234,
#   'Valid_Votes': 153064,
#   'Remain': 67967,
#   'Leave': 85097,
#   'Rejected_Ballots': 170,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 85,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 85},
#  'E08000027': {'Area_Code': 'E08000027',
#   'Area': 'Dudley',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 244516,
#   'Votes_Cast': 175333,
#   'Valid_Votes': 175226,
#   'Remain': 56780,
#   'Leave': 118446,
#   'Rejected_Ballots': 107,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 41,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 64},
#  'E08000028': {'Area_Code': 'E08000028',
#   'Area': 'Sandwell',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 221429,
#   'Votes_Cast': 147418,
#   'Valid_Votes': 147254,
#   'Remain': 49004,
#   'Leave': 98250,
#   'Rejected_Ballots': 164,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 90,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 72},
#  'E08000029': {'Area_Code': 'E08000029',
#   'Area': 'Solihull',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 160425,
#   'Votes_Cast': 122020,
#   'Valid_Votes': 121950,
#   'Remain': 53466,
#   'Leave': 68484,
#   'Rejected_Ballots': 70,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 25,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 45},
#  'E08000030': {'Area_Code': 'E08000030',
#   'Area': 'Walsall',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 194729,
#   'Votes_Cast': 135685,
#   'Valid_Votes': 135579,
#   'Remain': 43572,
#   'Leave': 92007,
#   'Rejected_Ballots': 106,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 59,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 44},
#  'E08000031': {'Area_Code': 'E08000031',
#   'Area': 'Wolverhampton',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 174760,
#   'Votes_Cast': 118037,
#   'Valid_Votes': 117936,
#   'Remain': 44138,
#   'Leave': 73798,
#   'Rejected_Ballots': 101,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 45,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 49},
#  'E06000010': {'Area_Code': 'E06000010',
#   'Area': 'Kingston upon Hull, City of',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 180230,
#   'Votes_Cast': 113436,
#   'Valid_Votes': 113355,
#   'Remain': 36709,
#   'Leave': 76646,
#   'Rejected_Ballots': 81,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 23,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 54},
#  'E06000011': {'Area_Code': 'E06000011',
#   'Area': 'East Riding of Yorkshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 266047,
#   'Votes_Cast': 199036,
#   'Valid_Votes': 198915,
#   'Remain': 78779,
#   'Leave': 120136,
#   'Rejected_Ballots': 121,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 36,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 82},
#  'E06000012': {'Area_Code': 'E06000012',
#   'Area': 'North East Lincolnshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 116302,
#   'Votes_Cast': 79011,
#   'Valid_Votes': 78982,
#   'Remain': 23797,
#   'Leave': 55185,
#   'Rejected_Ballots': 29,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 4,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 23},
#  'E06000013': {'Area_Code': 'E06000013',
#   'Area': 'North Lincolnshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 123611,
#   'Votes_Cast': 88906,
#   'Valid_Votes': 88862,
#   'Remain': 29947,
#   'Leave': 58915,
#   'Rejected_Ballots': 44,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 11,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 30},
#  'E06000014': {'Area_Code': 'E06000014',
#   'Area': 'York',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 155157,
#   'Votes_Cast': 109681,
#   'Valid_Votes': 109600,
#   'Remain': 63617,
#   'Leave': 45983,
#   'Rejected_Ballots': 81,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 20,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 56},
#  'E07000163': {'Area_Code': 'E07000163',
#   'Area': 'Craven',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 44320,
#   'Votes_Cast': 35907,
#   'Valid_Votes': 35891,
#   'Remain': 16930,
#   'Leave': 18961,
#   'Rejected_Ballots': 16,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 10},
#  'E07000164': {'Area_Code': 'E07000164',
#   'Area': 'Hambleton',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 70133,
#   'Votes_Cast': 55016,
#   'Valid_Votes': 54982,
#   'Remain': 25480,
#   'Leave': 29502,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 18,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 15},
#  'E07000165': {'Area_Code': 'E07000165',
#   'Area': 'Harrogate',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 119987,
#   'Votes_Cast': 94653,
#   'Valid_Votes': 94585,
#   'Remain': 48211,
#   'Leave': 46374,
#   'Rejected_Ballots': 68,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 25,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 38},
#  'E07000166': {'Area_Code': 'E07000166',
#   'Area': 'Richmondshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 36794,
#   'Votes_Cast': 27652,
#   'Valid_Votes': 27636,
#   'Remain': 11945,
#   'Leave': 15691,
#   'Rejected_Ballots': 16,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 10},
#  'E07000167': {'Area_Code': 'E07000167',
#   'Area': 'Ryedale',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 41529,
#   'Votes_Cast': 32069,
#   'Valid_Votes': 32050,
#   'Remain': 14340,
#   'Leave': 17710,
#   'Rejected_Ballots': 19,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 5,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 12},
#  'E07000168': {'Area_Code': 'E07000168',
#   'Area': 'Scarborough',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 82900,
#   'Votes_Cast': 60539,
#   'Valid_Votes': 60511,
#   'Remain': 22999,
#   'Leave': 37512,
#   'Rejected_Ballots': 28,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 22},
#  'E07000169': {'Area_Code': 'E07000169',
#   'Area': 'Selby',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 65278,
#   'Votes_Cast': 51636,
#   'Valid_Votes': 51603,
#   'Remain': 21071,
#   'Leave': 30532,
#   'Rejected_Ballots': 33,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 7,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 24},
#  'E08000016': {'Area_Code': 'E08000016',
#   'Area': 'Barnsley',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 175809,
#   'Votes_Cast': 122972,
#   'Valid_Votes': 122909,
#   'Remain': 38951,
#   'Leave': 83958,
#   'Rejected_Ballots': 63,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 45},
#  'E08000017': {'Area_Code': 'E08000017',
#   'Area': 'Doncaster',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 217432,
#   'Votes_Cast': 151246,
#   'Valid_Votes': 151182,
#   'Remain': 46922,
#   'Leave': 104260,
#   'Rejected_Ballots': 64,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 19,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 45},
#  'E08000018': {'Area_Code': 'E08000018',
#   'Area': 'Rotherham',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 197623,
#   'Votes_Cast': 137470,
#   'Valid_Votes': 137387,
#   'Remain': 44115,
#   'Leave': 93272,
#   'Rejected_Ballots': 83,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 30,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 49},
#  'E08000019': {'Area_Code': 'E08000019',
#   'Area': 'Sheffield',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 396406,
#   'Votes_Cast': 266951,
#   'Valid_Votes': 266753,
#   'Remain': 130735,
#   'Leave': 136018,
#   'Rejected_Ballots': 198,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 76,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 116},
#  'E08000032': {'Area_Code': 'E08000032',
#   'Area': 'Bradford',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 342817,
#   'Votes_Cast': 228727,
#   'Valid_Votes': 228488,
#   'Remain': 104575,
#   'Leave': 123913,
#   'Rejected_Ballots': 239,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 121,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 113},
#  'E08000033': {'Area_Code': 'E08000033',
#   'Area': 'Calderdale',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 149195,
#   'Votes_Cast': 106004,
#   'Valid_Votes': 105925,
#   'Remain': 46950,
#   'Leave': 58975,
#   'Rejected_Ballots': 79,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 22,
#   'Writing_or_mark': 15,
#   'Unmarked_or_void': 42},
#  'E08000034': {'Area_Code': 'E08000034',
#   'Area': 'Kirklees',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 307081,
#   'Votes_Cast': 217428,
#   'Valid_Votes': 217240,
#   'Remain': 98485,
#   'Leave': 118755,
#   'Rejected_Ballots': 188,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 86,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 95},
#  'E08000035': {'Area_Code': 'E08000035',
#   'Area': 'Leeds',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 543033,
#   'Votes_Cast': 387677,
#   'Valid_Votes': 387337,
#   'Remain': 194863,
#   'Leave': 192474,
#   'Rejected_Ballots': 340,
#   'No_official_mark': 39,
#   'Voting_for_both_answers': 116,
#   'Writing_or_mark': 8,
#   'Unmarked_or_void': 177},
#  'E08000036': {'Area_Code': 'E08000036',
#   'Area': 'Wakefield',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 246096,
#   'Votes_Cast': 175155,
#   'Valid_Votes': 175042,
#   'Remain': 58877,
#   'Leave': 116165,
#   'Rejected_Ballots': 113,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 46,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 63}}

# %%
{**uk_demo_dict, **uk_results_dict}
# Out:
# {'E06000031': {'Area_Code': 'E06000031',
#   'Votes_Cast': 87469,
#   'Valid_Votes': 87392,
#   'Remain': 34176,
#   'Leave': 53216},
#  'E06000032': {'Area_Code': 'E06000032',
#   'Votes_Cast': 84616,
#   'Valid_Votes': 84481,
#   'Remain': 36708,
#   'Leave': 47773},
#  'E06000033': {'Area_Code': 'E06000033',
#   'Votes_Cast': 93939,
#   'Valid_Votes': 93870,
#   'Remain': 39348,
#   'Leave': 54522},
#  'E06000034': {'Area_Code': 'E06000034',
#   'Votes_Cast': 79950,
#   'Valid_Votes': 79916,
#   'Remain': 22151,
#   'Leave': 57765},
#  'E06000055': {'Area_Code': 'E06000055',
#   'Votes_Cast': 86135,
#   'Valid_Votes': 86066,
#   'Remain': 41497,
#   'Leave': 44569},
#  'E06000056': {'Area_Code': 'E06000056',
#   'Votes_Cast': 158894,
#   'Valid_Votes': 158804,
#   'Remain': 69670,
#   'Leave': 89134},
#  'E07000008': {'Area_Code': 'E07000008',
#   'Votes_Cast': 57852,
#   'Valid_Votes': 57799,
#   'Remain': 42682,
#   'Leave': 15117},
#  'E07000009': {'Area_Code': 'E07000009',
#   'Votes_Cast': 48124,
#   'Valid_Votes': 48086,
#   'Remain': 23599,
#   'Leave': 24487},
#  'E07000010': {'Area_Code': 'E07000010',
#   'Votes_Cast': 52649,
#   'Valid_Votes': 52626,
#   'Remain': 15055,
#   'Leave': 37571},
#  'E07000011': {'Area_Code': 'E07000011',
#   'Votes_Cast': 99990,
#   'Valid_Votes': 99927,
#   'Remain': 45729,
#   'Leave': 54198},
#  'E07000012': {'Area_Code': 'E07000012',
#   'Votes_Cast': 93250,
#   'Valid_Votes': 93189,
#   'Remain': 56128,
#   'Leave': 37061},
#  'E07000066': {'Area_Code': 'E07000066',
#   'Votes_Cast': 98062,
#   'Valid_Votes': 97999,
#   'Remain': 30748,
#   'Leave': 67251},
#  'E07000067': {'Area_Code': 'E07000067',
#   'Votes_Cast': 86303,
#   'Valid_Votes': 86236,
#   'Remain': 33523,
#   'Leave': 52713},
#  'E07000068': {'Area_Code': 'E07000068',
#   'Votes_Cast': 46725,
#   'Valid_Votes': 46704,
#   'Remain': 19077,
#   'Leave': 27627},
#  'E07000069': {'Area_Code': 'E07000069',
#   'Votes_Cast': 51909,
#   'Valid_Votes': 51845,
#   'Remain': 14154,
#   'Leave': 37691},
#  'E07000070': {'Area_Code': 'E07000070',
#   'Votes_Cast': 100852,
#   'Valid_Votes': 100794,
#   'Remain': 47545,
#   'Leave': 53249},
#  'E07000071': {'Area_Code': 'E07000071',
#   'Votes_Cast': 95782,
#   'Valid_Votes': 95719,
#   'Remain': 44414,
#   'Leave': 51305},
#  'E07000072': {'Area_Code': 'E07000072',
#   'Votes_Cast': 76900,
#   'Valid_Votes': 76852,
#   'Remain': 28676,
#   'Leave': 48176},
#  'E07000073': {'Area_Code': 'E07000073',
#   'Votes_Cast': 43489,
#   'Valid_Votes': 43469,
#   'Remain': 13867,
#   'Leave': 29602},
#  'E07000074': {'Area_Code': 'E07000074',
#   'Votes_Cast': 38850,
#   'Valid_Votes': 38831,
#   'Remain': 14529,
#   'Leave': 24302},
#  'E07000075': {'Area_Code': 'E07000075',
#   'Votes_Cast': 52479,
#   'Valid_Votes': 52447,
#   'Remain': 17510,
#   'Leave': 34937},
#  'E07000076': {'Area_Code': 'E07000076',
#   'Votes_Cast': 82703,
#   'Valid_Votes': 82657,
#   'Remain': 25210,
#   'Leave': 57447},
#  'E07000077': {'Area_Code': 'E07000077',
#   'Votes_Cast': 51972,
#   'Valid_Votes': 51943,
#   'Remain': 25619,
#   'Leave': 26324},
#  'E07000095': {'Area_Code': 'E07000095',
#   'Votes_Cast': 50907,
#   'Valid_Votes': 50872,
#   'Remain': 17166,
#   'Leave': 33706},
#  'E07000096': {'Area_Code': 'E07000096',
#   'Votes_Cast': 86307,
#   'Valid_Votes': 86244,
#   'Remain': 42542,
#   'Leave': 43702},
#  'E07000098': {'Area_Code': 'E07000098',
#   'Votes_Cast': 56159,
#   'Valid_Votes': 56125,
#   'Remain': 27593,
#   'Leave': 28532},
#  'E07000099': {'Area_Code': 'E07000099',
#   'Votes_Cast': 77737,
#   'Valid_Votes': 77672,
#   'Remain': 42234,
#   'Leave': 35438},
#  'E07000102': {'Area_Code': 'E07000102',
#   'Votes_Cast': 52896,
#   'Valid_Votes': 52848,
#   'Remain': 25751,
#   'Leave': 27097},
#  'E07000103': {'Area_Code': 'E07000103',
#   'Votes_Cast': 46635,
#   'Valid_Votes': 46586,
#   'Remain': 23167,
#   'Leave': 23419},
#  'E07000143': {'Area_Code': 'E07000143',
#   'Votes_Cast': 73593,
#   'Valid_Votes': 73548,
#   'Remain': 26313,
#   'Leave': 47235},
#  'E07000144': {'Area_Code': 'E07000144',
#   'Votes_Cast': 77781,
#   'Valid_Votes': 77737,
#   'Remain': 35469,
#   'Leave': 42268},
#  'E07000145': {'Area_Code': 'E07000145',
#   'Votes_Cast': 50158,
#   'Valid_Votes': 50128,
#   'Remain': 14284,
#   'Leave': 35844},
#  'E07000146': {'Area_Code': 'E07000146',
#   'Votes_Cast': 85128,
#   'Valid_Votes': 85080,
#   'Remain': 28587,
#   'Leave': 56493},
#  'E07000147': {'Area_Code': 'E07000147',
#   'Votes_Cast': 63829,
#   'Valid_Votes': 63790,
#   'Remain': 26214,
#   'Leave': 37576},
#  'E07000148': {'Area_Code': 'E07000148',
#   'Votes_Cast': 66422,
#   'Valid_Votes': 66366,
#   'Remain': 37326,
#   'Leave': 29040},
#  'E07000149': {'Area_Code': 'E07000149',
#   'Votes_Cast': 80418,
#   'Valid_Votes': 80358,
#   'Remain': 38817,
#   'Leave': 41541},
#  'E07000200': {'Area_Code': 'E07000200',
#   'Votes_Cast': 55272,
#   'Valid_Votes': 55242,
#   'Remain': 25309,
#   'Leave': 29933},
#  'E07000201': {'Area_Code': 'E07000201',
#   'Votes_Cast': 27977,
#   'Valid_Votes': 27951,
#   'Remain': 9791,
#   'Leave': 18160},
#  'E07000202': {'Area_Code': 'E07000202',
#   'Votes_Cast': 66400,
#   'Valid_Votes': 66353,
#   'Remain': 27698,
#   'Leave': 38655},
#  'E07000203': {'Area_Code': 'E07000203',
#   'Votes_Cast': 61222,
#   'Valid_Votes': 61185,
#   'Remain': 27391,
#   'Leave': 33794},
#  'E07000204': {'Area_Code': 'E07000204',
#   'Votes_Cast': 62255,
#   'Valid_Votes': 62210,
#   'Remain': 26986,
#   'Leave': 35224},
#  'E07000205': {'Area_Code': 'E07000205',
#   'Votes_Cast': 79226,
#   'Valid_Votes': 79184,
#   'Remain': 37218,
#   'Leave': 41966},
#  'E07000206': {'Area_Code': 'E07000206',
#   'Votes_Cast': 65687,
#   'Valid_Votes': 65646,
#   'Remain': 24356,
#   'Leave': 41290},
#  'E07000240': {'Area_Code': 'E07000240',
#   'Votes_Cast': 86524,
#   'Valid_Votes': 86445,
#   'Remain': 54208,
#   'Leave': 32237},
#  'E07000241': {'Area_Code': 'E07000241',
#   'Votes_Cast': 58641,
#   'Valid_Votes': 58610,
#   'Remain': 27550,
#   'Leave': 31060},
#  'E07000242': {'Area_Code': 'E07000242',
#   'Votes_Cast': 85433,
#   'Valid_Votes': 85366,
#   'Remain': 42372,
#   'Leave': 42994},
#  'E07000243': {'Area_Code': 'E07000243',
#   'Votes_Cast': 45811,
#   'Valid_Votes': 45785,
#   'Remain': 18659,
#   'Leave': 27126},
#  'E06000015': {'Area_Code': 'E06000015',
#   'Votes_Cast': 120772,
#   'Valid_Votes': 120655,
#   'Remain': 51612,
#   'Leave': 69043},
#  'E06000016': {'Area_Code': 'E06000016',
#   'Votes_Cast': 139307,
#   'Valid_Votes': 138972,
#   'Remain': 70980,
#   'Leave': 67992},
#  'E06000017': {'Area_Code': 'E06000017',
#   'Votes_Cast': 22984,
#   'Valid_Votes': 22966,
#   'Remain': 11353,
#   'Leave': 11613},
#  'E06000018': {'Area_Code': 'E06000018',
#   'Votes_Cast': 120791,
#   'Valid_Votes': 120661,
#   'Remain': 59318,
#   'Leave': 61343},
#  'E07000032': {'Area_Code': 'E07000032',
#   'Votes_Cast': 73864,
#   'Valid_Votes': 73820,
#   'Remain': 29319,
#   'Leave': 44501},
#  'E07000033': {'Area_Code': 'E07000033',
#   'Votes_Cast': 41999,
#   'Valid_Votes': 41972,
#   'Remain': 12242,
#   'Leave': 29730},
#  'E07000034': {'Area_Code': 'E07000034',
#   'Votes_Cast': 57470,
#   'Valid_Votes': 57424,
#   'Remain': 22946,
#   'Leave': 34478},
#  'E07000035': {'Area_Code': 'E07000035',
#   'Votes_Cast': 46756,
#   'Valid_Votes': 46728,
#   'Remain': 22633,
#   'Leave': 24095},
#  'E07000036': {'Area_Code': 'E07000036',
#   'Votes_Cast': 66566,
#   'Valid_Votes': 66530,
#   'Remain': 25791,
#   'Leave': 40739},
#  'E07000037': {'Area_Code': 'E07000037',
#   'Votes_Cast': 54864,
#   'Valid_Votes': 54833,
#   'Remain': 27116,
#   'Leave': 27717},
#  'E07000038': {'Area_Code': 'E07000038',
#   'Votes_Cast': 59341,
#   'Valid_Votes': 59310,
#   'Remain': 22075,
#   'Leave': 37235},
#  'E07000039': {'Area_Code': 'E07000039',
#   'Votes_Cast': 56718,
#   'Valid_Votes': 56695,
#   'Remain': 22479,
#   'Leave': 34216},
#  'E07000129': {'Area_Code': 'E07000129',
#   'Votes_Cast': 56512,
#   'Valid_Votes': 56471,
#   'Remain': 22888,
#   'Leave': 33583},
#  'E07000130': {'Area_Code': 'E07000130',
#   'Votes_Cast': 94257,
#   'Valid_Votes': 94172,
#   'Remain': 43500,
#   'Leave': 50672},
#  'E07000131': {'Area_Code': 'E07000131',
#   'Votes_Cast': 54910,
#   'Valid_Votes': 54878,
#   'Remain': 27028,
#   'Leave': 27850},
#  'E07000132': {'Area_Code': 'E07000132',
#   'Votes_Cast': 65516,
#   'Valid_Votes': 65470,
#   'Remain': 25969,
#   'Leave': 39501},
#  'E07000133': {'Area_Code': 'E07000133',
#   'Votes_Cast': 30327,
#   'Valid_Votes': 30305,
#   'Remain': 12695,
#   'Leave': 17610},
#  'E07000134': {'Area_Code': 'E07000134',
#   'Votes_Cast': 57638,
#   'Valid_Votes': 57611,
#   'Remain': 22642,
#   'Leave': 34969},
#  'E07000135': {'Area_Code': 'E07000135',
#   'Votes_Cast': 31489,
#   'Valid_Votes': 31465,
#   'Remain': 14292,
#   'Leave': 17173},
#  'E07000136': {'Area_Code': 'E07000136',
#   'Votes_Cast': 30416,
#   'Valid_Votes': 30404,
#   'Remain': 7430,
#   'Leave': 22974},
#  'E07000137': {'Area_Code': 'E07000137',
#   'Votes_Cast': 80178,
#   'Valid_Votes': 80128,
#   'Remain': 23515,
#   'Leave': 56613},
#  'E07000138': {'Area_Code': 'E07000138',
#   'Votes_Cast': 43928,
#   'Valid_Votes': 43894,
#   'Remain': 18902,
#   'Leave': 24992},
#  'E07000139': {'Area_Code': 'E07000139',
#   'Votes_Cast': 67791,
#   'Valid_Votes': 67753,
#   'Remain': 25570,
#   'Leave': 42183},
#  'E07000140': {'Area_Code': 'E07000140',
#   'Votes_Cast': 49518,
#   'Valid_Votes': 49497,
#   'Remain': 13074,
#   'Leave': 36423},
#  'E07000141': {'Area_Code': 'E07000141',
#   'Votes_Cast': 82523,
#   'Valid_Votes': 82471,
#   'Remain': 33047,
#   'Leave': 49424},
#  'E07000142': {'Area_Code': 'E07000142',
#   'Votes_Cast': 54781,
#   'Valid_Votes': 54753,
#   'Remain': 20906,
#   'Leave': 33847},
#  'E07000150': {'Area_Code': 'E07000150',
#   'Votes_Cast': 32097,
#   'Valid_Votes': 32081,
#   'Remain': 11470,
#   'Leave': 20611},
#  'E07000151': {'Area_Code': 'E07000151',
#   'Votes_Cast': 49420,
#   'Valid_Votes': 49381,
#   'Remain': 20443,
#   'Leave': 28938},
#  'E07000152': {'Area_Code': 'E07000152',
#   'Votes_Cast': 52607,
#   'Valid_Votes': 52574,
#   'Remain': 21680,
#   'Leave': 30894},
#  'E07000153': {'Area_Code': 'E07000153',
#   'Votes_Cast': 53940,
#   'Valid_Votes': 53907,
#   'Remain': 21030,
#   'Leave': 32877},
#  'E07000154': {'Area_Code': 'E07000154',
#   'Votes_Cast': 105354,
#   'Valid_Votes': 105259,
#   'Remain': 43805,
#   'Leave': 61454},
#  'E07000155': {'Area_Code': 'E07000155',
#   'Votes_Cast': 56664,
#   'Valid_Votes': 56624,
#   'Remain': 25853,
#   'Leave': 30771},
#  'E07000156': {'Area_Code': 'E07000156',
#   'Votes_Cast': 41178,
#   'Valid_Votes': 41141,
#   'Remain': 15462,
#   'Leave': 25679},
#  'E07000170': {'Area_Code': 'E07000170',
#   'Votes_Cast': 66946,
#   'Valid_Votes': 66899,
#   'Remain': 20179,
#   'Leave': 46720},
#  'E07000171': {'Area_Code': 'E07000171',
#   'Votes_Cast': 64003,
#   'Valid_Votes': 63967,
#   'Remain': 20575,
#   'Leave': 43392},
#  'E07000172': {'Area_Code': 'E07000172',
#   'Votes_Cast': 65468,
#   'Valid_Votes': 65426,
#   'Remain': 29672,
#   'Leave': 35754},
#  'E07000173': {'Area_Code': 'E07000173',
#   'Votes_Cast': 67635,
#   'Valid_Votes': 67577,
#   'Remain': 30035,
#   'Leave': 37542},
#  'E07000174': {'Area_Code': 'E07000174',
#   'Votes_Cast': 56370,
#   'Valid_Votes': 56344,
#   'Remain': 16417,
#   'Leave': 39927},
#  'E07000175': {'Area_Code': 'E07000175',
#   'Votes_Cast': 67128,
#   'Valid_Votes': 67087,
#   'Remain': 26571,
#   'Leave': 40516},
#  'E07000176': {'Area_Code': 'E07000176',
#   'Votes_Cast': 70470,
#   'Valid_Votes': 70410,
#   'Remain': 40522,
#   'Leave': 29888},
#  'E09000001': {'Area_Code': 'E09000001',
#   'Votes_Cast': 4405,
#   'Valid_Votes': 4399,
#   'Remain': 3312,
#   'Leave': 1087},
#  'E09000002': {'Area_Code': 'E09000002',
#   'Votes_Cast': 73941,
#   'Valid_Votes': 73880,
#   'Remain': 27750,
#   'Leave': 46130},
#  'E09000003': {'Area_Code': 'E09000003',
#   'Votes_Cast': 161218,
#   'Valid_Votes': 161033,
#   'Remain': 100210,
#   'Leave': 60823},
#  'E09000004': {'Area_Code': 'E09000004',
#   'Votes_Cast': 128570,
#   'Valid_Votes': 128489,
#   'Remain': 47603,
#   'Leave': 80886},
#  'E09000005': {'Area_Code': 'E09000005',
#   'Votes_Cast': 121671,
#   'Valid_Votes': 121404,
#   'Remain': 72523,
#   'Leave': 48881},
#  'E09000006': {'Area_Code': 'E09000006',
#   'Votes_Cast': 182570,
#   'Valid_Votes': 182432,
#   'Remain': 92398,
#   'Leave': 90034},
#  'E09000007': {'Area_Code': 'E09000007',
#   'Votes_Cast': 95281,
#   'Valid_Votes': 95133,
#   'Remain': 71295,
#   'Leave': 23838},
#  'E09000008': {'Area_Code': 'E09000008',
#   'Votes_Cast': 171289,
#   'Valid_Votes': 171134,
#   'Remain': 92913,
#   'Leave': 78221},
#  'E09000009': {'Area_Code': 'E09000009',
#   'Votes_Cast': 149268,
#   'Valid_Votes': 149041,
#   'Remain': 90024,
#   'Leave': 59017},
#  'E09000010': {'Area_Code': 'E09000010',
#   'Votes_Cast': 137056,
#   'Valid_Votes': 136906,
#   'Remain': 76425,
#   'Leave': 60481},
#  'E09000011': {'Area_Code': 'E09000011',
#   'Votes_Cast': 117470,
#   'Valid_Votes': 117365,
#   'Remain': 65248,
#   'Leave': 52117},
#  'E09000012': {'Area_Code': 'E09000012',
#   'Votes_Cast': 106422,
#   'Valid_Votes': 106266,
#   'Remain': 83398,
#   'Leave': 22868},
#  'E09000013': {'Area_Code': 'E09000013',
#   'Votes_Cast': 80347,
#   'Valid_Votes': 80242,
#   'Remain': 56188,
#   'Leave': 24054},
#  'E09000014': {'Area_Code': 'E09000014',
#   'Votes_Cast': 106032,
#   'Valid_Votes': 105846,
#   'Remain': 79991,
#   'Leave': 25855},
#  'E09000015': {'Area_Code': 'E09000015',
#   'Votes_Cast': 117352,
#   'Valid_Votes': 117225,
#   'Remain': 64042,
#   'Leave': 53183},
#  'E09000016': {'Area_Code': 'E09000016',
#   'Votes_Cast': 139175,
#   'Valid_Votes': 139086,
#   'Remain': 42201,
#   'Leave': 96885},
#  'E09000017': {'Area_Code': 'E09000017',
#   'Votes_Cast': 133170,
#   'Valid_Votes': 133022,
#   'Remain': 58040,
#   'Leave': 74982},
#  'E09000018': {'Area_Code': 'E09000018',
#   'Votes_Cast': 115208,
#   'Valid_Votes': 115076,
#   'Remain': 58755,
#   'Leave': 56321},
#  'E09000019': {'Area_Code': 'E09000019',
#   'Votes_Cast': 101723,
#   'Valid_Votes': 101600,
#   'Remain': 76420,
#   'Leave': 25180},
#  'E09000020': {'Area_Code': 'E09000020',
#   'Votes_Cast': 54801,
#   'Valid_Votes': 54739,
#   'Remain': 37601,
#   'Leave': 17138},
#  'E09000021': {'Area_Code': 'E09000021',
#   'Votes_Cast': 85330,
#   'Valid_Votes': 85270,
#   'Remain': 52533,
#   'Leave': 32737},
#  'E09000022': {'Area_Code': 'E09000022',
#   'Votes_Cast': 142162,
#   'Valid_Votes': 141924,
#   'Remain': 111584,
#   'Leave': 30340},
#  'E09000023': {'Area_Code': 'E09000023',
#   'Votes_Cast': 124637,
#   'Valid_Votes': 124473,
#   'Remain': 86955,
#   'Leave': 37518},
#  'E09000024': {'Area_Code': 'E09000024',
#   'Votes_Cast': 100207,
#   'Valid_Votes': 100100,
#   'Remain': 63003,
#   'Leave': 37097},
#  'E09000025': {'Area_Code': 'E09000025',
#   'Votes_Cast': 104864,
#   'Valid_Votes': 104699,
#   'Remain': 55328,
#   'Leave': 49371},
#  'E09000026': {'Area_Code': 'E09000026',
#   'Votes_Cast': 128397,
#   'Valid_Votes': 128233,
#   'Remain': 69213,
#   'Leave': 59020},
#  'E09000027': {'Area_Code': 'E09000027',
#   'Votes_Cast': 108876,
#   'Valid_Votes': 108806,
#   'Remain': 75396,
#   'Leave': 33410},
#  'E09000028': {'Area_Code': 'E09000028',
#   'Votes_Cast': 129677,
#   'Valid_Votes': 129502,
#   'Remain': 94293,
#   'Leave': 35209},
#  'E09000029': {'Area_Code': 'E09000029',
#   'Votes_Cast': 106633,
#   'Valid_Votes': 106560,
#   'Remain': 49319,
#   'Leave': 57241},
#  'E09000030': {'Area_Code': 'E09000030',
#   'Votes_Cast': 108420,
#   'Valid_Votes': 108235,
#   'Remain': 73011,
#   'Leave': 35224},
#  'E09000031': {'Area_Code': 'E09000031',
#   'Votes_Cast': 108689,
#   'Valid_Votes': 108551,
#   'Remain': 64156,
#   'Leave': 44395},
#  'E09000032': {'Area_Code': 'E09000032',
#   'Votes_Cast': 158018,
#   'Valid_Votes': 157884,
#   'Remain': 118463,
#   'Leave': 39421},
#  'E09000033': {'Area_Code': 'E09000033',
#   'Votes_Cast': 78325,
#   'Valid_Votes': 78196,
#   'Remain': 53928,
#   'Leave': 24268},
#  'E06000001': {'Area_Code': 'E06000001',
#   'Votes_Cast': 46134,
#   'Valid_Votes': 46100,
#   'Remain': 14029,
#   'Leave': 32071},
#  'E06000002': {'Area_Code': 'E06000002',
#   'Votes_Cast': 61393,
#   'Valid_Votes': 61358,
#   'Remain': 21181,
#   'Leave': 40177},
#  'E06000003': {'Area_Code': 'E06000003',
#   'Votes_Cast': 72741,
#   'Valid_Votes': 72714,
#   'Remain': 24586,
#   'Leave': 48128},
#  'E06000004': {'Area_Code': 'E06000004',
#   'Votes_Cast': 100460,
#   'Valid_Votes': 100415,
#   'Remain': 38433,
#   'Leave': 61982},
#  'E06000005': {'Area_Code': 'E06000005',
#   'Votes_Cast': 55195,
#   'Valid_Votes': 55166,
#   'Remain': 24172,
#   'Leave': 30994},
#  'E06000047': {'Area_Code': 'E06000047',
#   'Votes_Cast': 267546,
#   'Valid_Votes': 267398,
#   'Remain': 113521,
#   'Leave': 153877},
#  'E06000057': {'Area_Code': 'E06000057',
#   'Votes_Cast': 178815,
#   'Valid_Votes': 178721,
#   'Remain': 82022,
#   'Leave': 96699},
#  'E08000021': {'Area_Code': 'E08000021',
#   'Votes_Cast': 129072,
#   'Valid_Votes': 129003,
#   'Remain': 65405,
#   'Leave': 63598},
#  'E08000022': {'Area_Code': 'E08000022',
#   'Votes_Cast': 113507,
#   'Valid_Votes': 113462,
#   'Remain': 52873,
#   'Leave': 60589},
#  'E08000023': {'Area_Code': 'E08000023',
#   'Votes_Cast': 79117,
#   'Valid_Votes': 79079,
#   'Remain': 30014,
#   'Leave': 49065},
#  'E08000024': {'Area_Code': 'E08000024',
#   'Votes_Cast': 134400,
#   'Valid_Votes': 134324,
#   'Remain': 51930,
#   'Leave': 82394},
#  'E08000037': {'Area_Code': 'E08000037',
#   'Votes_Cast': 103007,
#   'Valid_Votes': 102958,
#   'Remain': 44429,
#   'Leave': 58529},
#  'E06000006': {'Area_Code': 'E06000006',
#   'Votes_Cast': 65047,
#   'Valid_Votes': 65005,
#   'Remain': 27678,
#   'Leave': 37327},
#  'E06000007': {'Area_Code': 'E06000007',
#   'Votes_Cast': 115205,
#   'Valid_Votes': 115144,
#   'Remain': 52657,
#   'Leave': 62487},
#  'E06000008': {'Area_Code': 'E06000008',
#   'Votes_Cast': 65408,
#   'Valid_Votes': 65321,
#   'Remain': 28522,
#   'Leave': 36799},
#  'E06000009': {'Area_Code': 'E06000009',
#   'Votes_Cast': 66959,
#   'Valid_Votes': 66927,
#   'Remain': 21781,
#   'Leave': 45146},
#  'E06000049': {'Area_Code': 'E06000049',
#   'Votes_Cast': 221229,
#   'Valid_Votes': 221125,
#   'Remain': 107962,
#   'Leave': 113163},
#  'E06000050': {'Area_Code': 'E06000050',
#   'Votes_Cast': 193633,
#   'Valid_Votes': 193537,
#   'Remain': 95455,
#   'Leave': 98082},
#  'E07000026': {'Area_Code': 'E07000026',
#   'Votes_Cast': 54268,
#   'Valid_Votes': 54238,
#   'Remain': 22429,
#   'Leave': 31809},
#  'E07000027': {'Area_Code': 'E07000027',
#   'Votes_Cast': 36101,
#   'Valid_Votes': 36074,
#   'Remain': 14207,
#   'Leave': 21867},
#  'E07000028': {'Area_Code': 'E07000028',
#   'Votes_Cast': 59721,
#   'Valid_Votes': 59683,
#   'Remain': 23788,
#   'Leave': 35895},
#  'E07000029': {'Area_Code': 'E07000029',
#   'Votes_Cast': 37975,
#   'Valid_Votes': 37947,
#   'Remain': 14419,
#   'Leave': 23528},
#  'E07000030': {'Area_Code': 'E07000030',
#   'Votes_Cast': 31746,
#   'Valid_Votes': 31718,
#   'Remain': 14807,
#   'Leave': 16911},
#  'E07000031': {'Area_Code': 'E07000031',
#   'Votes_Cast': 65375,
#   'Valid_Votes': 65331,
#   'Remain': 34531,
#   'Leave': 30800},
#  'E07000117': {'Area_Code': 'E07000117',
#   'Votes_Cast': 43350,
#   'Valid_Votes': 43316,
#   'Remain': 14462,
#   'Leave': 28854},
#  'E07000118': {'Area_Code': 'E07000118',
#   'Votes_Cast': 63560,
#   'Valid_Votes': 63515,
#   'Remain': 27417,
#   'Leave': 36098},
#  'E07000119': {'Area_Code': 'E07000119',
#   'Votes_Cast': 46227,
#   'Valid_Votes': 46206,
#   'Remain': 19889,
#   'Leave': 26317},
#  'E07000120': {'Area_Code': 'E07000120',
#   'Votes_Cast': 40168,
#   'Valid_Votes': 40137,
#   'Remain': 13569,
#   'Leave': 26568},
#  'E07000121': {'Area_Code': 'E07000121',
#   'Votes_Cast': 73098,
#   'Valid_Votes': 73041,
#   'Remain': 35732,
#   'Leave': 37309},
#  'E07000122': {'Area_Code': 'E07000122',
#   'Votes_Cast': 45388,
#   'Valid_Votes': 45335,
#   'Remain': 16704,
#   'Leave': 28631},
#  'E07000123': {'Area_Code': 'E07000123',
#   'Votes_Cast': 64794,
#   'Valid_Votes': 64745,
#   'Remain': 30227,
#   'Leave': 34518},
#  'E07000124': {'Area_Code': 'E07000124',
#   'Votes_Cast': 36466,
#   'Valid_Votes': 36442,
#   'Remain': 15892,
#   'Leave': 20550},
#  'E07000125': {'Area_Code': 'E07000125',
#   'Votes_Cast': 38205,
#   'Valid_Votes': 38181,
#   'Remain': 15012,
#   'Leave': 23169},
#  'E07000126': {'Area_Code': 'E07000126',
#   'Votes_Cast': 63755,
#   'Valid_Votes': 63724,
#   'Remain': 26406,
#   'Leave': 37318},
#  'E07000127': {'Area_Code': 'E07000127',
#   'Votes_Cast': 63918,
#   'Valid_Votes': 63869,
#   'Remain': 28546,
#   'Leave': 35323},
#  'E07000128': {'Area_Code': 'E07000128',
#   'Votes_Cast': 63028,
#   'Valid_Votes': 62979,
#   'Remain': 22816,
#   'Leave': 40163},
#  'E08000001': {'Area_Code': 'E08000001',
#   'Votes_Cast': 138180,
#   'Valid_Votes': 138080,
#   'Remain': 57589,
#   'Leave': 80491},
#  'E08000002': {'Area_Code': 'E08000002',
#   'Votes_Cast': 101144,
#   'Valid_Votes': 101028,
#   'Remain': 46354,
#   'Leave': 54674},
#  'E08000003': {'Area_Code': 'E08000003',
#   'Votes_Cast': 202067,
#   'Valid_Votes': 201814,
#   'Remain': 121823,
#   'Leave': 79991},
#  'E08000004': {'Area_Code': 'E08000004',
#   'Votes_Cast': 107493,
#   'Valid_Votes': 107403,
#   'Remain': 42034,
#   'Leave': 65369},
#  'E08000005': {'Area_Code': 'E08000005',
#   'Votes_Cast': 103319,
#   'Valid_Votes': 103231,
#   'Remain': 41217,
#   'Leave': 62014},
#  'E08000006': {'Area_Code': 'E08000006',
#   'Votes_Cast': 109926,
#   'Valid_Votes': 109815,
#   'Remain': 47430,
#   'Leave': 62385},
#  'E08000007': {'Area_Code': 'E08000007',
#   'Votes_Cast': 163584,
#   'Valid_Votes': 163489,
#   'Remain': 85559,
#   'Leave': 77930},
#  'E08000008': {'Area_Code': 'E08000008',
#   'Votes_Cast': 111016,
#   'Valid_Votes': 110947,
#   'Remain': 43118,
#   'Leave': 67829},
#  'E08000009': {'Area_Code': 'E08000009',
#   'Votes_Cast': 125400,
#   'Valid_Votes': 125311,
#   'Remain': 72293,
#   'Leave': 53018},
#  'E08000010': {'Area_Code': 'E08000010',
#   'Votes_Cast': 163381,
#   'Valid_Votes': 163273,
#   'Remain': 58942,
#   'Leave': 104331},
#  'E08000011': {'Area_Code': 'E08000011',
#   'Votes_Cast': 70937,
#   'Valid_Votes': 70903,
#   'Remain': 34345,
#   'Leave': 36558},
#  'E08000012': {'Area_Code': 'E08000012',
#   'Votes_Cast': 203728,
#   'Valid_Votes': 203554,
#   'Remain': 118453,
#   'Leave': 85101},
#  'E08000013': {'Area_Code': 'E08000013',
#   'Votes_Cast': 93721,
#   'Valid_Votes': 93679,
#   'Remain': 39322,
#   'Leave': 54357},
#  'E08000014': {'Area_Code': 'E08000014',
#   'Votes_Cast': 147970,
#   'Valid_Votes': 147878,
#   'Remain': 76702,
#   'Leave': 71176},
#  'E08000015': {'Area_Code': 'E08000015',
#   'Votes_Cast': 172137,
#   'Valid_Votes': 172000,
#   'Remain': 88931,
#   'Leave': 83069},
#  'N92000002': {'Area_Code': 'N92000002',
#   'Votes_Cast': 790523,
#   'Valid_Votes': 790149,
#   'Remain': 440707,
#   'Leave': 349442},
#  'S12000005': {'Area_Code': 'S12000005',
#   'Votes_Cast': 25439,
#   'Valid_Votes': 25427,
#   'Remain': 14691,
#   'Leave': 10736},
#  'S12000006': {'Area_Code': 'S12000006',
#   'Votes_Cast': 82715,
#   'Valid_Votes': 82667,
#   'Remain': 43864,
#   'Leave': 38803},
#  'S12000008': {'Area_Code': 'S12000008',
#   'Votes_Cast': 57859,
#   'Valid_Votes': 57833,
#   'Remain': 33891,
#   'Leave': 23942},
#  'S12000010': {'Area_Code': 'S12000010',
#   'Votes_Cast': 55800,
#   'Valid_Votes': 55764,
#   'Remain': 36026,
#   'Leave': 19738},
#  'S12000011': {'Area_Code': 'S12000011',
#   'Votes_Cast': 52969,
#   'Valid_Votes': 52941,
#   'Remain': 39345,
#   'Leave': 13596},
#  'S12000013': {'Area_Code': 'S12000013',
#   'Votes_Cast': 14919,
#   'Valid_Votes': 14903,
#   'Remain': 8232,
#   'Leave': 6671},
#  'S12000014': {'Area_Code': 'S12000014',
#   'Votes_Cast': 79302,
#   'Valid_Votes': 79258,
#   'Remain': 44987,
#   'Leave': 34271},
#  'S12000015': {'Area_Code': 'S12000015',
#   'Votes_Cast': 182307,
#   'Valid_Votes': 182220,
#   'Remain': 106754,
#   'Leave': 75466},
#  'S12000017': {'Area_Code': 'S12000017',
#   'Votes_Cast': 125728,
#   'Valid_Votes': 125657,
#   'Remain': 70308,
#   'Leave': 55349},
#  'S12000018': {'Area_Code': 'S12000018',
#   'Votes_Cast': 38722,
#   'Valid_Votes': 38698,
#   'Remain': 24688,
#   'Leave': 14010},
#  'S12000019': {'Area_Code': 'S12000019',
#   'Votes_Cast': 45497,
#   'Valid_Votes': 45468,
#   'Remain': 28217,
#   'Leave': 17251},
#  'S12000020': {'Area_Code': 'S12000020',
#   'Votes_Cast': 48139,
#   'Valid_Votes': 48106,
#   'Remain': 24114,
#   'Leave': 23992},
#  'S12000021': {'Area_Code': 'S12000021',
#   'Votes_Cast': 67548,
#   'Valid_Votes': 67504,
#   'Remain': 38394,
#   'Leave': 29110},
#  'S12000023': {'Area_Code': 'S12000023',
#   'Votes_Cast': 11402,
#   'Valid_Votes': 11382,
#   'Remain': 7189,
#   'Leave': 4193},
#  'S12000024': {'Area_Code': 'S12000024',
#   'Votes_Cast': 81294,
#   'Valid_Votes': 81255,
#   'Remain': 49641,
#   'Leave': 31614},
#  'S12000026': {'Area_Code': 'S12000026',
#   'Votes_Cast': 64953,
#   'Valid_Votes': 64914,
#   'Remain': 37952,
#   'Leave': 26962},
#  'S12000027': {'Area_Code': 'S12000027',
#   'Votes_Cast': 12231,
#   'Valid_Votes': 12222,
#   'Remain': 6907,
#   'Leave': 5315},
#  'S12000028': {'Area_Code': 'S12000028',
#   'Votes_Cast': 61542,
#   'Valid_Votes': 61506,
#   'Remain': 36265,
#   'Leave': 25241},
#  'S12000029': {'Area_Code': 'S12000029',
#   'Votes_Cast': 162683,
#   'Valid_Votes': 162592,
#   'Remain': 102568,
#   'Leave': 60024},
#  'S12000030': {'Area_Code': 'S12000030',
#   'Votes_Cast': 48931,
#   'Valid_Votes': 48899,
#   'Remain': 33112,
#   'Leave': 15787},
#  'S12000033': {'Area_Code': 'S12000033',
#   'Votes_Cast': 104809,
#   'Valid_Votes': 104714,
#   'Remain': 63985,
#   'Leave': 40729},
#  'S12000034': {'Area_Code': 'S12000034',
#   'Votes_Cast': 139014,
#   'Valid_Votes': 138961,
#   'Remain': 76445,
#   'Leave': 62516},
#  'S12000035': {'Area_Code': 'S12000035',
#   'Votes_Cast': 48734,
#   'Valid_Votes': 48696,
#   'Remain': 29494,
#   'Leave': 19202},
#  'S12000036': {'Area_Code': 'S12000036',
#   'Votes_Cast': 252481,
#   'Valid_Votes': 252294,
#   'Remain': 187796,
#   'Leave': 64498},
#  'S12000038': {'Area_Code': 'S12000038',
#   'Votes_Cast': 88197,
#   'Valid_Votes': 88129,
#   'Remain': 57119,
#   'Leave': 31010},
#  'S12000039': {'Area_Code': 'S12000039',
#   'Votes_Cast': 43245,
#   'Valid_Votes': 43220,
#   'Remain': 26794,
#   'Leave': 16426},
#  'S12000040': {'Area_Code': 'S12000040',
#   'Votes_Cast': 88556,
#   'Valid_Votes': 88508,
#   'Remain': 51560,
#   'Leave': 36948},
#  'S12000041': {'Area_Code': 'S12000041',
#   'Votes_Cast': 59282,
#   'Valid_Votes': 59258,
#   'Remain': 32747,
#   'Leave': 26511},
#  'S12000042': {'Area_Code': 'S12000042',
#   'Votes_Cast': 66418,
#   'Valid_Votes': 66385,
#   'Remain': 39688,
#   'Leave': 26697},
#  'S12000044': {'Area_Code': 'S12000044',
#   'Votes_Cast': 155045,
#   'Valid_Votes': 154949,
#   'Remain': 95549,
#   'Leave': 59400},
#  'S12000045': {'Area_Code': 'S12000045',
#   'Votes_Cast': 62418,
#   'Valid_Votes': 62374,
#   'Remain': 44534,
#   'Leave': 17840},
#  'S12000046': {'Area_Code': 'S12000046',
#   'Votes_Cast': 253000,
#   'Valid_Votes': 252809,
#   'Remain': 168335,
#   'Leave': 84474},
#  'E06000035': {'Area_Code': 'E06000035',
#   'Votes_Cast': 138973,
#   'Valid_Votes': 138886,
#   'Remain': 49889,
#   'Leave': 88997},
#  'E06000036': {'Area_Code': 'E06000036',
#   'Votes_Cast': 64922,
#   'Valid_Votes': 64890,
#   'Remain': 29888,
#   'Leave': 35002},
#  'E06000037': {'Area_Code': 'E06000037',
#   'Votes_Cast': 93345,
#   'Valid_Votes': 93277,
#   'Remain': 48300,
#   'Leave': 44977},
#  'E06000038': {'Area_Code': 'E06000038',
#   'Votes_Cast': 74826,
#   'Valid_Votes': 74767,
#   'Remain': 43385,
#   'Leave': 31382},
#  'E06000039': {'Area_Code': 'E06000039',
#   'Votes_Cast': 54598,
#   'Valid_Votes': 54542,
#   'Remain': 24911,
#   'Leave': 29631},
#  'E06000040': {'Area_Code': 'E06000040',
#   'Votes_Cast': 81855,
#   'Valid_Votes': 81792,
#   'Remain': 44086,
#   'Leave': 37706},
#  'E06000041': {'Area_Code': 'E06000041',
#   'Votes_Cast': 97551,
#   'Valid_Votes': 97501,
#   'Remain': 55272,
#   'Leave': 42229},
#  'E06000042': {'Area_Code': 'E06000042',
#   'Votes_Cast': 130534,
#   'Valid_Votes': 130456,
#   'Remain': 63393,
#   'Leave': 67063},
#  'E06000043': {'Area_Code': 'E06000043',
#   'Votes_Cast': 146829,
#   'Valid_Votes': 146675,
#   'Remain': 100648,
#   'Leave': 46027},
#  'E06000044': {'Area_Code': 'E06000044',
#   'Votes_Cast': 98786,
#   'Valid_Votes': 98720,
#   'Remain': 41384,
#   'Leave': 57336},
#  'E06000045': {'Area_Code': 'E06000045',
#   'Votes_Cast': 107775,
#   'Valid_Votes': 107665,
#   'Remain': 49738,
#   'Leave': 57927},
#  'E06000046': {'Area_Code': 'E06000046',
#   'Votes_Cast': 79430,
#   'Valid_Votes': 79380,
#   'Remain': 30207,
#   'Leave': 49173},
#  'E07000004': {'Area_Code': 'E07000004',
#   'Votes_Cast': 106895,
#   'Valid_Votes': 106833,
#   'Remain': 52877,
#   'Leave': 53956},
#  'E07000005': {'Area_Code': 'E07000005',
#   'Votes_Cast': 58651,
#   'Valid_Votes': 58604,
#   'Remain': 32241,
#   'Leave': 26363},
#  'E07000006': {'Area_Code': 'E07000006',
#   'Votes_Cast': 40755,
#   'Valid_Votes': 40724,
#   'Remain': 20077,
#   'Leave': 20647},
#  'E07000007': {'Area_Code': 'E07000007',
#   'Votes_Cast': 94869,
#   'Valid_Votes': 94790,
#   'Remain': 49261,
#   'Leave': 45529},
#  'E07000061': {'Area_Code': 'E07000061',
#   'Votes_Cast': 53598,
#   'Valid_Votes': 53545,
#   'Remain': 22845,
#   'Leave': 30700},
#  'E07000062': {'Area_Code': 'E07000062',
#   'Votes_Cast': 44387,
#   'Valid_Votes': 44350,
#   'Remain': 20011,
#   'Leave': 24339},
#  'E07000063': {'Area_Code': 'E07000063',
#   'Votes_Cast': 59531,
#   'Valid_Votes': 59482,
#   'Remain': 30974,
#   'Leave': 28508},
#  'E07000064': {'Area_Code': 'E07000064',
#   'Votes_Cast': 57715,
#   'Valid_Votes': 57669,
#   'Remain': 23916,
#   'Leave': 33753},
#  'E07000065': {'Area_Code': 'E07000065',
#   'Votes_Cast': 96944,
#   'Valid_Votes': 96892,
#   'Remain': 44084,
#   'Leave': 52808},
#  'E07000084': {'Area_Code': 'E07000084',
#   'Votes_Cast': 100395,
#   'Valid_Votes': 100328,
#   'Remain': 48257,
#   'Leave': 52071},
#  'E07000085': {'Area_Code': 'E07000085',
#   'Votes_Cast': 73967,
#   'Valid_Votes': 73922,
#   'Remain': 37346,
#   'Leave': 36576},
#  'E07000086': {'Area_Code': 'E07000086',
#   'Votes_Cast': 76148,
#   'Valid_Votes': 76074,
#   'Remain': 36172,
#   'Leave': 39902},
#  'E07000087': {'Area_Code': 'E07000087',
#   'Votes_Cast': 71772,
#   'Valid_Votes': 71735,
#   'Remain': 32210,
#   'Leave': 39525},
#  'E07000088': {'Area_Code': 'E07000088',
#   'Votes_Cast': 46150,
#   'Valid_Votes': 46127,
#   'Remain': 16671,
#   'Leave': 29456},
#  'E07000089': {'Area_Code': 'E07000089',
#   'Votes_Cast': 57827,
#   'Valid_Votes': 57795,
#   'Remain': 30282,
#   'Leave': 27513},
#  'E07000090': {'Area_Code': 'E07000090',
#   'Votes_Cast': 70670,
#   'Valid_Votes': 70629,
#   'Remain': 26582,
#   'Leave': 44047},
#  'E07000091': {'Area_Code': 'E07000091',
#   'Votes_Cast': 111786,
#   'Valid_Votes': 111740,
#   'Remain': 47199,
#   'Leave': 64541},
#  'E07000092': {'Area_Code': 'E07000092',
#   'Votes_Cast': 48800,
#   'Valid_Votes': 48780,
#   'Remain': 20384,
#   'Leave': 28396},
#  'E07000093': {'Area_Code': 'E07000093',
#   'Votes_Cast': 75316,
#   'Valid_Votes': 75261,
#   'Remain': 36170,
#   'Leave': 39091},
#  'E07000094': {'Area_Code': 'E07000094',
#   'Votes_Cast': 72801,
#   'Valid_Votes': 72764,
#   'Remain': 42878,
#   'Leave': 29886},
#  'E07000105': {'Area_Code': 'E07000105',
#   'Votes_Cast': 69827,
#   'Valid_Votes': 69786,
#   'Remain': 28314,
#   'Leave': 41472},
#  'E07000106': {'Area_Code': 'E07000106',
#   'Votes_Cast': 82105,
#   'Valid_Votes': 82048,
#   'Remain': 40169,
#   'Leave': 41879},
#  'E07000107': {'Area_Code': 'E07000107',
#   'Votes_Cast': 55883,
#   'Valid_Votes': 55855,
#   'Remain': 19985,
#   'Leave': 35870},
#  'E07000108': {'Area_Code': 'E07000108',
#   'Votes_Cast': 65057,
#   'Valid_Votes': 65016,
#   'Remain': 24606,
#   'Leave': 40410},
#  'E07000109': {'Area_Code': 'E07000109',
#   'Votes_Cast': 54553,
#   'Valid_Votes': 54519,
#   'Remain': 18876,
#   'Leave': 35643},
#  'E07000110': {'Area_Code': 'E07000110',
#   'Votes_Cast': 89173,
#   'Valid_Votes': 89127,
#   'Remain': 36762,
#   'Leave': 52365},
#  'E07000111': {'Area_Code': 'E07000111',
#   'Votes_Cast': 70393,
#   'Valid_Votes': 70349,
#   'Remain': 32091,
#   'Leave': 38258},
#  'E07000112': {'Area_Code': 'E07000112',
#   'Votes_Cast': 60659,
#   'Valid_Votes': 60613,
#   'Remain': 22884,
#   'Leave': 37729},
#  'E07000113': {'Area_Code': 'E07000113',
#   'Votes_Cast': 75913,
#   'Valid_Votes': 75869,
#   'Remain': 28481,
#   'Leave': 47388},
#  'E07000114': {'Area_Code': 'E07000114',
#   'Votes_Cast': 72146,
#   'Valid_Votes': 72102,
#   'Remain': 26065,
#   'Leave': 46037},
#  'E07000115': {'Area_Code': 'E07000115',
#   'Votes_Cast': 74066,
#   'Valid_Votes': 74021,
#   'Remain': 32792,
#   'Leave': 41229},
#  'E07000116': {'Area_Code': 'E07000116',
#   'Votes_Cast': 65039,
#   'Valid_Votes': 64996,
#   'Remain': 35676,
#   'Leave': 29320},
#  'E07000177': {'Area_Code': 'E07000177',
#   'Votes_Cast': 81908,
#   'Valid_Votes': 81836,
#   'Remain': 40668,
#   'Leave': 41168},
#  'E07000178': {'Area_Code': 'E07000178',
#   'Votes_Cast': 70411,
#   'Valid_Votes': 70337,
#   'Remain': 49424,
#   'Leave': 20913},
#  'E07000179': {'Area_Code': 'E07000179',
#   'Votes_Cast': 84167,
#   'Valid_Votes': 84110,
#   'Remain': 46245,
#   'Leave': 37865},
#  'E07000180': {'Area_Code': 'E07000180',
#   'Votes_Cast': 76706,
#   'Valid_Votes': 76654,
#   'Remain': 43462,
#   'Leave': 33192},
#  'E07000181': {'Area_Code': 'E07000181',
#   'Votes_Cast': 65719,
#   'Valid_Votes': 65671,
#   'Remain': 35236,
#   'Leave': 30435},
#  'E07000207': {'Area_Code': 'E07000207',
#   'Votes_Cast': 77058,
#   'Valid_Votes': 77003,
#   'Remain': 45841,
#   'Leave': 31162},
#  'E07000208': {'Area_Code': 'E07000208',
#   'Votes_Cast': 45343,
#   'Valid_Votes': 45303,
#   'Remain': 23596,
#   'Leave': 21707},
#  'E07000209': {'Area_Code': 'E07000209',
#   'Votes_Cast': 78657,
#   'Valid_Votes': 78613,
#   'Remain': 44155,
#   'Leave': 34458},
#  'E07000210': {'Area_Code': 'E07000210',
#   'Votes_Cast': 54829,
#   'Valid_Votes': 54796,
#   'Remain': 29088,
#   'Leave': 25708},
#  'E07000211': {'Area_Code': 'E07000211',
#   'Votes_Cast': 81200,
#   'Valid_Votes': 81161,
#   'Remain': 40181,
#   'Leave': 40980},
#  'E07000212': {'Area_Code': 'E07000212',
#   'Votes_Cast': 44326,
#   'Valid_Votes': 44294,
#   'Remain': 20259,
#   'Leave': 24035},
#  'E07000213': {'Area_Code': 'E07000213',
#   'Votes_Cast': 56638,
#   'Valid_Votes': 56609,
#   'Remain': 22474,
#   'Leave': 34135},
#  'E07000214': {'Area_Code': 'E07000214',
#   'Votes_Cast': 52330,
#   'Valid_Votes': 52305,
#   'Remain': 25638,
#   'Leave': 26667},
#  'E07000215': {'Area_Code': 'E07000215',
#   'Votes_Cast': 51466,
#   'Valid_Votes': 51420,
#   'Remain': 24251,
#   'Leave': 27169},
#  'E07000216': {'Area_Code': 'E07000216',
#   'Votes_Cast': 75999,
#   'Valid_Votes': 75942,
#   'Remain': 44341,
#   'Leave': 31601},
#  'E07000217': {'Area_Code': 'E07000217',
#   'Votes_Cast': 55261,
#   'Valid_Votes': 55221,
#   'Remain': 31007,
#   'Leave': 24214},
#  'E07000223': {'Area_Code': 'E07000223',
#   'Votes_Cast': 37251,
#   'Valid_Votes': 37229,
#   'Remain': 16914,
#   'Leave': 20315},
#  'E07000224': {'Area_Code': 'E07000224',
#   'Votes_Cast': 91199,
#   'Valid_Votes': 91129,
#   'Remain': 34193,
#   'Leave': 56936},
#  'E07000225': {'Area_Code': 'E07000225',
#   'Votes_Cast': 71407,
#   'Valid_Votes': 71337,
#   'Remain': 35011,
#   'Leave': 36326},
#  'E07000226': {'Area_Code': 'E07000226',
#   'Votes_Cast': 53884,
#   'Valid_Votes': 53835,
#   'Remain': 22388,
#   'Leave': 31447},
#  'E07000227': {'Area_Code': 'E07000227',
#   'Votes_Cast': 85132,
#   'Valid_Votes': 85088,
#   'Remain': 43785,
#   'Leave': 41303},
#  'E07000228': {'Area_Code': 'E07000228',
#   'Votes_Cast': 87588,
#   'Valid_Votes': 87528,
#   'Remain': 46471,
#   'Leave': 41057},
#  'E07000229': {'Area_Code': 'E07000229',
#   'Votes_Cast': 61416,
#   'Valid_Votes': 61366,
#   'Remain': 28851,
#   'Leave': 32515},
#  'E06000022': {'Area_Code': 'E06000022',
#   'Votes_Cast': 105300,
#   'Valid_Votes': 105230,
#   'Remain': 60878,
#   'Leave': 44352},
#  'E06000023': {'Area_Code': 'E06000023',
#   'Votes_Cast': 228646,
#   'Valid_Votes': 228445,
#   'Remain': 141027,
#   'Leave': 87418},
#  'E06000024': {'Area_Code': 'E06000024',
#   'Votes_Cast': 124622,
#   'Valid_Votes': 124548,
#   'Remain': 59572,
#   'Leave': 64976},
#  'E06000025': {'Area_Code': 'E06000025',
#   'Votes_Cast': 158427,
#   'Valid_Votes': 158333,
#   'Remain': 74928,
#   'Leave': 83405},
#  'E06000026': {'Area_Code': 'E06000026',
#   'Votes_Cast': 133523,
#   'Valid_Votes': 133455,
#   'Remain': 53458,
#   'Leave': 79997},
#  'E06000027': {'Area_Code': 'E06000027',
#   'Votes_Cast': 75868,
#   'Valid_Votes': 75824,
#   'Remain': 27935,
#   'Leave': 47889},
#  'E06000028': {'Area_Code': 'E06000028',
#   'Votes_Cast': 91997,
#   'Valid_Votes': 91926,
#   'Remain': 41473,
#   'Leave': 50453},
#  'E06000029': {'Area_Code': 'E06000029',
#   'Votes_Cast': 85493,
#   'Valid_Votes': 85448,
#   'Remain': 35741,
#   'Leave': 49707},
#  'E06000030': {'Area_Code': 'E06000030',
#   'Votes_Cast': 113060,
#   'Valid_Votes': 112965,
#   'Remain': 51220,
#   'Leave': 61745},
#  'E06000052': {'Area_Code': 'E06000052',
#   'Votes_Cast': 323442,
#   'Valid_Votes': 323205,
#   'Remain': 140540,
#   'Leave': 182665},
#  'E06000053': {'Area_Code': 'E06000053',
#   'Votes_Cast': 1424,
#   'Valid_Votes': 1424,
#   'Remain': 803,
#   'Leave': 621},
#  'E06000054': {'Area_Code': 'E06000054',
#   'Votes_Cast': 289102,
#   'Valid_Votes': 288895,
#   'Remain': 137258,
#   'Leave': 151637},
#  'E07000040': {'Area_Code': 'E07000040',
#   'Votes_Cast': 88831,
#   'Valid_Votes': 88783,
#   'Remain': 40743,
#   'Leave': 48040},
#  'E07000041': {'Area_Code': 'E07000041',
#   'Votes_Cast': 63867,
#   'Valid_Votes': 63803,
#   'Remain': 35270,
#   'Leave': 28533},
#  'E07000042': {'Area_Code': 'E07000042',
#   'Votes_Cast': 48049,
#   'Valid_Votes': 48006,
#   'Remain': 22400,
#   'Leave': 25606},
#  'E07000043': {'Area_Code': 'E07000043',
#   'Votes_Cast': 58056,
#   'Valid_Votes': 58031,
#   'Remain': 24931,
#   'Leave': 33100},
#  'E07000044': {'Area_Code': 'E07000044',
#   'Votes_Cast': 55485,
#   'Valid_Votes': 55450,
#   'Remain': 29308,
#   'Leave': 26142},
#  'E07000045': {'Area_Code': 'E07000045',
#   'Votes_Cast': 82369,
#   'Valid_Votes': 82312,
#   'Remain': 37949,
#   'Leave': 44363},
#  'E07000046': {'Area_Code': 'E07000046',
#   'Votes_Cast': 41462,
#   'Valid_Votes': 41429,
#   'Remain': 16229,
#   'Leave': 25200},
#  'E07000047': {'Area_Code': 'E07000047',
#   'Votes_Cast': 35612,
#   'Valid_Votes': 35595,
#   'Remain': 16658,
#   'Leave': 18937},
#  'E07000048': {'Area_Code': 'E07000048',
#   'Votes_Cast': 31066,
#   'Valid_Votes': 31050,
#   'Remain': 12782,
#   'Leave': 18268},
#  'E07000049': {'Area_Code': 'E07000049',
#   'Votes_Cast': 58530,
#   'Valid_Votes': 58488,
#   'Remain': 24786,
#   'Leave': 33702},
#  'E07000050': {'Area_Code': 'E07000050',
#   'Votes_Cast': 42228,
#   'Valid_Votes': 42201,
#   'Remain': 18399,
#   'Leave': 23802},
#  'E07000051': {'Area_Code': 'E07000051',
#   'Votes_Cast': 28736,
#   'Valid_Votes': 28720,
#   'Remain': 11754,
#   'Leave': 16966},
#  'E07000052': {'Area_Code': 'E07000052',
#   'Votes_Cast': 65237,
#   'Valid_Votes': 65191,
#   'Remain': 31924,
#   'Leave': 33267},
#  'E07000053': {'Area_Code': 'E07000053',
#   'Votes_Cast': 38271,
#   'Valid_Votes': 38255,
#   'Remain': 14903,
#   'Leave': 23352},
#  'E07000078': {'Area_Code': 'E07000078',
#   'Votes_Cast': 66057,
#   'Valid_Votes': 66013,
#   'Remain': 37081,
#   'Leave': 28932},
#  'E07000079': {'Area_Code': 'E07000079',
#   'Votes_Cast': 54847,
#   'Valid_Votes': 54821,
#   'Remain': 28015,
#   'Leave': 26806},
#  'E07000080': {'Area_Code': 'E07000080',
#   'Votes_Cast': 51677,
#   'Valid_Votes': 51643,
#   'Remain': 21392,
#   'Leave': 30251},
#  'E07000081': {'Area_Code': 'E07000081',
#   'Votes_Cast': 64606,
#   'Valid_Votes': 64577,
#   'Remain': 26801,
#   'Leave': 37776},
#  'E07000082': {'Area_Code': 'E07000082',
#   'Votes_Cast': 74128,
#   'Valid_Votes': 74064,
#   'Remain': 40446,
#   'Leave': 33618},
#  'E07000083': {'Area_Code': 'E07000083',
#   'Votes_Cast': 53686,
#   'Valid_Votes': 53652,
#   'Remain': 25084,
#   'Leave': 28568},
#  'E07000187': {'Area_Code': 'E07000187',
#   'Votes_Cast': 65509,
#   'Valid_Votes': 65455,
#   'Remain': 33427,
#   'Leave': 32028},
#  'E07000188': {'Area_Code': 'E07000188',
#   'Votes_Cast': 68450,
#   'Valid_Votes': 68414,
#   'Remain': 26545,
#   'Leave': 41869},
#  'E07000189': {'Area_Code': 'E07000189',
#   'Votes_Cast': 99535,
#   'Valid_Votes': 99467,
#   'Remain': 42527,
#   'Leave': 56940},
#  'E07000190': {'Area_Code': 'E07000190',
#   'Votes_Cast': 65786,
#   'Valid_Votes': 65733,
#   'Remain': 30944,
#   'Leave': 34789},
#  'E07000191': {'Area_Code': 'E07000191',
#   'Votes_Cast': 21753,
#   'Valid_Votes': 21734,
#   'Remain': 8566,
#   'Leave': 13168},
#  'GI': {'Area_Code': 'GI',
#   'Votes_Cast': 20172,
#   'Valid_Votes': 20145,
#   'Remain': 19322,
#   'Leave': 823},
#  'W06000001': {'Area_Code': 'W06000001',
#   'Votes_Cast': 37978,
#   'Valid_Votes': 37951,
#   'Remain': 18618,
#   'Leave': 19333},
#  'W06000002': {'Area_Code': 'W06000002',
#   'Votes_Cast': 61245,
#   'Valid_Votes': 61182,
#   'Remain': 35517,
#   'Leave': 25665},
#  'W06000003': {'Area_Code': 'W06000003',
#   'Votes_Cast': 65554,
#   'Valid_Votes': 65504,
#   'Remain': 30147,
#   'Leave': 35357},
#  'W06000004': {'Area_Code': 'W06000004',
#   'Votes_Cast': 52108,
#   'Valid_Votes': 52072,
#   'Remain': 23955,
#   'Leave': 28117},
#  'W06000005': {'Area_Code': 'W06000005',
#   'Votes_Cast': 86854,
#   'Valid_Votes': 86797,
#   'Remain': 37867,
#   'Leave': 48930},
#  'W06000006': {'Area_Code': 'W06000006',
#   'Votes_Cast': 70407,
#   'Valid_Votes': 70366,
#   'Remain': 28822,
#   'Leave': 41544},
#  'W06000008': {'Area_Code': 'W06000008',
#   'Votes_Cast': 39772,
#   'Valid_Votes': 39742,
#   'Remain': 21711,
#   'Leave': 18031},
#  'W06000009': {'Area_Code': 'W06000009',
#   'Votes_Cast': 68555,
#   'Valid_Votes': 68522,
#   'Remain': 29367,
#   'Leave': 39155},
#  'W06000010': {'Area_Code': 'W06000010',
#   'Votes_Cast': 103126,
#   'Valid_Votes': 103035,
#   'Remain': 47654,
#   'Leave': 55381},
#  'W06000011': {'Area_Code': 'W06000011',
#   'Votes_Cast': 120362,
#   'Valid_Votes': 120243,
#   'Remain': 58307,
#   'Leave': 61936},
#  'W06000012': {'Area_Code': 'W06000012',
#   'Votes_Cast': 75694,
#   'Valid_Votes': 75652,
#   'Remain': 32651,
#   'Leave': 43001},
#  'W06000013': {'Area_Code': 'W06000013',
#   'Votes_Cast': 74378,
#   'Valid_Votes': 74345,
#   'Remain': 33723,
#   'Leave': 40622},
#  'W06000014': {'Area_Code': 'W06000014',
#   'Votes_Cast': 72348,
#   'Valid_Votes': 72309,
#   'Remain': 36681,
#   'Leave': 35628},
#  'W06000015': {'Area_Code': 'W06000015',
#   'Votes_Cast': 169745,
#   'Valid_Votes': 169604,
#   'Remain': 101788,
#   'Leave': 67816},
#  'W06000016': {'Area_Code': 'W06000016',
#   'Votes_Cast': 116645,
#   'Valid_Votes': 116563,
#   'Remain': 53973,
#   'Leave': 62590},
#  'W06000018': {'Area_Code': 'W06000018',
#   'Votes_Cast': 92525,
#   'Valid_Votes': 92473,
#   'Remain': 39178,
#   'Leave': 53295},
#  'W06000019': {'Area_Code': 'W06000019',
#   'Votes_Cast': 34812,
#   'Valid_Votes': 34802,
#   'Remain': 13215,
#   'Leave': 21587},
#  'W06000020': {'Area_Code': 'W06000020',
#   'Votes_Cast': 48172,
#   'Valid_Votes': 48144,
#   'Remain': 19363,
#   'Leave': 28781},
#  'W06000021': {'Area_Code': 'W06000021',
#   'Votes_Cast': 55670,
#   'Valid_Votes': 55630,
#   'Remain': 28061,
#   'Leave': 27569},
#  'W06000022': {'Area_Code': 'W06000022',
#   'Votes_Cast': 73708,
#   'Valid_Votes': 73649,
#   'Remain': 32413,
#   'Leave': 41236},
#  'W06000023': {'Area_Code': 'W06000023',
#   'Votes_Cast': 79515,
#   'Valid_Votes': 79469,
#   'Remain': 36762,
#   'Leave': 42707},
#  'W06000024': {'Area_Code': 'W06000024',
#   'Votes_Cast': 28881,
#   'Valid_Votes': 28865,
#   'Remain': 12574,
#   'Leave': 16291},
#  'E06000019': {'Area_Code': 'E06000019',
#   'Votes_Cast': 108336,
#   'Valid_Votes': 108270,
#   'Remain': 44148,
#   'Leave': 64122},
#  'E06000020': {'Area_Code': 'E06000020',
#   'Votes_Cast': 89704,
#   'Valid_Votes': 89603,
#   'Remain': 32954,
#   'Leave': 56649},
#  'E06000021': {'Area_Code': 'E06000021',
#   'Votes_Cast': 117674,
#   'Valid_Votes': 117590,
#   'Remain': 36027,
#   'Leave': 81563},
#  'E06000051': {'Area_Code': 'E06000051',
#   'Votes_Cast': 183323,
#   'Valid_Votes': 183153,
#   'Remain': 78987,
#   'Leave': 104166},
#  'E07000192': {'Area_Code': 'E07000192',
#   'Votes_Cast': 53607,
#   'Valid_Votes': 53578,
#   'Remain': 16684,
#   'Leave': 36894},
#  'E07000193': {'Area_Code': 'E07000193',
#   'Votes_Cast': 62161,
#   'Valid_Votes': 62116,
#   'Remain': 22850,
#   'Leave': 39266},
#  'E07000194': {'Area_Code': 'E07000194',
#   'Votes_Cast': 63318,
#   'Valid_Votes': 63278,
#   'Remain': 26064,
#   'Leave': 37214},
#  'E07000195': {'Area_Code': 'E07000195',
#   'Votes_Cast': 68966,
#   'Valid_Votes': 68934,
#   'Remain': 25477,
#   'Leave': 43457},
#  'E07000196': {'Area_Code': 'E07000196',
#   'Votes_Cast': 66739,
#   'Valid_Votes': 66692,
#   'Remain': 23444,
#   'Leave': 43248},
#  'E07000197': {'Area_Code': 'E07000197',
#   'Votes_Cast': 77527,
#   'Valid_Votes': 77484,
#   'Remain': 34098,
#   'Leave': 43386},
#  'E07000198': {'Area_Code': 'E07000198',
#   'Votes_Cast': 59793,
#   'Valid_Votes': 59760,
#   'Remain': 21076,
#   'Leave': 38684},
#  'E07000199': {'Area_Code': 'E07000199',
#   'Votes_Cast': 42151,
#   'Valid_Votes': 42129,
#   'Remain': 13705,
#   'Leave': 28424},
#  'E07000218': {'Area_Code': 'E07000218',
#   'Votes_Cast': 37975,
#   'Valid_Votes': 37954,
#   'Remain': 12569,
#   'Leave': 25385},
#  'E07000219': {'Area_Code': 'E07000219',
#   'Votes_Cast': 69876,
#   'Valid_Votes': 69831,
#   'Remain': 23736,
#   'Leave': 46095},
#  'E07000220': {'Area_Code': 'E07000220',
#   'Votes_Cast': 58593,
#   'Valid_Votes': 58549,
#   'Remain': 25350,
#   'Leave': 33199},
#  'E07000221': {'Area_Code': 'E07000221',
#   'Votes_Cast': 79217,
#   'Valid_Votes': 79158,
#   'Remain': 38341,
#   'Leave': 40817},
#  'E07000222': {'Area_Code': 'E07000222',
#   'Votes_Cast': 81680,
#   'Valid_Votes': 81618,
#   'Remain': 47976,
#   'Leave': 33642},
#  'E07000234': {'Area_Code': 'E07000234',
#   'Votes_Cast': 58855,
#   'Valid_Votes': 58815,
#   'Remain': 26252,
#   'Leave': 32563},
#  'E07000235': {'Area_Code': 'E07000235',
#   'Votes_Cast': 48538,
#   'Valid_Votes': 48497,
#   'Remain': 23203,
#   'Leave': 25294},
#  'E07000236': {'Area_Code': 'E07000236',
#   'Votes_Cast': 45912,
#   'Valid_Votes': 45882,
#   'Remain': 17303,
#   'Leave': 28579},
#  'E07000237': {'Area_Code': 'E07000237',
#   'Votes_Cast': 54290,
#   'Valid_Votes': 54239,
#   'Remain': 25125,
#   'Leave': 29114},
#  'E07000238': {'Area_Code': 'E07000238',
#   'Votes_Cast': 76425,
#   'Valid_Votes': 76389,
#   'Remain': 32188,
#   'Leave': 44201},
#  'E07000239': {'Area_Code': 'E07000239',
#   'Votes_Cast': 57666,
#   'Valid_Votes': 57632,
#   'Remain': 21240,
#   'Leave': 36392},
#  'E08000025': {'Area_Code': 'E08000025',
#   'Votes_Cast': 451316,
#   'Valid_Votes': 450702,
#   'Remain': 223451,
#   'Leave': 227251},
#  'E08000026': {'Area_Code': 'E08000026',
#   'Votes_Cast': 153234,
#   'Valid_Votes': 153064,
#   'Remain': 67967,
#   'Leave': 85097},
#  'E08000027': {'Area_Code': 'E08000027',
#   'Votes_Cast': 175333,
#   'Valid_Votes': 175226,
#   'Remain': 56780,
#   'Leave': 118446},
#  'E08000028': {'Area_Code': 'E08000028',
#   'Votes_Cast': 147418,
#   'Valid_Votes': 147254,
#   'Remain': 49004,
#   'Leave': 98250},
#  'E08000029': {'Area_Code': 'E08000029',
#   'Votes_Cast': 122020,
#   'Valid_Votes': 121950,
#   'Remain': 53466,
#   'Leave': 68484},
#  'E08000030': {'Area_Code': 'E08000030',
#   'Votes_Cast': 135685,
#   'Valid_Votes': 135579,
#   'Remain': 43572,
#   'Leave': 92007},
#  'E08000031': {'Area_Code': 'E08000031',
#   'Votes_Cast': 118037,
#   'Valid_Votes': 117936,
#   'Remain': 44138,
#   'Leave': 73798},
#  'E06000010': {'Area_Code': 'E06000010',
#   'Votes_Cast': 113436,
#   'Valid_Votes': 113355,
#   'Remain': 36709,
#   'Leave': 76646},
#  'E06000011': {'Area_Code': 'E06000011',
#   'Votes_Cast': 199036,
#   'Valid_Votes': 198915,
#   'Remain': 78779,
#   'Leave': 120136},
#  'E06000012': {'Area_Code': 'E06000012',
#   'Votes_Cast': 79011,
#   'Valid_Votes': 78982,
#   'Remain': 23797,
#   'Leave': 55185},
#  'E06000013': {'Area_Code': 'E06000013',
#   'Votes_Cast': 88906,
#   'Valid_Votes': 88862,
#   'Remain': 29947,
#   'Leave': 58915},
#  'E06000014': {'Area_Code': 'E06000014',
#   'Votes_Cast': 109681,
#   'Valid_Votes': 109600,
#   'Remain': 63617,
#   'Leave': 45983},
#  'E07000163': {'Area_Code': 'E07000163',
#   'Votes_Cast': 35907,
#   'Valid_Votes': 35891,
#   'Remain': 16930,
#   'Leave': 18961},
#  'E07000164': {'Area_Code': 'E07000164',
#   'Votes_Cast': 55016,
#   'Valid_Votes': 54982,
#   'Remain': 25480,
#   'Leave': 29502},
#  'E07000165': {'Area_Code': 'E07000165',
#   'Votes_Cast': 94653,
#   'Valid_Votes': 94585,
#   'Remain': 48211,
#   'Leave': 46374},
#  'E07000166': {'Area_Code': 'E07000166',
#   'Votes_Cast': 27652,
#   'Valid_Votes': 27636,
#   'Remain': 11945,
#   'Leave': 15691},
#  'E07000167': {'Area_Code': 'E07000167',
#   'Votes_Cast': 32069,
#   'Valid_Votes': 32050,
#   'Remain': 14340,
#   'Leave': 17710},
#  'E07000168': {'Area_Code': 'E07000168',
#   'Votes_Cast': 60539,
#   'Valid_Votes': 60511,
#   'Remain': 22999,
#   'Leave': 37512},
#  'E07000169': {'Area_Code': 'E07000169',
#   'Votes_Cast': 51636,
#   'Valid_Votes': 51603,
#   'Remain': 21071,
#   'Leave': 30532},
#  'E08000016': {'Area_Code': 'E08000016',
#   'Votes_Cast': 122972,
#   'Valid_Votes': 122909,
#   'Remain': 38951,
#   'Leave': 83958},
#  'E08000017': {'Area_Code': 'E08000017',
#   'Votes_Cast': 151246,
#   'Valid_Votes': 151182,
#   'Remain': 46922,
#   'Leave': 104260},
#  'E08000018': {'Area_Code': 'E08000018',
#   'Votes_Cast': 137470,
#   'Valid_Votes': 137387,
#   'Remain': 44115,
#   'Leave': 93272},
#  'E08000019': {'Area_Code': 'E08000019',
#   'Votes_Cast': 266951,
#   'Valid_Votes': 266753,
#   'Remain': 130735,
#   'Leave': 136018},
#  'E08000032': {'Area_Code': 'E08000032',
#   'Votes_Cast': 228727,
#   'Valid_Votes': 228488,
#   'Remain': 104575,
#   'Leave': 123913},
#  'E08000033': {'Area_Code': 'E08000033',
#   'Votes_Cast': 106004,
#   'Valid_Votes': 105925,
#   'Remain': 46950,
#   'Leave': 58975},
#  'E08000034': {'Area_Code': 'E08000034',
#   'Votes_Cast': 217428,
#   'Valid_Votes': 217240,
#   'Remain': 98485,
#   'Leave': 118755},
#  'E08000035': {'Area_Code': 'E08000035',
#   'Votes_Cast': 387677,
#   'Valid_Votes': 387337,
#   'Remain': 194863,
#   'Leave': 192474},
#  'E08000036': {'Area_Code': 'E08000036',
#   'Votes_Cast': 175155,
#   'Valid_Votes': 175042,
#   'Remain': 58877,
#   'Leave': 116165}}

# %%
merged_list = [v for k,v in merged_dict.items()]
merged_list
# Out:
# [{'Area_Code': 'E06000031',
#   'Area': 'Peterborough',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 120892,
#   'Votes_Cast': 87469,
#   'Valid_Votes': 87392,
#   'Remain': 34176,
#   'Leave': 53216,
#   'Rejected_Ballots': 77,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 32,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 38},
#  {'Area_Code': 'E06000032',
#   'Area': 'Luton',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 127612,
#   'Votes_Cast': 84616,
#   'Valid_Votes': 84481,
#   'Remain': 36708,
#   'Leave': 47773,
#   'Rejected_Ballots': 135,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 85,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 50},
#  {'Area_Code': 'E06000033',
#   'Area': 'Southend-on-Sea',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 128856,
#   'Votes_Cast': 93939,
#   'Valid_Votes': 93870,
#   'Remain': 39348,
#   'Leave': 54522,
#   'Rejected_Ballots': 69,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 21,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 48},
#  {'Area_Code': 'E06000034',
#   'Area': 'Thurrock',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 109897,
#   'Votes_Cast': 79950,
#   'Valid_Votes': 79916,
#   'Remain': 22151,
#   'Leave': 57765,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 8,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 23},
#  {'Area_Code': 'E06000055',
#   'Area': 'Bedford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 119530,
#   'Votes_Cast': 86135,
#   'Valid_Votes': 86066,
#   'Remain': 41497,
#   'Leave': 44569,
#   'Rejected_Ballots': 69,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 26,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 42},
#  {'Area_Code': 'E06000056',
#   'Area': 'Central Bedfordshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 204004,
#   'Votes_Cast': 158894,
#   'Valid_Votes': 158804,
#   'Remain': 69670,
#   'Leave': 89134,
#   'Rejected_Ballots': 90,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 34,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 55},
#  {'Area_Code': 'E07000008',
#   'Area': 'Cambridge',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 80108,
#   'Votes_Cast': 57852,
#   'Valid_Votes': 57799,
#   'Remain': 42682,
#   'Leave': 15117,
#   'Rejected_Ballots': 53,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 40},
#  {'Area_Code': 'E07000009',
#   'Area': 'East Cambridgeshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 62435,
#   'Votes_Cast': 48124,
#   'Valid_Votes': 48086,
#   'Remain': 23599,
#   'Leave': 24487,
#   'Rejected_Ballots': 38,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 18,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 20},
#  {'Area_Code': 'E07000010',
#   'Area': 'Fenland',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 71447,
#   'Votes_Cast': 52649,
#   'Valid_Votes': 52626,
#   'Remain': 15055,
#   'Leave': 37571,
#   'Rejected_Ballots': 23,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 12},
#  {'Area_Code': 'E07000011',
#   'Area': 'Huntingdonshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 128486,
#   'Votes_Cast': 99990,
#   'Valid_Votes': 99927,
#   'Remain': 45729,
#   'Leave': 54198,
#   'Rejected_Ballots': 63,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 31,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 32},
#  {'Area_Code': 'E07000012',
#   'Area': 'South Cambridgeshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 114830,
#   'Votes_Cast': 93250,
#   'Valid_Votes': 93189,
#   'Remain': 56128,
#   'Leave': 37061,
#   'Rejected_Ballots': 61,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 24,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 37},
#  {'Area_Code': 'E07000066',
#   'Area': 'Basildon',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 132771,
#   'Votes_Cast': 98062,
#   'Valid_Votes': 97999,
#   'Remain': 30748,
#   'Leave': 67251,
#   'Rejected_Ballots': 63,
#   'No_official_mark': 3,
#   'Voting_for_both_answers': 26,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 32},
#  {'Area_Code': 'E07000067',
#   'Area': 'Braintree',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 112562,
#   'Votes_Cast': 86303,
#   'Valid_Votes': 86236,
#   'Remain': 33523,
#   'Leave': 52713,
#   'Rejected_Ballots': 67,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 23,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 44},
#  {'Area_Code': 'E07000068',
#   'Area': 'Brentwood',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 58777,
#   'Votes_Cast': 46725,
#   'Valid_Votes': 46704,
#   'Remain': 19077,
#   'Leave': 27627,
#   'Rejected_Ballots': 21,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 3,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 17},
#  {'Area_Code': 'E07000069',
#   'Area': 'Castle Point',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 68860,
#   'Votes_Cast': 51909,
#   'Valid_Votes': 51845,
#   'Remain': 14154,
#   'Leave': 37691,
#   'Rejected_Ballots': 64,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 48},
#  {'Area_Code': 'E07000070',
#   'Area': 'Chelmsford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 129971,
#   'Votes_Cast': 100852,
#   'Valid_Votes': 100794,
#   'Remain': 47545,
#   'Leave': 53249,
#   'Rejected_Ballots': 58,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 23,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 33},
#  {'Area_Code': 'E07000071',
#   'Area': 'Colchester',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 127520,
#   'Votes_Cast': 95782,
#   'Valid_Votes': 95719,
#   'Remain': 44414,
#   'Leave': 51305,
#   'Rejected_Ballots': 63,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 39},
#  {'Area_Code': 'E07000072',
#   'Area': 'Epping Forest',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 100016,
#   'Votes_Cast': 76900,
#   'Valid_Votes': 76852,
#   'Remain': 28676,
#   'Leave': 48176,
#   'Rejected_Ballots': 48,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 21,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 25},
#  {'Area_Code': 'E07000073',
#   'Area': 'Harlow',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 59124,
#   'Votes_Cast': 43489,
#   'Valid_Votes': 43469,
#   'Remain': 13867,
#   'Leave': 29602,
#   'Rejected_Ballots': 20,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 1,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 19},
#  {'Area_Code': 'E07000074',
#   'Area': 'Maldon',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 49073,
#   'Votes_Cast': 38850,
#   'Valid_Votes': 38831,
#   'Remain': 14529,
#   'Leave': 24302,
#   'Rejected_Ballots': 19,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 8},
#  {'Area_Code': 'E07000075',
#   'Area': 'Rochford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 66589,
#   'Votes_Cast': 52479,
#   'Valid_Votes': 52447,
#   'Remain': 17510,
#   'Leave': 34937,
#   'Rejected_Ballots': 32,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 18},
#  {'Area_Code': 'E07000076',
#   'Area': 'Tendring',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 111167,
#   'Votes_Cast': 82703,
#   'Valid_Votes': 82657,
#   'Remain': 25210,
#   'Leave': 57447,
#   'Rejected_Ballots': 46,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 27},
#  {'Area_Code': 'E07000077',
#   'Area': 'Uttlesford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 64735,
#   'Votes_Cast': 51972,
#   'Valid_Votes': 51943,
#   'Remain': 25619,
#   'Leave': 26324,
#   'Rejected_Ballots': 29,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 5,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 24},
#  {'Area_Code': 'E07000095',
#   'Area': 'Broxbourne',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 68997,
#   'Votes_Cast': 50907,
#   'Valid_Votes': 50872,
#   'Remain': 17166,
#   'Leave': 33706,
#   'Rejected_Ballots': 35,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 21},
#  {'Area_Code': 'E07000096',
#   'Area': 'Dacorum',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 108965,
#   'Votes_Cast': 86307,
#   'Valid_Votes': 86244,
#   'Remain': 42542,
#   'Leave': 43702,
#   'Rejected_Ballots': 63,
#   'No_official_mark': 4,
#   'Voting_for_both_answers': 24,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 35},
#  {'Area_Code': 'E07000098',
#   'Area': 'Hertsmere',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 73295,
#   'Votes_Cast': 56159,
#   'Valid_Votes': 56125,
#   'Remain': 27593,
#   'Leave': 28532,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 12,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 22},
#  {'Area_Code': 'E07000099',
#   'Area': 'North Hertfordshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 99316,
#   'Votes_Cast': 77737,
#   'Valid_Votes': 77672,
#   'Remain': 42234,
#   'Leave': 35438,
#   'Rejected_Ballots': 65,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 29,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 35},
#  {'Area_Code': 'E07000102',
#   'Area': 'Three Rivers',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 67380,
#   'Votes_Cast': 52896,
#   'Valid_Votes': 52848,
#   'Remain': 25751,
#   'Leave': 27097,
#   'Rejected_Ballots': 48,
#   'No_official_mark': 4,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 25},
#  {'Area_Code': 'E07000103',
#   'Area': 'Watford',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 65060,
#   'Votes_Cast': 46635,
#   'Valid_Votes': 46586,
#   'Remain': 23167,
#   'Leave': 23419,
#   'Rejected_Ballots': 49,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 23,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 22},
#  {'Area_Code': 'E07000143',
#   'Area': 'Breckland',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 98989,
#   'Votes_Cast': 73593,
#   'Valid_Votes': 73548,
#   'Remain': 26313,
#   'Leave': 47235,
#   'Rejected_Ballots': 45,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 35},
#  {'Area_Code': 'E07000144',
#   'Area': 'Broadland',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 99254,
#   'Votes_Cast': 77781,
#   'Valid_Votes': 77737,
#   'Remain': 35469,
#   'Leave': 42268,
#   'Rejected_Ballots': 44,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 0,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 44},
#  {'Area_Code': 'E07000145',
#   'Area': 'Great Yarmouth',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 72634,
#   'Votes_Cast': 50158,
#   'Valid_Votes': 50128,
#   'Remain': 14284,
#   'Leave': 35844,
#   'Rejected_Ballots': 30,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 9},
#  {'Area_Code': 'E07000146',
#   'Area': "King's Lynn and West Norfolk",
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 113884,
#   'Votes_Cast': 85128,
#   'Valid_Votes': 85080,
#   'Remain': 28587,
#   'Leave': 56493,
#   'Rejected_Ballots': 48,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 32},
#  {'Area_Code': 'E07000147',
#   'Area': 'North Norfolk',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 83065,
#   'Votes_Cast': 63829,
#   'Valid_Votes': 63790,
#   'Remain': 26214,
#   'Leave': 37576,
#   'Rejected_Ballots': 39,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 4,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 33},
#  {'Area_Code': 'E07000148',
#   'Area': 'Norwich',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 96091,
#   'Votes_Cast': 66422,
#   'Valid_Votes': 66366,
#   'Remain': 37326,
#   'Leave': 29040,
#   'Rejected_Ballots': 56,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 38},
#  {'Area_Code': 'E07000149',
#   'Area': 'South Norfolk',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 102395,
#   'Votes_Cast': 80418,
#   'Valid_Votes': 80358,
#   'Remain': 38817,
#   'Leave': 41541,
#   'Rejected_Ballots': 60,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 24,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 35},
#  {'Area_Code': 'E07000200',
#   'Area': 'Babergh',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 70628,
#   'Votes_Cast': 55272,
#   'Valid_Votes': 55242,
#   'Remain': 25309,
#   'Leave': 29933,
#   'Rejected_Ballots': 30,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 17},
#  {'Area_Code': 'E07000201',
#   'Area': 'Forest Heath',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 38527,
#   'Votes_Cast': 27977,
#   'Valid_Votes': 27951,
#   'Remain': 9791,
#   'Leave': 18160,
#   'Rejected_Ballots': 26,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 4,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 18},
#  {'Area_Code': 'E07000202',
#   'Area': 'Ipswich',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 91574,
#   'Votes_Cast': 66400,
#   'Valid_Votes': 66353,
#   'Remain': 27698,
#   'Leave': 38655,
#   'Rejected_Ballots': 47,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 1,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 39},
#  {'Area_Code': 'E07000203',
#   'Area': 'Mid Suffolk',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 78325,
#   'Votes_Cast': 61222,
#   'Valid_Votes': 61185,
#   'Remain': 27391,
#   'Leave': 33794,
#   'Rejected_Ballots': 37,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 4,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 33},
#  {'Area_Code': 'E07000204',
#   'Area': 'St Edmundsbury',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 81148,
#   'Votes_Cast': 62255,
#   'Valid_Votes': 62210,
#   'Remain': 26986,
#   'Leave': 35224,
#   'Rejected_Ballots': 45,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 30},
#  {'Area_Code': 'E07000205',
#   'Area': 'Suffolk Coastal',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 98195,
#   'Votes_Cast': 79226,
#   'Valid_Votes': 79184,
#   'Remain': 37218,
#   'Leave': 41966,
#   'Rejected_Ballots': 42,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 24},
#  {'Area_Code': 'E07000206',
#   'Area': 'Waveney',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 90391,
#   'Votes_Cast': 65687,
#   'Valid_Votes': 65646,
#   'Remain': 24356,
#   'Leave': 41290,
#   'Rejected_Ballots': 41,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 11,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 30},
#  {'Area_Code': 'E07000240',
#   'Area': 'St Albans',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 104859,
#   'Votes_Cast': 86524,
#   'Valid_Votes': 86445,
#   'Remain': 54208,
#   'Leave': 32237,
#   'Rejected_Ballots': 79,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 31,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 48},
#  {'Area_Code': 'E07000241',
#   'Area': 'Welwyn Hatfield',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 78146,
#   'Votes_Cast': 58641,
#   'Valid_Votes': 58610,
#   'Remain': 27550,
#   'Leave': 31060,
#   'Rejected_Ballots': 31,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 21},
#  {'Area_Code': 'E07000242',
#   'Area': 'East Hertfordshire',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 106260,
#   'Votes_Cast': 85433,
#   'Valid_Votes': 85366,
#   'Remain': 42372,
#   'Leave': 42994,
#   'Rejected_Ballots': 67,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 26,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 36},
#  {'Area_Code': 'E07000243',
#   'Area': 'Stevenage',
#   'Region_Code': 'E12000006',
#   'Region': 'East',
#   'Electorate': 62156,
#   'Votes_Cast': 45811,
#   'Valid_Votes': 45785,
#   'Remain': 18659,
#   'Leave': 27126,
#   'Rejected_Ballots': 26,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 12,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 12},
#  {'Area_Code': 'E06000015',
#   'Area': 'Derby',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 171246,
#   'Votes_Cast': 120772,
#   'Valid_Votes': 120655,
#   'Remain': 51612,
#   'Leave': 69043,
#   'Rejected_Ballots': 117,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 41,
#   'Writing_or_mark': 10,
#   'Unmarked_or_void': 66},
#  {'Area_Code': 'E06000016',
#   'Area': 'Leicester',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 213819,
#   'Votes_Cast': 139307,
#   'Valid_Votes': 138972,
#   'Remain': 70980,
#   'Leave': 67992,
#   'Rejected_Ballots': 335,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 154,
#   'Writing_or_mark': 8,
#   'Unmarked_or_void': 173},
#  {'Area_Code': 'E06000017',
#   'Area': 'Rutland',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 29390,
#   'Votes_Cast': 22984,
#   'Valid_Votes': 22966,
#   'Remain': 11353,
#   'Leave': 11613,
#   'Rejected_Ballots': 18,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 7},
#  {'Area_Code': 'E06000018',
#   'Area': 'Nottingham',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 195394,
#   'Votes_Cast': 120791,
#   'Valid_Votes': 120661,
#   'Remain': 59318,
#   'Leave': 61343,
#   'Rejected_Ballots': 130,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 47,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 79},
#  {'Area_Code': 'E07000032',
#   'Area': 'Amber Valley',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 96760,
#   'Votes_Cast': 73864,
#   'Valid_Votes': 73820,
#   'Remain': 29319,
#   'Leave': 44501,
#   'Rejected_Ballots': 44,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 7,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 36},
#  {'Area_Code': 'E07000033',
#   'Area': 'Bolsover',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 58063,
#   'Votes_Cast': 41999,
#   'Valid_Votes': 41972,
#   'Remain': 12242,
#   'Leave': 29730,
#   'Rejected_Ballots': 27,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 5,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 21},
#  {'Area_Code': 'E07000034',
#   'Area': 'Chesterfield',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 79905,
#   'Votes_Cast': 57470,
#   'Valid_Votes': 57424,
#   'Remain': 22946,
#   'Leave': 34478,
#   'Rejected_Ballots': 46,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 16,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 28},
#  {'Area_Code': 'E07000035',
#   'Area': 'Derbyshire Dales',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 57075,
#   'Votes_Cast': 46756,
#   'Valid_Votes': 46728,
#   'Remain': 22633,
#   'Leave': 24095,
#   'Rejected_Ballots': 28,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 5,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 23},
#  {'Area_Code': 'E07000036',
#   'Area': 'Erewash',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 87596,
#   'Votes_Cast': 66566,
#   'Valid_Votes': 66530,
#   'Remain': 25791,
#   'Leave': 40739,
#   'Rejected_Ballots': 36,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 20},
#  {'Area_Code': 'E07000037',
#   'Area': 'High Peak',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 72487,
#   'Votes_Cast': 54864,
#   'Valid_Votes': 54833,
#   'Remain': 27116,
#   'Leave': 27717,
#   'Rejected_Ballots': 31,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 18},
#  {'Area_Code': 'E07000038',
#   'Area': 'North East Derbyshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 78855,
#   'Votes_Cast': 59341,
#   'Valid_Votes': 59310,
#   'Remain': 22075,
#   'Leave': 37235,
#   'Rejected_Ballots': 31,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 16},
#  {'Area_Code': 'E07000039',
#   'Area': 'South Derbyshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73856,
#   'Votes_Cast': 56718,
#   'Valid_Votes': 56695,
#   'Remain': 22479,
#   'Leave': 34216,
#   'Rejected_Ballots': 23,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 5,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 18},
#  {'Area_Code': 'E07000129',
#   'Area': 'Blaby',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73832,
#   'Votes_Cast': 56512,
#   'Valid_Votes': 56471,
#   'Remain': 22888,
#   'Leave': 33583,
#   'Rejected_Ballots': 41,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 26},
#  {'Area_Code': 'E07000130',
#   'Area': 'Charnwood',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 133780,
#   'Votes_Cast': 94257,
#   'Valid_Votes': 94172,
#   'Remain': 43500,
#   'Leave': 50672,
#   'Rejected_Ballots': 85,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 47,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 38},
#  {'Area_Code': 'E07000131',
#   'Area': 'Harborough',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 67420,
#   'Votes_Cast': 54910,
#   'Valid_Votes': 54878,
#   'Remain': 27028,
#   'Leave': 27850,
#   'Rejected_Ballots': 32,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 1,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 29},
#  {'Area_Code': 'E07000132',
#   'Area': 'Hinckley and Bosworth',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 85305,
#   'Votes_Cast': 65516,
#   'Valid_Votes': 65470,
#   'Remain': 25969,
#   'Leave': 39501,
#   'Rejected_Ballots': 46,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 40},
#  {'Area_Code': 'E07000133',
#   'Area': 'Melton',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 37273,
#   'Votes_Cast': 30327,
#   'Valid_Votes': 30305,
#   'Remain': 12695,
#   'Leave': 17610,
#   'Rejected_Ballots': 22,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 12},
#  {'Area_Code': 'E07000134',
#   'Area': 'North West Leicestershire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73944,
#   'Votes_Cast': 57638,
#   'Valid_Votes': 57611,
#   'Remain': 22642,
#   'Leave': 34969,
#   'Rejected_Ballots': 27,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 21},
#  {'Area_Code': 'E07000135',
#   'Area': 'Oadby and Wigston',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 42684,
#   'Votes_Cast': 31489,
#   'Valid_Votes': 31465,
#   'Remain': 14292,
#   'Leave': 17173,
#   'Rejected_Ballots': 24,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 15},
#  {'Area_Code': 'E07000136',
#   'Area': 'Boston',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 39363,
#   'Votes_Cast': 30416,
#   'Valid_Votes': 30404,
#   'Remain': 7430,
#   'Leave': 22974,
#   'Rejected_Ballots': 12,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 1,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 10},
#  {'Area_Code': 'E07000137',
#   'Area': 'East Lindsey',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 107009,
#   'Votes_Cast': 80178,
#   'Valid_Votes': 80128,
#   'Remain': 23515,
#   'Leave': 56613,
#   'Rejected_Ballots': 50,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 21,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 27},
#  {'Area_Code': 'E07000138',
#   'Area': 'Lincoln',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 63351,
#   'Votes_Cast': 43928,
#   'Valid_Votes': 43894,
#   'Remain': 18902,
#   'Leave': 24992,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 17},
#  {'Area_Code': 'E07000139',
#   'Area': 'North Kesteven',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 86468,
#   'Votes_Cast': 67791,
#   'Valid_Votes': 67753,
#   'Remain': 25570,
#   'Leave': 42183,
#   'Rejected_Ballots': 38,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 24},
#  {'Area_Code': 'E07000140',
#   'Area': 'South Holland',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 65701,
#   'Votes_Cast': 49518,
#   'Valid_Votes': 49497,
#   'Remain': 13074,
#   'Leave': 36423,
#   'Rejected_Ballots': 21,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 8,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 13},
#  {'Area_Code': 'E07000141',
#   'Area': 'South Kesteven',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 105457,
#   'Votes_Cast': 82523,
#   'Valid_Votes': 82471,
#   'Remain': 33047,
#   'Leave': 49424,
#   'Rejected_Ballots': 52,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 34},
#  {'Area_Code': 'E07000142',
#   'Area': 'West Lindsey',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 73499,
#   'Votes_Cast': 54781,
#   'Valid_Votes': 54753,
#   'Remain': 20906,
#   'Leave': 33847,
#   'Rejected_Ballots': 28,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 7,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 17},
#  {'Area_Code': 'E07000150',
#   'Area': 'Corby',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 43313,
#   'Votes_Cast': 32097,
#   'Valid_Votes': 32081,
#   'Remain': 11470,
#   'Leave': 20611,
#   'Rejected_Ballots': 16,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 4,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 12},
#  {'Area_Code': 'E07000151',
#   'Area': 'Daventry',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 61004,
#   'Votes_Cast': 49420,
#   'Valid_Votes': 49381,
#   'Remain': 20443,
#   'Leave': 28938,
#   'Rejected_Ballots': 39,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 27},
#  {'Area_Code': 'E07000152',
#   'Area': 'East Northamptonshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 68334,
#   'Votes_Cast': 52607,
#   'Valid_Votes': 52574,
#   'Remain': 21680,
#   'Leave': 30894,
#   'Rejected_Ballots': 33,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 25},
#  {'Area_Code': 'E07000153',
#   'Area': 'Kettering',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 70570,
#   'Votes_Cast': 53940,
#   'Valid_Votes': 53907,
#   'Remain': 21030,
#   'Leave': 32877,
#   'Rejected_Ballots': 33,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 12,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 20},
#  {'Area_Code': 'E07000154',
#   'Area': 'Northampton',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 144948,
#   'Votes_Cast': 105354,
#   'Valid_Votes': 105259,
#   'Remain': 43805,
#   'Leave': 61454,
#   'Rejected_Ballots': 95,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 35,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 53},
#  {'Area_Code': 'E07000155',
#   'Area': 'South Northamptonshire',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 71309,
#   'Votes_Cast': 56664,
#   'Valid_Votes': 56624,
#   'Remain': 25853,
#   'Leave': 30771,
#   'Rejected_Ballots': 40,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 18,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 21},
#  {'Area_Code': 'E07000156',
#   'Area': 'Wellingborough',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 54572,
#   'Votes_Cast': 41178,
#   'Valid_Votes': 41141,
#   'Remain': 15462,
#   'Leave': 25679,
#   'Rejected_Ballots': 37,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 18,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 17},
#  {'Area_Code': 'E07000170',
#   'Area': 'Ashfield',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 91916,
#   'Votes_Cast': 66946,
#   'Valid_Votes': 66899,
#   'Remain': 20179,
#   'Leave': 46720,
#   'Rejected_Ballots': 47,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 30},
#  {'Area_Code': 'E07000171',
#   'Area': 'Bassetlaw',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 85547,
#   'Votes_Cast': 64003,
#   'Valid_Votes': 63967,
#   'Remain': 20575,
#   'Leave': 43392,
#   'Rejected_Ballots': 36,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 20},
#  {'Area_Code': 'E07000172',
#   'Area': 'Broxtowe',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 83593,
#   'Votes_Cast': 65468,
#   'Valid_Votes': 65426,
#   'Remain': 29672,
#   'Leave': 35754,
#   'Rejected_Ballots': 42,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 8,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 33},
#  {'Area_Code': 'E07000173',
#   'Area': 'Gedling',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 88298,
#   'Votes_Cast': 67635,
#   'Valid_Votes': 67577,
#   'Remain': 30035,
#   'Leave': 37542,
#   'Rejected_Ballots': 58,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 38},
#  {'Area_Code': 'E07000174',
#   'Area': 'Mansfield',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 77624,
#   'Votes_Cast': 56370,
#   'Valid_Votes': 56344,
#   'Remain': 16417,
#   'Leave': 39927,
#   'Rejected_Ballots': 26,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 8,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 18},
#  {'Area_Code': 'E07000175',
#   'Area': 'Newark and Sherwood',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 87338,
#   'Votes_Cast': 67128,
#   'Valid_Votes': 67087,
#   'Remain': 26571,
#   'Leave': 40516,
#   'Rejected_Ballots': 41,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 25},
#  {'Area_Code': 'E07000176',
#   'Area': 'Rushcliffe',
#   'Region_Code': 'E12000004',
#   'Region': 'East Midlands',
#   'Electorate': 86401,
#   'Votes_Cast': 70470,
#   'Valid_Votes': 70410,
#   'Remain': 40522,
#   'Leave': 29888,
#   'Rejected_Ballots': 60,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 20,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 40},
#  {'Area_Code': 'E09000001',
#   'Area': 'City of London',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 5987,
#   'Votes_Cast': 4405,
#   'Valid_Votes': 4399,
#   'Remain': 3312,
#   'Leave': 1087,
#   'Rejected_Ballots': 6,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 2,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 4},
#  {'Area_Code': 'E09000002',
#   'Area': 'Barking and Dagenham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 115812,
#   'Votes_Cast': 73941,
#   'Valid_Votes': 73880,
#   'Remain': 27750,
#   'Leave': 46130,
#   'Rejected_Ballots': 61,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 21,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 40},
#  {'Area_Code': 'E09000003',
#   'Area': 'Barnet',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 223467,
#   'Votes_Cast': 161218,
#   'Valid_Votes': 161033,
#   'Remain': 100210,
#   'Leave': 60823,
#   'Rejected_Ballots': 185,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 54,
#   'Writing_or_mark': 12,
#   'Unmarked_or_void': 119},
#  {'Area_Code': 'E09000004',
#   'Area': 'Bexley',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 170779,
#   'Votes_Cast': 128570,
#   'Valid_Votes': 128489,
#   'Remain': 47603,
#   'Leave': 80886,
#   'Rejected_Ballots': 81,
#   'No_official_mark': 5,
#   'Voting_for_both_answers': 35,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 41},
#  {'Area_Code': 'E09000005',
#   'Area': 'Brent',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 186793,
#   'Votes_Cast': 121671,
#   'Valid_Votes': 121404,
#   'Remain': 72523,
#   'Leave': 48881,
#   'Rejected_Ballots': 267,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 157,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 110},
#  {'Area_Code': 'E09000006',
#   'Area': 'Bromley',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 231473,
#   'Votes_Cast': 182570,
#   'Valid_Votes': 182432,
#   'Remain': 92398,
#   'Leave': 90034,
#   'Rejected_Ballots': 138,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 43,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 95},
#  {'Area_Code': 'E09000007',
#   'Area': 'Camden',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 145425,
#   'Votes_Cast': 95281,
#   'Valid_Votes': 95133,
#   'Remain': 71295,
#   'Leave': 23838,
#   'Rejected_Ballots': 148,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 54,
#   'Writing_or_mark': 8,
#   'Unmarked_or_void': 86},
#  {'Area_Code': 'E09000008',
#   'Area': 'Croydon',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 245349,
#   'Votes_Cast': 171289,
#   'Valid_Votes': 171134,
#   'Remain': 92913,
#   'Leave': 78221,
#   'Rejected_Ballots': 155,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 73,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 77},
#  {'Area_Code': 'E09000009',
#   'Area': 'Ealing',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 212991,
#   'Votes_Cast': 149268,
#   'Valid_Votes': 149041,
#   'Remain': 90024,
#   'Leave': 59017,
#   'Rejected_Ballots': 227,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 115,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 109},
#  {'Area_Code': 'E09000010',
#   'Area': 'Enfield',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 198387,
#   'Votes_Cast': 137056,
#   'Valid_Votes': 136906,
#   'Remain': 76425,
#   'Leave': 60481,
#   'Rejected_Ballots': 150,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 69,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 80},
#  {'Area_Code': 'E09000011',
#   'Area': 'Greenwich',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 168967,
#   'Votes_Cast': 117470,
#   'Valid_Votes': 117365,
#   'Remain': 65248,
#   'Leave': 52117,
#   'Rejected_Ballots': 105,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 35,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 69},
#  {'Area_Code': 'E09000012',
#   'Area': 'Hackney',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 163284,
#   'Votes_Cast': 106422,
#   'Valid_Votes': 106266,
#   'Remain': 83398,
#   'Leave': 22868,
#   'Rejected_Ballots': 156,
#   'No_official_mark': 7,
#   'Voting_for_both_answers': 44,
#   'Writing_or_mark': 35,
#   'Unmarked_or_void': 70},
#  {'Area_Code': 'E09000013',
#   'Area': 'Hammersmith and Fulham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 114863,
#   'Votes_Cast': 80347,
#   'Valid_Votes': 80242,
#   'Remain': 56188,
#   'Leave': 24054,
#   'Rejected_Ballots': 105,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 32,
#   'Writing_or_mark': 8,
#   'Unmarked_or_void': 65},
#  {'Area_Code': 'E09000014',
#   'Area': 'Haringey',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 150098,
#   'Votes_Cast': 106032,
#   'Valid_Votes': 105846,
#   'Remain': 79991,
#   'Leave': 25855,
#   'Rejected_Ballots': 186,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 71,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 115},
#  {'Area_Code': 'E09000015',
#   'Area': 'Harrow',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 162397,
#   'Votes_Cast': 117352,
#   'Valid_Votes': 117225,
#   'Remain': 64042,
#   'Leave': 53183,
#   'Rejected_Ballots': 127,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 50,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 71},
#  {'Area_Code': 'E09000016',
#   'Area': 'Havering',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 183082,
#   'Votes_Cast': 139175,
#   'Valid_Votes': 139086,
#   'Remain': 42201,
#   'Leave': 96885,
#   'Rejected_Ballots': 89,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 25,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 62},
#  {'Area_Code': 'E09000017',
#   'Area': 'Hillingdon',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 193033,
#   'Votes_Cast': 133170,
#   'Valid_Votes': 133022,
#   'Remain': 58040,
#   'Leave': 74982,
#   'Rejected_Ballots': 148,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 55,
#   'Writing_or_mark': 16,
#   'Unmarked_or_void': 77},
#  {'Area_Code': 'E09000018',
#   'Area': 'Hounslow',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 165050,
#   'Votes_Cast': 115208,
#   'Valid_Votes': 115076,
#   'Remain': 58755,
#   'Leave': 56321,
#   'Rejected_Ballots': 132,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 39,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 87},
#  {'Area_Code': 'E09000019',
#   'Area': 'Islington',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 144514,
#   'Votes_Cast': 101723,
#   'Valid_Votes': 101600,
#   'Remain': 76420,
#   'Leave': 25180,
#   'Rejected_Ballots': 123,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 47,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 74},
#  {'Area_Code': 'E09000020',
#   'Area': 'Kensington and Chelsea',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 83042,
#   'Votes_Cast': 54801,
#   'Valid_Votes': 54739,
#   'Remain': 37601,
#   'Leave': 17138,
#   'Rejected_Ballots': 62,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 14,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 46},
#  {'Area_Code': 'E09000021',
#   'Area': 'Kingston upon Thames',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 108838,
#   'Votes_Cast': 85330,
#   'Valid_Votes': 85270,
#   'Remain': 52533,
#   'Leave': 32737,
#   'Rejected_Ballots': 60,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 16,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 41},
#  {'Area_Code': 'E09000022',
#   'Area': 'Lambeth',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 210800,
#   'Votes_Cast': 142162,
#   'Valid_Votes': 141924,
#   'Remain': 111584,
#   'Leave': 30340,
#   'Rejected_Ballots': 238,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 104,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 134},
#  {'Area_Code': 'E09000023',
#   'Area': 'Lewisham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 197514,
#   'Votes_Cast': 124637,
#   'Valid_Votes': 124473,
#   'Remain': 86955,
#   'Leave': 37518,
#   'Rejected_Ballots': 164,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 61,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 102},
#  {'Area_Code': 'E09000024',
#   'Area': 'Merton',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 136352,
#   'Votes_Cast': 100207,
#   'Valid_Votes': 100100,
#   'Remain': 63003,
#   'Leave': 37097,
#   'Rejected_Ballots': 107,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 45,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 62},
#  {'Area_Code': 'E09000025',
#   'Area': 'Newham',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 176985,
#   'Votes_Cast': 104864,
#   'Valid_Votes': 104699,
#   'Remain': 55328,
#   'Leave': 49371,
#   'Rejected_Ballots': 165,
#   'No_official_mark': 9,
#   'Voting_for_both_answers': 87,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 69},
#  {'Area_Code': 'E09000026',
#   'Area': 'Redbridge',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 189843,
#   'Votes_Cast': 128397,
#   'Valid_Votes': 128233,
#   'Remain': 69213,
#   'Leave': 59020,
#   'Rejected_Ballots': 164,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 78,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 83},
#  {'Area_Code': 'E09000027',
#   'Area': 'Richmond upon Thames',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 132632,
#   'Votes_Cast': 108876,
#   'Valid_Votes': 108806,
#   'Remain': 75396,
#   'Leave': 33410,
#   'Rejected_Ballots': 70,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 26,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 42},
#  {'Area_Code': 'E09000028',
#   'Area': 'Southwark',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 195875,
#   'Votes_Cast': 129677,
#   'Valid_Votes': 129502,
#   'Remain': 94293,
#   'Leave': 35209,
#   'Rejected_Ballots': 175,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 60,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 110},
#  {'Area_Code': 'E09000029',
#   'Area': 'Sutton',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 140288,
#   'Votes_Cast': 106633,
#   'Valid_Votes': 106560,
#   'Remain': 49319,
#   'Leave': 57241,
#   'Rejected_Ballots': 73,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 25,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 41},
#  {'Area_Code': 'E09000030',
#   'Area': 'Tower Hamlets',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 167820,
#   'Votes_Cast': 108420,
#   'Valid_Votes': 108235,
#   'Remain': 73011,
#   'Leave': 35224,
#   'Rejected_Ballots': 185,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 105,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 74},
#  {'Area_Code': 'E09000031',
#   'Area': 'Waltham Forest',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 162983,
#   'Votes_Cast': 108689,
#   'Valid_Votes': 108551,
#   'Remain': 64156,
#   'Leave': 44395,
#   'Rejected_Ballots': 138,
#   'No_official_mark': 4,
#   'Voting_for_both_answers': 44,
#   'Writing_or_mark': 9,
#   'Unmarked_or_void': 81},
#  {'Area_Code': 'E09000032',
#   'Area': 'Wandsworth',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 219521,
#   'Votes_Cast': 158018,
#   'Valid_Votes': 157884,
#   'Remain': 118463,
#   'Leave': 39421,
#   'Rejected_Ballots': 134,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 55,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 79},
#  {'Area_Code': 'E09000033',
#   'Area': 'Westminster',
#   'Region_Code': 'E12000007',
#   'Region': 'London',
#   'Electorate': 120524,
#   'Votes_Cast': 78325,
#   'Valid_Votes': 78196,
#   'Remain': 53928,
#   'Leave': 24268,
#   'Rejected_Ballots': 129,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 47,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 81},
#  {'Area_Code': 'E06000001',
#   'Area': 'Hartlepool',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 70341,
#   'Votes_Cast': 46134,
#   'Valid_Votes': 46100,
#   'Remain': 14029,
#   'Leave': 32071,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 12,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 16},
#  {'Area_Code': 'E06000002',
#   'Area': 'Middlesbrough',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 94612,
#   'Votes_Cast': 61393,
#   'Valid_Votes': 61358,
#   'Remain': 21181,
#   'Leave': 40177,
#   'Rejected_Ballots': 35,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 16,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 18},
#  {'Area_Code': 'E06000003',
#   'Area': 'Redcar and Cleveland',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 103529,
#   'Votes_Cast': 72741,
#   'Valid_Votes': 72714,
#   'Remain': 24586,
#   'Leave': 48128,
#   'Rejected_Ballots': 27,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 21},
#  {'Area_Code': 'E06000004',
#   'Area': 'Stockton-on-Tees',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 141486,
#   'Votes_Cast': 100460,
#   'Valid_Votes': 100415,
#   'Remain': 38433,
#   'Leave': 61982,
#   'Rejected_Ballots': 45,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 28},
#  {'Area_Code': 'E06000005',
#   'Area': 'Darlington',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 77662,
#   'Votes_Cast': 55195,
#   'Valid_Votes': 55166,
#   'Remain': 24172,
#   'Leave': 30994,
#   'Rejected_Ballots': 29,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 0,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 29},
#  {'Area_Code': 'E06000047',
#   'Area': 'County Durham',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 389507,
#   'Votes_Cast': 267546,
#   'Valid_Votes': 267398,
#   'Remain': 113521,
#   'Leave': 153877,
#   'Rejected_Ballots': 148,
#   'No_official_mark': 3,
#   'Voting_for_both_answers': 35,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 109},
#  {'Area_Code': 'E06000057',
#   'Area': 'Northumberland',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 240496,
#   'Votes_Cast': 178815,
#   'Valid_Votes': 178721,
#   'Remain': 82022,
#   'Leave': 96699,
#   'Rejected_Ballots': 94,
#   'No_official_mark': 3,
#   'Voting_for_both_answers': 30,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 55},
#  {'Area_Code': 'E08000021',
#   'Area': 'Newcastle upon Tyne',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 190735,
#   'Votes_Cast': 129072,
#   'Valid_Votes': 129003,
#   'Remain': 65405,
#   'Leave': 63598,
#   'Rejected_Ballots': 69,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 20,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 44},
#  {'Area_Code': 'E08000022',
#   'Area': 'North Tyneside',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 156993,
#   'Votes_Cast': 113507,
#   'Valid_Votes': 113462,
#   'Remain': 52873,
#   'Leave': 60589,
#   'Rejected_Ballots': 45,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 25},
#  {'Area_Code': 'E08000023',
#   'Area': 'South Tyneside',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 115893,
#   'Votes_Cast': 79117,
#   'Valid_Votes': 79079,
#   'Remain': 30014,
#   'Leave': 49065,
#   'Rejected_Ballots': 38,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 27},
#  {'Area_Code': 'E08000024',
#   'Area': 'Sunderland',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 207221,
#   'Votes_Cast': 134400,
#   'Valid_Votes': 134324,
#   'Remain': 51930,
#   'Leave': 82394,
#   'Rejected_Ballots': 76,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 61},
#  {'Area_Code': 'E08000037',
#   'Area': 'Gateshead',
#   'Region_Code': 'E12000001',
#   'Region': 'North East',
#   'Electorate': 145866,
#   'Votes_Cast': 103007,
#   'Valid_Votes': 102958,
#   'Remain': 44429,
#   'Leave': 58529,
#   'Rejected_Ballots': 49,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 33},
#  {'Area_Code': 'E06000006',
#   'Area': 'Halton',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 95289,
#   'Votes_Cast': 65047,
#   'Valid_Votes': 65005,
#   'Remain': 27678,
#   'Leave': 37327,
#   'Rejected_Ballots': 42,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 7,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 34},
#  {'Area_Code': 'E06000007',
#   'Area': 'Warrington',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 157042,
#   'Votes_Cast': 115205,
#   'Valid_Votes': 115144,
#   'Remain': 52657,
#   'Leave': 62487,
#   'Rejected_Ballots': 61,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 43},
#  {'Area_Code': 'E06000008',
#   'Area': 'Blackburn with Darwen',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 100117,
#   'Votes_Cast': 65408,
#   'Valid_Votes': 65321,
#   'Remain': 28522,
#   'Leave': 36799,
#   'Rejected_Ballots': 87,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 40,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 43},
#  {'Area_Code': 'E06000009',
#   'Area': 'Blackpool',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 102354,
#   'Votes_Cast': 66959,
#   'Valid_Votes': 66927,
#   'Remain': 21781,
#   'Leave': 45146,
#   'Rejected_Ballots': 32,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 8,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 21},
#  {'Area_Code': 'E06000049',
#   'Area': 'Cheshire East',
#   'Region_Code': 'E12000002',
#   'Region': 'North West',
#   'Electorate': 285957,
#   'Votes_Cast': 221229,
#   'Valid_Votes': 221125,
#   'Remain': 107962,
#   'Leave': 113163,
#   'Rejected_Ballots': 104,
#   'No_official_mark': 19,
#   'Voting_for_both_answers': 40,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 42},
# ...
#   'Voting_for_both_answers': 16,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 23},
#  {'Area_Code': 'E07000195',
#   'Area': 'Newcastle-under-Lyme',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 92816,
#   'Votes_Cast': 68966,
#   'Valid_Votes': 68934,
#   'Remain': 25477,
#   'Leave': 43457,
#   'Rejected_Ballots': 32,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 19},
#  {'Area_Code': 'E07000196',
#   'Area': 'South Staffordshire',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 85777,
#   'Votes_Cast': 66739,
#   'Valid_Votes': 66692,
#   'Remain': 23444,
#   'Leave': 43248,
#   'Rejected_Ballots': 47,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 39},
#  {'Area_Code': 'E07000197',
#   'Area': 'Stafford',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 99612,
#   'Votes_Cast': 77527,
#   'Valid_Votes': 77484,
#   'Remain': 34098,
#   'Leave': 43386,
#   'Rejected_Ballots': 43,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 11,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 29},
#  {'Area_Code': 'E07000198',
#   'Area': 'Staffordshire Moorlands',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 79347,
#   'Votes_Cast': 59793,
#   'Valid_Votes': 59760,
#   'Remain': 21076,
#   'Leave': 38684,
#   'Rejected_Ballots': 33,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 20},
#  {'Area_Code': 'E07000199',
#   'Area': 'Tamworth',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 56825,
#   'Votes_Cast': 42151,
#   'Valid_Votes': 42129,
#   'Remain': 13705,
#   'Leave': 28424,
#   'Rejected_Ballots': 22,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 12,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 10},
#  {'Area_Code': 'E07000218',
#   'Area': 'North Warwickshire',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 49790,
#   'Votes_Cast': 37975,
#   'Valid_Votes': 37954,
#   'Remain': 12569,
#   'Leave': 25385,
#   'Rejected_Ballots': 21,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 12},
#  {'Area_Code': 'E07000219',
#   'Area': 'Nuneaton and Bedworth',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 93978,
#   'Votes_Cast': 69876,
#   'Valid_Votes': 69831,
#   'Remain': 23736,
#   'Leave': 46095,
#   'Rejected_Ballots': 45,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 20,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 23},
#  {'Area_Code': 'E07000220',
#   'Area': 'Rugby',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 74137,
#   'Votes_Cast': 58593,
#   'Valid_Votes': 58549,
#   'Remain': 25350,
#   'Leave': 33199,
#   'Rejected_Ballots': 44,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 13,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 29},
#  {'Area_Code': 'E07000221',
#   'Area': 'Stratford-on-Avon',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 98014,
#   'Votes_Cast': 79217,
#   'Valid_Votes': 79158,
#   'Remain': 38341,
#   'Leave': 40817,
#   'Rejected_Ballots': 59,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 9,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 50},
#  {'Area_Code': 'E07000222',
#   'Area': 'Warwick',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 103099,
#   'Votes_Cast': 81680,
#   'Valid_Votes': 81618,
#   'Remain': 47976,
#   'Leave': 33642,
#   'Rejected_Ballots': 62,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 33,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 29},
#  {'Area_Code': 'E07000234',
#   'Area': 'Bromsgrove',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 74170,
#   'Votes_Cast': 58855,
#   'Valid_Votes': 58815,
#   'Remain': 26252,
#   'Leave': 32563,
#   'Rejected_Ballots': 40,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 11,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 27},
#  {'Area_Code': 'E07000235',
#   'Area': 'Malvern Hills',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 60217,
#   'Votes_Cast': 48538,
#   'Valid_Votes': 48497,
#   'Remain': 23203,
#   'Leave': 25294,
#   'Rejected_Ballots': 41,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 10,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 31},
#  {'Area_Code': 'E07000236',
#   'Area': 'Redditch',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 61038,
#   'Votes_Cast': 45912,
#   'Valid_Votes': 45882,
#   'Remain': 17303,
#   'Leave': 28579,
#   'Rejected_Ballots': 30,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 7,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 23},
#  {'Area_Code': 'E07000237',
#   'Area': 'Worcester',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 73516,
#   'Votes_Cast': 54290,
#   'Valid_Votes': 54239,
#   'Remain': 25125,
#   'Leave': 29114,
#   'Rejected_Ballots': 51,
#   'No_official_mark': 7,
#   'Voting_for_both_answers': 22,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 20},
#  {'Area_Code': 'E07000238',
#   'Area': 'Wychavon',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 94497,
#   'Votes_Cast': 76425,
#   'Valid_Votes': 76389,
#   'Remain': 32188,
#   'Leave': 44201,
#   'Rejected_Ballots': 36,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 15,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 21},
#  {'Area_Code': 'E07000239',
#   'Area': 'Wyre Forest',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 77878,
#   'Votes_Cast': 57666,
#   'Valid_Votes': 57632,
#   'Remain': 21240,
#   'Leave': 36392,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 28},
#  {'Area_Code': 'E08000025',
#   'Area': 'Birmingham',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 707293,
#   'Votes_Cast': 451316,
#   'Valid_Votes': 450702,
#   'Remain': 223451,
#   'Leave': 227251,
#   'Rejected_Ballots': 614,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 311,
#   'Writing_or_mark': 17,
#   'Unmarked_or_void': 286},
#  {'Area_Code': 'E08000026',
#   'Area': 'Coventry',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 221389,
#   'Votes_Cast': 153234,
#   'Valid_Votes': 153064,
#   'Remain': 67967,
#   'Leave': 85097,
#   'Rejected_Ballots': 170,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 85,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 85},
#  {'Area_Code': 'E08000027',
#   'Area': 'Dudley',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 244516,
#   'Votes_Cast': 175333,
#   'Valid_Votes': 175226,
#   'Remain': 56780,
#   'Leave': 118446,
#   'Rejected_Ballots': 107,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 41,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 64},
#  {'Area_Code': 'E08000028',
#   'Area': 'Sandwell',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 221429,
#   'Votes_Cast': 147418,
#   'Valid_Votes': 147254,
#   'Remain': 49004,
#   'Leave': 98250,
#   'Rejected_Ballots': 164,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 90,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 72},
#  {'Area_Code': 'E08000029',
#   'Area': 'Solihull',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 160425,
#   'Votes_Cast': 122020,
#   'Valid_Votes': 121950,
#   'Remain': 53466,
#   'Leave': 68484,
#   'Rejected_Ballots': 70,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 25,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 45},
#  {'Area_Code': 'E08000030',
#   'Area': 'Walsall',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 194729,
#   'Votes_Cast': 135685,
#   'Valid_Votes': 135579,
#   'Remain': 43572,
#   'Leave': 92007,
#   'Rejected_Ballots': 106,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 59,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 44},
#  {'Area_Code': 'E08000031',
#   'Area': 'Wolverhampton',
#   'Region_Code': 'E12000005',
#   'Region': 'West Midlands',
#   'Electorate': 174760,
#   'Votes_Cast': 118037,
#   'Valid_Votes': 117936,
#   'Remain': 44138,
#   'Leave': 73798,
#   'Rejected_Ballots': 101,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 45,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 49},
#  {'Area_Code': 'E06000010',
#   'Area': 'Kingston upon Hull, City of',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 180230,
#   'Votes_Cast': 113436,
#   'Valid_Votes': 113355,
#   'Remain': 36709,
#   'Leave': 76646,
#   'Rejected_Ballots': 81,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 23,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 54},
#  {'Area_Code': 'E06000011',
#   'Area': 'East Riding of Yorkshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 266047,
#   'Votes_Cast': 199036,
#   'Valid_Votes': 198915,
#   'Remain': 78779,
#   'Leave': 120136,
#   'Rejected_Ballots': 121,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 36,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 82},
#  {'Area_Code': 'E06000012',
#   'Area': 'North East Lincolnshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 116302,
#   'Votes_Cast': 79011,
#   'Valid_Votes': 78982,
#   'Remain': 23797,
#   'Leave': 55185,
#   'Rejected_Ballots': 29,
#   'No_official_mark': 1,
#   'Voting_for_both_answers': 4,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 23},
#  {'Area_Code': 'E06000013',
#   'Area': 'North Lincolnshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 123611,
#   'Votes_Cast': 88906,
#   'Valid_Votes': 88862,
#   'Remain': 29947,
#   'Leave': 58915,
#   'Rejected_Ballots': 44,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 11,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 30},
#  {'Area_Code': 'E06000014',
#   'Area': 'York',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 155157,
#   'Votes_Cast': 109681,
#   'Valid_Votes': 109600,
#   'Remain': 63617,
#   'Leave': 45983,
#   'Rejected_Ballots': 81,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 20,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 56},
#  {'Area_Code': 'E07000163',
#   'Area': 'Craven',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 44320,
#   'Votes_Cast': 35907,
#   'Valid_Votes': 35891,
#   'Remain': 16930,
#   'Leave': 18961,
#   'Rejected_Ballots': 16,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 10},
#  {'Area_Code': 'E07000164',
#   'Area': 'Hambleton',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 70133,
#   'Votes_Cast': 55016,
#   'Valid_Votes': 54982,
#   'Remain': 25480,
#   'Leave': 29502,
#   'Rejected_Ballots': 34,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 18,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 15},
#  {'Area_Code': 'E07000165',
#   'Area': 'Harrogate',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 119987,
#   'Votes_Cast': 94653,
#   'Valid_Votes': 94585,
#   'Remain': 48211,
#   'Leave': 46374,
#   'Rejected_Ballots': 68,
#   'No_official_mark': 2,
#   'Voting_for_both_answers': 25,
#   'Writing_or_mark': 3,
#   'Unmarked_or_void': 38},
#  {'Area_Code': 'E07000166',
#   'Area': 'Richmondshire',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 36794,
#   'Votes_Cast': 27652,
#   'Valid_Votes': 27636,
#   'Remain': 11945,
#   'Leave': 15691,
#   'Rejected_Ballots': 16,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 10},
#  {'Area_Code': 'E07000167',
#   'Area': 'Ryedale',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 41529,
#   'Votes_Cast': 32069,
#   'Valid_Votes': 32050,
#   'Remain': 14340,
#   'Leave': 17710,
#   'Rejected_Ballots': 19,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 5,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 12},
#  {'Area_Code': 'E07000168',
#   'Area': 'Scarborough',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 82900,
#   'Votes_Cast': 60539,
#   'Valid_Votes': 60511,
#   'Remain': 22999,
#   'Leave': 37512,
#   'Rejected_Ballots': 28,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 6,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 22},
#  {'Area_Code': 'E07000169',
#   'Area': 'Selby',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 65278,
#   'Votes_Cast': 51636,
#   'Valid_Votes': 51603,
#   'Remain': 21071,
#   'Leave': 30532,
#   'Rejected_Ballots': 33,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 7,
#   'Writing_or_mark': 2,
#   'Unmarked_or_void': 24},
#  {'Area_Code': 'E08000016',
#   'Area': 'Barnsley',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 175809,
#   'Votes_Cast': 122972,
#   'Valid_Votes': 122909,
#   'Remain': 38951,
#   'Leave': 83958,
#   'Rejected_Ballots': 63,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 17,
#   'Writing_or_mark': 1,
#   'Unmarked_or_void': 45},
#  {'Area_Code': 'E08000017',
#   'Area': 'Doncaster',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 217432,
#   'Votes_Cast': 151246,
#   'Valid_Votes': 151182,
#   'Remain': 46922,
#   'Leave': 104260,
#   'Rejected_Ballots': 64,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 19,
#   'Writing_or_mark': 0,
#   'Unmarked_or_void': 45},
#  {'Area_Code': 'E08000018',
#   'Area': 'Rotherham',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 197623,
#   'Votes_Cast': 137470,
#   'Valid_Votes': 137387,
#   'Remain': 44115,
#   'Leave': 93272,
#   'Rejected_Ballots': 83,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 30,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 49},
#  {'Area_Code': 'E08000019',
#   'Area': 'Sheffield',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 396406,
#   'Votes_Cast': 266951,
#   'Valid_Votes': 266753,
#   'Remain': 130735,
#   'Leave': 136018,
#   'Rejected_Ballots': 198,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 76,
#   'Writing_or_mark': 6,
#   'Unmarked_or_void': 116},
#  {'Area_Code': 'E08000032',
#   'Area': 'Bradford',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 342817,
#   'Votes_Cast': 228727,
#   'Valid_Votes': 228488,
#   'Remain': 104575,
#   'Leave': 123913,
#   'Rejected_Ballots': 239,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 121,
#   'Writing_or_mark': 5,
#   'Unmarked_or_void': 113},
#  {'Area_Code': 'E08000033',
#   'Area': 'Calderdale',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 149195,
#   'Votes_Cast': 106004,
#   'Valid_Votes': 105925,
#   'Remain': 46950,
#   'Leave': 58975,
#   'Rejected_Ballots': 79,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 22,
#   'Writing_or_mark': 15,
#   'Unmarked_or_void': 42},
#  {'Area_Code': 'E08000034',
#   'Area': 'Kirklees',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 307081,
#   'Votes_Cast': 217428,
#   'Valid_Votes': 217240,
#   'Remain': 98485,
#   'Leave': 118755,
#   'Rejected_Ballots': 188,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 86,
#   'Writing_or_mark': 7,
#   'Unmarked_or_void': 95},
#  {'Area_Code': 'E08000035',
#   'Area': 'Leeds',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 543033,
#   'Votes_Cast': 387677,
#   'Valid_Votes': 387337,
#   'Remain': 194863,
#   'Leave': 192474,
#   'Rejected_Ballots': 340,
#   'No_official_mark': 39,
#   'Voting_for_both_answers': 116,
#   'Writing_or_mark': 8,
#   'Unmarked_or_void': 177},
#  {'Area_Code': 'E08000036',
#   'Area': 'Wakefield',
#   'Region_Code': 'E12000003',
#   'Region': 'Yorkshire and The Humber',
#   'Electorate': 246096,
#   'Votes_Cast': 175155,
#   'Valid_Votes': 175042,
#   'Remain': 58877,
#   'Leave': 116165,
#   'Rejected_Ballots': 113,
#   'No_official_mark': 0,
#   'Voting_for_both_answers': 46,
#   'Writing_or_mark': 4,
#   'Unmarked_or_void': 63}]

# %% [markdown]
# ### Q3. Summary Statistics
#
# Find the maximum, minimum, median, 25th and 75th percentile values for
# - Electorate
# - Number of Votes Cast
# - Number of Valid Votes
# - Number of Remain Votes
# - Number of Leave Votes
# - Number of Rejected Votes

# %%
def summ_stats(source_data, variable):
    # Get the variable data
    out_list = []
    for k,v in source_data.items():
        out_list.append(v[variable])
    out_list.sort()
    max_value = max(out_list)
    min_value = min(out_list)
    num_items = len(out_list)
    # Median Value
    if num_items //2 == num_items / 2:
        mid_value1 = num_items //2 - 1
        mid_value2 = num_items //2 
        median_value = (out_list[mid_value1] + out_list[mid_value2]) / 2
    else:
        mid_value = (num_items + 1) // 2 - 1
        median_value = out_list[mid_value]
    
    # Quartiles, using the nearest rank method
    q1_rank = (num_items * 0.25).__ceil__() - 1
    q3_rank = (num_items * 0.75).__ceil__() - 1
    
    q1 = out_list[q1_rank]
    q3 = out_list[q3_rank]
    
    out_dict = {
        'N': num_items
        , 'Max': max_value
        , 'Min': min_value
        , 'Median' : median_value
        , 'q1' : q1
        , 'q3' : q3
    }
        
    return out_dict

summ_stats(merged_dict, 'Electorate')
# Out:
# {'N': 382,
#  'Max': 1260955,
#  'Min': 1799,
#  'Median': 96425.5,
#  'q1': 72487,
#  'q3': 141486}

# %%
summ_stats(merged_dict, 'Votes_Cast')
# Out:
# {'N': 382,
#  'Max': 790523,
#  'Min': 1424,
#  'Median': 72544.5,
#  'q1': 54864,
#  'q3': 104809}

# %%
summ_stats(merged_dict, 'Valid_Votes')
# Out:
# {'N': 382,
#  'Max': 790149,
#  'Min': 1424,
#  'Median': 72511.5,
#  'q1': 54833,
#  'q3': 104699}

# %%
summ_stats(merged_dict, 'Remain')
# Out:
# {'N': 382,
#  'Max': 440707,
#  'Min': 803,
#  'Median': 33475.0,
#  'q1': 23515,
#  'q3': 48257}

# %%
summ_stats(merged_dict, 'Leave')
# Out:
# {'N': 382,
#  'Max': 349442,
#  'Min': 621,
#  'Median': 37573.5,
#  'q1': 28631,
#  'q3': 54198}

# %%
summ_stats(merged_dict, 'Rejected_Ballots')
# Out:
# {'N': 382, 'Max': 614, 'Min': 0, 'Median': 46.5, 'q1': 33, 'q3': 74}

# %% [markdown]
# ### Q4. Top and Bottom Areas
#
# - Find the Area with the highest and lowest Electorates
# - Find the Area with the highest and lowest Remain Voters
# - Find the Area with the highest and lowest Leave Voters

# %%
sorted(merged_list, key = lambda x:x['Electorate'])[0]['Area']
# Out:
# 'Isles of Scilly'

# %%
sorted(merged_list, key = lambda x:x['Electorate'])[-1]['Area']
# Out:
# 'Northern Ireland'

# %% [markdown]
# ### Q5. Region-wise Totals
#
# Aggregate the values at region level

# %%
regions = set([area['Region'] for area in merged_list])
regions
# Out:
# {'East',
#  'East Midlands',
#  'London',
#  'North East',
#  'North West',
#  'Northern Ireland',
#  'Scotland',
#  'South East',
#  'South West',
#  'Wales',
#  'West Midlands',
#  'Yorkshire and The Humber'}

# %%
region_dict = {}
for region in regions:
    reg_sum = sum([area['Electorate'] for area in merged_list if area['Region'] == region])
    region_dict.update({region: reg_sum})
    
region_dict
# Out:
# {'London': 5424768,
#  'Wales': 2270272,
#  'West Midlands': 4116572,
#  'North West': 5241568,
#  'Scotland': 3987112,
#  'Northern Ireland': 1260955,
#  'South East': 6465404,
#  'East': 4398796,
#  'East Midlands': 3384299,
#  'South West': 4138134,
#  'Yorkshire and The Humber': 3877780,
#  'North East': 1934341}

# %% [markdown]
# ### Q6. Contribution
#
# Find the Contribution of each region to the total

# %%
total_val = sum([reg[1] for reg in region_dict.items()])
cont_dict = {}
for k,v in region_dict.items():
    cont_dict.update({k: v/total_val * 100})
cont_dict
# Out:
# {'London': 11.66616749105016,
#  'Wales': 4.882305271348273,
#  'West Midlands': 8.852842820368972,
#  'North West': 11.272189004899161,
#  'Scotland': 8.574434224205715,
#  'Northern Ireland': 2.711731124478901,
#  'South East': 13.904094324643133,
#  'East': 9.459776140649975,
#  'East Midlands': 7.278062209073931,
#  'South West': 8.899212711844887,
#  'Yorkshire and The Humber': 8.339311648616954,
#  'North East': 4.159873028819935}
